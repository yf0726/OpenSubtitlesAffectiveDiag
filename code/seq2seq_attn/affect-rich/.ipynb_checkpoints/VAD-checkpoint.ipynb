# %%
import pandas as pd
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# %%
from itertools import chain
from nltk.corpus import wordnet

# %%
data = pd.read_csv('VAD.csv')

# %%
VAD = data[['Word','V.Mean.Sum','A.Mean.Sum','D.Mean.Sum']].copy()
VAD.columns = ['Word','V','A','D']
VAD.head()
# Out:
#           Word     V     A     D
# 0     aardvark  6.26  2.41  4.27
# 1      abalone  5.30  2.65  4.95
# 2      abandon  2.84  3.73  3.32
# 3  abandonment  2.63  4.95  2.64
# 4        abbey  5.85  2.20  5.00

# %%
VAD['Word'] = VAD['Word'].astype(str)
VAD.dtypes
# Out:
# Word     object
# V       float64
# A       float64
# D       float64
# dtype: object

# %%
VAD.set_index('Word',inplace=True)

# %%
def isVAD(x):
    return x in VAD.index

# %%
def VADsyn(x):
    synonyms = wordnet.synsets(x)
    VAD_syn = set(chain.from_iterable([word.lemma_names() for word in synonyms]))
    inVAD = list(filter(isVAD,VAD_syn))
    notinVAD = list(set(VAD_syn) - set(inVAD))
    print(notinVAD,'\n')
    
    for syn in notinVAD:
        if syn not in dict_syn.keys():
            dict_syn.update({syn:inVAD})
        else:
            dict_syn.update({syn:list(set(dict_syn[syn]+inVAD))})

# %%
dict_syn = {}

for word in VAD.index:
    print(word,type(word))
    VADsyn(word)
# Out:
# aardvark <class 'str'>
# ['ant_bear', 'anteater', 'Orycteropus_afer']
#
# abalone <class 'str'>
# ['ear-shell']
#
# abandon <class 'str'>
# ['wantonness', 'wildness', 'give_up', 'unconstraint']
#
# abandonment <class 'str'>
# ['defection', 'forsaking']
#
# abbey <class 'str'>
# []
#
# abdomen <class 'str'>
# ['venter', 'abdominal_cavity']
#
# abdominal <class 'str'>
# ['ab', 'abdominal_muscle']
#
# abduct <class 'str'>
# ['nobble']
#
# abduction <class 'str'>
# []
#
# abide <class 'str'>
# ['stick_out', 'put_up']
#
# abiding <class 'str'>
# ['stick_out', 'put_up', 'imperishable']
#
# ability <class 'str'>
# []
#
# abject <class 'str'>
# ['low-down', 'scummy', 'unhopeful']
#
# ablaze <class 'str'>
# ['aflame', 'reddened', 'aflare', 'inflamed', 'on_fire']
#
# able <class 'str'>
# ['able-bodied']
#
# abnormal <class 'str'>
# []
#
# abnormality <class 'str'>
# ['abnormalcy', 'mental_defectiveness', 'freakishness']
#
# abode <class 'str'>
# ['dwelling_house', 'put_up', 'habitation', 'stick_out', 'domicile']
#
# abolish <class 'str'>
# ['get_rid_of']
#
# abominable <class 'str'>
# ['execrable', 'detestable', 'odious']
#
# abomination <class 'str'>
# ['abhorrence', 'detestation', 'odium', 'execration']
#
# abort <class 'str'>
# []
#
# abortion <class 'str'>
# []
#
# abracadabra <class 'str'>
# []
#
# abrasive <class 'str'>
# ['abradant', 'abrasive_material']
#
# abreast <class 'str'>
# ['up_on', 'au_courant', 'au_fait']
#
# abrupt <class 'str'>
# ['disconnected', 'precipitous']
#
# abscess <class 'str'>
# []
#
# absence <class 'str'>
# ['absence_seizure']
#
# absent <class 'str'>
# ['missing', 'abstracted', 'scatty', 'lacking', 'absentminded', 'wanting']
#
# absinthe <class 'str'>
# ['old_man', 'absinth', "lad's_love", 'Artemisia_absinthium', 'common_wormwood']
#
# absolute <class 'str'>
# ['out-and-out', 'infrangible', 'downright', 'inviolable', 'right-down']
#
# absolution <class 'str'>
# ['remission_of_sin', 'remittal']
#
# absolve <class 'str'>
# ['shrive']
#
# absorb <class 'str'>
# ['suck_up', 'soak_up', 'engross', 'sop_up', 'engulf', 'take_up', 'immerse', 'take_over', 'take_in', 'imbibe']
#
# abstain <class 'str'>
# []
#
# abstinence <class 'str'>
# ['abstention']
#
# abstract <class 'str'>
# ['purloin', 'filch', 'synopsis', 'nonobjective', 'snarf', 'nobble', 'abstractionist', 'pilfer', 'abstraction', 'precis', 'nonfigurative']
#
# absurd <class 'str'>
# ['derisory', 'the_absurd', 'nonsensical']
#
# absurdity <class 'str'>
# ['absurdness', 'ridiculousness', 'fatuity', 'fatuousness']
#
# abundance <class 'str'>
# ['teemingness', 'copiousness']
#
# abundant <class 'str'>
# []
#
# abuse <class 'str'>
# ['blackguard', 'maltreatment', 'ill-treat', 'maltreat', 'ill-usage', 'revilement', 'vilification', 'mistreat', 'clapperclaw', 'contumely', 'ill-use', 'ill-treatment']
#
# abusive <class 'str'>
# ['scurrilous', 'opprobrious']
#
# abysmal <class 'str'>
# ['unfathomable', 'abyssal']
#
# abyss <class 'str'>
# ['abysm', 'abye', 'expiate', 'aby']
#
# academic <class 'str'>
# ['pedantic', 'academician', 'donnish', 'faculty_member']
#
# academy <class 'str'>
# ['honorary_society']
#
# accelerant <class 'str'>
# []
#
# accelerate <class 'str'>
# ['speed_up', 'quicken']
#
# accelerated <class 'str'>
# ['speed_up', 'quicken']
#
# acceleration <class 'str'>
# ['quickening', 'speedup']
#
# accelerator <class 'str'>
# ['atom_smasher', 'throttle_valve', 'particle_accelerator', 'gas_pedal', 'accelerator_pedal']
#
# accent <class 'str'>
# ['accent_mark', 'idiom', 'accentuate', 'speech_pattern', 'punctuate', 'emphasise']
#
# accept <class 'str'>
# ['go_for', 'live_with', 'take_on', 'take_over']
#
# acceptable <class 'str'>
# []
#
# acceptance <class 'str'>
# ['espousal', 'acceptation', "banker's_acceptance", 'toleration', 'sufferance']
#
# access <class 'str'>
# ['memory_access', 'get_at', 'access_code', 'accession']
#
# accessible <class 'str'>
# ['approachable']
#
# accessory <class 'str'>
# ['accessary', 'accoutrement', 'adjuvant', 'appurtenant', 'adjunct', 'accouterment', 'ancillary', 'appurtenance', 'add-on']
#
# accident <class 'str'>
# ['fortuity', 'chance_event']
#
# accidental <class 'str'>
# ['inadvertent']
#
# acclaim <class 'str'>
# ['eclat', 'acclamation', 'plaudit', 'plaudits', 'spat']
#
# accommodate <class 'str'>
# ['conciliate']
#
# accommodation <class 'str'>
# ['fitting']
#
# accompany <class 'str'>
# ['go_with', 'play_along', 'come_with', 'attach_to', 'keep_company']
#
# accomplice <class 'str'>
# []
#
# accomplish <class 'str'>
# ['carry_out', 'fulfil', 'carry_through']
#
# accomplishment <class 'str'>
# ['attainment', 'acquirement']
#
# accord <class 'str'>
# ['harmonize', 'conformity', 'concord', 'allot', 'fit_in', 'harmonise', 'accordance', 'grant']
#
# accordion <class 'str'>
# ['piano_accordion', 'squeeze_box']
#
# account <class 'str'>
# ['business_relationship', 'news_report', 'answer_for', 'write_up', 'account_statement']
#
# accountability <class 'str'>
# ['answerableness', 'answerability']
#
# accountable <class 'str'>
# []
#
# accountant <class 'str'>
# ['comptroller']
#
# accounting <class 'str'>
# ['answer_for', 'accounting_system', 'method_of_accounting', 'accountancy', 'account_statement']
#
# accumulate <class 'str'>
# ['pile_up', 'cumulate', 'amass', 'roll_up']
#
# accuracy <class 'str'>
# []
#
# accurate <class 'str'>
# []
#
# accursed <class 'str'>
# ['comminate', 'anathemize', 'execrate', 'accurst', 'anathematize', 'maledict', 'accurse', 'anathematise', 'anathemise']
#
# accusation <class 'str'>
# ['accusal']
#
# accuse <class 'str'>
# ['criminate']
#
# ace <class 'str'>
# ['top-notch', 'ACE', 'A-one', 'tiptop', 'first-rate', 'sweep_through', 'topnotch', 'breeze_through', 'maven', 'I', 'sail_through', 'whizz', 'angiotensin_converting_enzyme', 'angiotensin-converting_enzyme', 'pass_with_flying_colors', 'tops', 'mavin', '1', 'Allied_Command_Europe']
#
# acetylene <class 'str'>
# ['alkyne', 'ethyne']
#
# ache <class 'str'>
# ['languish', 'aching']
#
# achieve <class 'str'>
# []
#
# achievement <class 'str'>
# []
#
# achy <class 'str'>
# ['aching']
#
# acid <class 'str'>
# ['sulphurous', 'Zen', 'acidulous', 'sulfurous', 'acidulent', 'acrid', 'battery-acid', 'virulent', 'Lucy_in_the_sky_with_diamonds', 'Elvis', 'loony_toons', 'acerbic', 'acerb', 'caustic', 'back_breaker', 'window_pane', 'vitriolic', 'acidic']
#
# acknowledge <class 'str'>
# ['recognise']
#
# acknowledgement <class 'str'>
# ['acknowledgment']
#
# acne <class 'str'>
# []
#
# acorn <class 'str'>
# []
#
# acoustic <class 'str'>
# ['acoustical']
#
# acoustics <class 'str'>
# []
#
# acquaintance <class 'str'>
# ['conversancy', 'acquaintanceship', 'conversance']
#
# acquire <class 'str'>
# ['larn', 'take_on']
#
# acquisition <class 'str'>
# ['acquirement', 'attainment', 'learning']
#
# acquit <class 'str'>
# ['exculpate', 'comport', 'assoil']
#
# acquittal <class 'str'>
# []
#
# acre <class 'str'>
# ['Akko', 'Akka', 'Acre', 'Accho']
#
# acreage <class 'str'>
# ['land_area']
#
# acrobat <class 'str'>
# []
#
# acrylic <class 'str'>
# ['acrylic_paint', 'acrylate_resin', 'acrylic_resin', 'acrylic_fiber']
#
# act <class 'str'>
# ['dissemble', 'enactment', 'human_action', 'playact', 'act_as', 'human_activity', 'roleplay']
#
# action <class 'str'>
# ['natural_action', 'carry_through', 'litigate', 'natural_process', 'activeness', 'action_mechanism', 'carry_out', 'action_at_law', 'legal_action', 'military_action', 'fulfil']
#
# action figure <class 'str'>
# []
#
# activate <class 'str'>
# ['touch_off', 'spark_off', 'trigger_off', 'actuate', 'aerate', 'set_off']
#
# activation <class 'str'>
# ['energizing', 'activating']
#
# active <class 'str'>
# ['active_agent', 'combat-ready', 'fighting', 'active_voice', 'participating']
#
# activist <class 'str'>
# ['activistic']
#
# activity <class 'str'>
# ['natural_action', 'natural_process', 'activeness', 'bodily_function', 'bodily_process', 'body_process']
#
# actor <class 'str'>
# ['thespian', 'histrion', 'role_player']
#
# actress <class 'str'>
# []
#
# actual <class 'str'>
# ['existent']
#
# actuality <class 'str'>
# []
#
# acupuncture <class 'str'>
# ['stylostixis']
#
# acute <class 'str'>
# ['knifelike', 'acute_accent', 'penetrating', 'ague', 'piercing', 'incisive', 'penetrative', 'needlelike', 'acuate']
#
# ad <class 'str'>
# ['A.D.', 'AD', 'advertizing', 'advertizement', 'advert', 'anno_Domini']
#
# adage <class 'str'>
# ['byword']
#
# adamant <class 'str'>
# ['adamantine', 'intransigent', 'inexorable']
#
# adapt <class 'str'>
# []
#
# adaptation <class 'str'>
# ['adaption']
#
# add <class 'str'>
# ['ADD', 'ADHD', 'MBD', 'add_together', 'tote_up', 'minimal_brain_dysfunction', 'sum_up', 'add_up', 'summate', 'tot_up', 'attention_deficit_disorder', 'minimal_brain_damage', 'append', 'attention_deficit_hyperactivity_disorder', 'hyperkinetic_syndrome']
#
# adder <class 'str'>
# ['common_viper', 'Vipera_berus']
#
# addict <class 'str'>
# []
#
# addicted <class 'str'>
# []
#
# addiction <class 'str'>
# ['dependance', 'habituation']
#
# addictive <class 'str'>
# ['habit-forming']
#
# additional <class 'str'>
# []
#
# address <class 'str'>
# ['computer_address', 'accost', 'name_and_address', 'turn_to', 'savoir-faire', 'come_up_to']
#
# adept <class 'str'>
# ['practiced', 'maven', 'skilful', 'whizz', 'mavin']
#
# adequate <class 'str'>
# ['enough', 'passable', 'fair_to_middling']
#
# adhere <class 'str'>
# ['cleave', 'stand_by', 'stick_to', 'stick_by', 'hold_fast', 'bond', 'cohere']
#
# adhesive <class 'str'>
# ['adhesive_agent', 'adhesive_material']
#
# Adidas <class 'str'>
# []
#
# adjacent <class 'str'>
# ['next', 'side_by_side', 'conterminous', 'contiguous']
#
# adjective <class 'str'>
# ['adjectival']
#
# adjoining <class 'str'>
# ['abut', 'butt_against', 'adjoin', 'butt_on', 'march']
#
# adjourn <class 'str'>
# ['break_up']
#
# adjust <class 'str'>
# ['line_up', 'aline']
#
# adjuster <class 'str'>
# ['claims_adjustor', 'claim_agent', 'adjustor', 'claims_adjuster']
#
# adjustment <class 'str'>
# ['fitting', 'readjustment', 'adaption']
#
# admin <class 'str'>
# []
#
# administer <class 'str'>
# ['lot', 'deal_out', 'parcel_out', 'administrate', 'allot', 'dish_out', 'dole_out', 'mete_out', 'shell_out']
#
# administration <class 'str'>
# ['establishment', 'judicature', 'giving_medication', 'governing_body', 'government_activity', 'organisation', 'presidential_term', 'governing', 'governance']
#
# administrative <class 'str'>
# []
#
# administrator <class 'str'>
# ['decision_maker']
#
# admirable <class 'str'>
# []
#
# admiral <class 'str'>
# ['full_admiral']
#
# admiralty <class 'str'>
# []
#
# admiration <class 'str'>
# ['wonderment']
#
# admire <class 'str'>
# ['look_up_to']
#
# admired <class 'str'>
# ['look_up_to']
#
# admirer <class 'str'>
# ['protagonist', 'adorer']
#
# admissible <class 'str'>
# []
#
# admission <class 'str'>
# ['admission_fee', 'price_of_admission', 'entrance_money', 'admission_price', 'accession', 'admission_charge', 'entrance_fee']
#
# admit <class 'str'>
# ['intromit', 'let_in', 'take_on', 'allow_in']
#
# admittance <class 'str'>
# ['accession']
#
# ado <class 'str'>
# []
#
# adobe <class 'str'>
# ['adobe_brick']
#
# adolescence <class 'str'>
# []
#
# adolescent <class 'str'>
# ['stripling', 'puerile', 'jejune', 'teenaged']
#
# adopt <class 'str'>
# ['dramatize', 'take_on', 'take_over', 'take_up', 'dramatise', 'sweep_up', 'take_in', 'espouse']
#
# adoption <class 'str'>
# ['acceptation', 'espousal', 'borrowing']
#
# adoptive <class 'str'>
# ['adopted']
#
# adorable <class 'str'>
# []
#
# adoration <class 'str'>
# ['idolisation', 'idolization', 'latria']
#
# adore <class 'str'>
# []
#
# adoring <class 'str'>
# ['worshipful', 'doting']
#
# adrenalin <class 'str'>
# ['Adrenalin', 'epinephrine', 'epinephrin']
#
# adrenaline <class 'str'>
# ['Adrenalin', 'epinephrine', 'epinephrin']
#
# adrift <class 'str'>
# ['undirected', 'aimless', 'planless', 'rudderless', 'directionless']
#
# adult <class 'str'>
# ['fully_grown', 'grown', 'full-grown']
#
# adulterer <class 'str'>
# ['fornicator', 'fully_grown', 'grown', 'full-grown']
#
# adultery <class 'str'>
# ['criminal_conversation']
#
# adulthood <class 'str'>
# []
#
# advance <class 'str'>
# ['get_along', 'go_on', 'feeler', 'make_headway', 'set_ahead', 'kick_upstairs', 'cash_advance', 'supercharge', 'shape_up', 'in_advance', 'get_ahead', 'throw_out', 'forward_motion', 'onward_motion', 'pass_on', 'further', 'gain_ground', 'betterment', 'come_along', 'come_on', 'bring_forward', 'move_on', 'pull_ahead', 'march_on', 'get_on', 'beforehand']
#
# advanced <class 'str'>
# ['get_along', 'go_on', 'make_headway', 'set_ahead', 'kick_upstairs', 'supercharge', 'shape_up', 'in_advance', 'get_ahead', 'throw_out', 'pass_on', 'further', 'gain_ground', 'come_along', 'forward-looking', 'come_on', 'bring_forward', 'move_on', 'pull_ahead', 'march_on', 'get_on']
#
# advancement <class 'str'>
# ['forward_motion', 'onward_motion', 'furtherance']
#
# advantage <class 'str'>
# []
#
# advantageous <class 'str'>
# []
#
# adventure <class 'str'>
# ['dangerous_undertaking', 'risky_venture', 'take_chances', 'take_a_chance', 'escapade', 'run_a_risk']
#
# adventurer <class 'str'>
# ['venturer']
#
# adventurous <class 'str'>
# ['adventuresome']
#
# adversary <class 'str'>
# ['resister', 'antagonist', 'opposer']
#
# adverse <class 'str'>
# ['untoward', 'inauspicious']
#
# adversity <class 'str'>
# ['hard_knocks']
#
# advertise <class 'str'>
# ['advertize', 'publicise', 'publicize']
#
# advertisement <class 'str'>
# ['advert', 'advertizing', 'advertizement']
#
# advertising <class 'str'>
# ['advertize', 'advertizing', 'advertizement', 'advert', 'publicise', 'publicize', 'publicizing']
#
# advice <class 'str'>
# []
#
# advisable <class 'str'>
# []
#
# advise <class 'str'>
# ['rede', 'give_notice', 'apprize', 'apprise', 'send_word']
#
# advisement <class 'str'>
# ['weighing']
#
# adviser <class 'str'>
# []
#
# advisor <class 'str'>
# []
#
# advisory <class 'str'>
# ['consultative', 'consultatory', 'consultive']
#
# advocate <class 'str'>
# ['advocator', 'exponent', 'pleader', 'proponent', 'counsellor', 'counselor-at-law']
#
# aerial <class 'str'>
# ['aeriform', 'transmitting_aerial', 'airy', 'ethereal', 'forward_pass', 'aery']
#
# aerobics <class 'str'>
# ['aerobic_exercise']
#
# aerodynamic <class 'str'>
# ['flowing', 'streamlined']
#
# aerospace <class 'str'>
# []
#
# aesthetic <class 'str'>
# ['esthetic', 'esthetical', 'aesthetical']
#
# affair <class 'str'>
# ['social_occasion', 'social_function', 'affaire']
#
# affect <class 'str'>
# ['touch_on', 'dissemble', 'bear_upon', 'bear_on']
#
# affection <class 'str'>
# ['warmness', 'affectionateness', 'philia', 'warmheartedness']
#
# affectionate <class 'str'>
# ['lovesome']
#
# affidavit <class 'str'>
# []
#
# affiliation <class 'str'>
# ['tie-up']
#
# affinity <class 'str'>
# ['phylogenetic_relation', 'chemical_attraction']
#
# affirmation <class 'str'>
# ['avouchment', 'assertion', 'avowal']
#
# affirmative <class 'str'>
# ['affirmatory', 'approbatory', 'approving', 'approbative', 'plausive']
#
# affliction <class 'str'>
# []
#
# afford <class 'str'>
# []
#
# affordable <class 'str'>
# ['low-cost', 'low-priced']
#
# affront <class 'str'>
# ['diss']
#
# afire <class 'str'>
# ['aflame', 'on_fire', 'aflare']
#
# afloat <class 'str'>
# ['inundated', 'awash', 'flooded', 'undirected', 'aimless', 'planless', 'rudderless', 'overflowing', 'directionless']
#
# aforementioned <class 'str'>
# ['aforesaid', 'said']
#
# afraid <class 'str'>
# []
#
# african <class 'str'>
# ['African']
#
# afterlife <class 'str'>
# ['hereafter']
#
# aftermath <class 'str'>
# ['backwash']
#
# afternoon <class 'str'>
# ['good_afternoon']
#
# aftershave <class 'str'>
# []
#
# age <class 'str'>
# ['historic_period', 'eld', 'geezerhood', 'senesce', 'years', 'get_on', 'old_age', 'long_time', 'maturate']
#
# agency <class 'str'>
# ['federal_agency', 'delegacy', 'means', 'government_agency']
#
# agenda <class 'str'>
# ['agendum', 'order_of_business']
#
# agent <class 'str'>
# ['agentive_role', 'federal_agent']
#
# aggravate <class 'str'>
# ['exacerbate', 'worsen', 'exasperate']
#
# aggravation <class 'str'>
# ['exacerbation', 'exasperation']
#
# aggression <class 'str'>
# []
#
# aggressive <class 'str'>
# ['strong-growing', 'fast-growing']
#
# aggressiveness <class 'str'>
# ['pugnacity', 'belligerence']
#
# aggressor <class 'str'>
# ['assaulter']
#
# agile <class 'str'>
# ['spry']
#
# agility <class 'str'>
# ['nimbleness', 'lightsomeness', 'legerity']
#
# aging <class 'str'>
# ['senesce', 'ageing', 'get_on', 'ripening', 'senescence', 'maturate', 'senescent']
#
# agitate <class 'str'>
# ['vex', 'charge_up', 'shake_up', 'stir_up', 'raise_up', 'turn_on', 'foment', 'commove']
#
# agitation <class 'str'>
# ['fermentation', 'upheaval', 'tempestuousness', 'hullabaloo', 'ferment']
#
# aglow <class 'str'>
# ['lucent', 'lambent']
#
# agonizing <class 'str'>
# ['torturesome', 'torturing', 'agonise', 'torturous', 'agonize', 'agonising']
#
# agony <class 'str'>
# ['suffering', 'excruciation']
#
# agree <class 'str'>
# ['harmonize', 'concord', 'fit_in', 'harmonise', 'gibe', 'jibe']
#
# agreeable <class 'str'>
# ['accordant', 'conformable', 'concordant', 'consonant']
#
# agreement <class 'str'>
# ['concord']
#
# agricultural <class 'str'>
# ['agrarian']
#
# agriculture <class 'str'>
# ['factory_farm', 'Agriculture', 'Agriculture_Department', 'agribusiness', 'husbandry', 'USDA', 'Department_of_Agriculture']
#
# ahoy <class 'str'>
# []
#
# aid <class 'str'>
# ['tending', 'financial_aid', 'economic_aid']
#
# aide <class 'str'>
# ['adjutant', 'aide-de-camp']
#
# aids <class 'str'>
# ['tending', 'acquired_immune_deficiency_syndrome', 'financial_aid', 'economic_aid']
#
# AIDS <class 'str'>
# ['tending', 'acquired_immune_deficiency_syndrome', 'financial_aid', 'economic_aid']
#
# ailing <class 'str'>
# ['under_the_weather', 'ail', 'poorly', 'peaked']
#
# ailment <class 'str'>
# ['ill']
#
# aim <class 'str'>
# ['draw_a_bead_on', 'bearing', 'purport', 'heading', 'take_aim', 'shoot_for']
#
# air <class 'str'>
# ['melodic_phrase', 'air_travel', 'airwave', 'air_out', 'gentle_wind', 'publicise', 'melodic_line', 'ventilate', 'publicize', 'aerate']
#
# airbag <class 'str'>
# []
#
# airborne <class 'str'>
# []
#
# aircraft <class 'str'>
# []
#
# aircraft carrier <class 'str'>
# []
#
# airfield <class 'str'>
# ['flying_field', 'landing_field']
#
# airhead <class 'str'>
# []
#
# airline <class 'str'>
# ['airline_business', 'air_hose']
#
# airliner <class 'str'>
# []
#
# airlock <class 'str'>
# ['air_lock']
#
# airplane <class 'str'>
# ['aeroplane']
#
# airport <class 'str'>
# ['airdrome', 'drome', 'aerodrome']
#
# airship <class 'str'>
# ['dirigible']
#
# airspace <class 'str'>
# ['air_space']
#
# airspeed <class 'str'>
# []
#
# airstrip <class 'str'>
# ['flight_strip', 'landing_strip']
#
# airtight <class 'str'>
# ['air-tight', 'gas-tight']
#
# airway <class 'str'>
# ['respiratory_tract', 'skyway', 'air_passage', 'air_duct', 'airline_business', 'flight_path', 'air_lane']
#
# aisle <class 'str'>
# []
#
# ajar <class 'str'>
# []
#
# aka <class 'str'>
# []
#
# alabaster <class 'str'>
# ['onyx_marble', 'alabastrine', 'Mexican_onyx', 'oriental_alabaster']
#
# alarm <class 'str'>
# ['warning_device', 'horrify', 'alarm_system', 'alarum', 'consternation', 'appal', 'alarm_clock', 'warning_signal', 'appall']
#
# alarm clock <class 'str'>
# []
#
# alarming <class 'str'>
# ['appal', 'appall', 'horrify']
#
# albatross <class 'str'>
# ['mollymawk']
#
# albino <class 'str'>
# []
#
# album <class 'str'>
# ['record_album']
#
# alcohol <class 'str'>
# ['inebriant', 'intoxicant', 'alcoholic_beverage', 'alcoholic_drink']
#
# alcoholic <class 'str'>
# ['dipsomaniac', 'soaker', 'souse', 'alcohol-dependent', 'boozer', 'alky']
#
# alcoholism <class 'str'>
# ['potomania', 'alcohol_addiction', 'inebriation', 'dipsomania']
#
# alcove <class 'str'>
# []
#
# alderman <class 'str'>
# []
#
# ale <class 'str'>
# []
#
# alert <class 'str'>
# ['rattling', 'qui_vive', 'alarum', 'zippy', 'watchful', 'warning_signal', 'alerting']
#
# alfalfa <class 'str'>
# ['Medicago_sativa', 'lucerne']
#
# algebra <class 'str'>
# []
#
# algorithm <class 'str'>
# ['algorithmic_program', 'algorithmic_rule']
#
# alias <class 'str'>
# ['also_known_as', 'false_name', 'a.k.a.', 'assumed_name']
#
# alibi <class 'str'>
# ['exculpation', 'self-justification']
#
# alien <class 'str'>
# ['extraterrestrial_being', 'noncitizen', 'disaffect', 'outlander', 'estrange']
#
# alienate <class 'str'>
# ['estrange', 'disaffect']
#
# alienation <class 'str'>
# ['disaffection', 'estrangement']
#
# alight <class 'str'>
# ['aflame', 'climb_down', 'on_fire', 'aflare']
#
# align <class 'str'>
# ['ordinate', 'line_up', 'aline']
#
# alignment <class 'str'>
# ['alinement']
#
# alimony <class 'str'>
# []
#
# alive <class 'str'>
# []
#
# allegation <class 'str'>
# ['allegement']
#
# alleged <class 'str'>
# ['so-called', 'allege', 'aver']
#
# allegiance <class 'str'>
# ['fealty']
#
# allegro <class 'str'>
# []
#
# allergic <class 'str'>
# ['supersensitive', 'supersensitised', 'sensitised', 'sensitized', 'supersensitized', 'hypersensitized', 'hypersensitised', 'hypersensitive']
#
# allergy <class 'str'>
# ['allergic_reaction']
#
# alleviate <class 'str'>
# ['assuage', 'palliate']
#
# alley <class 'str'>
# ['bowling_alley', 'skittle_alley', 'back_street']
#
# alleyway <class 'str'>
# ['back_street']
#
# alliance <class 'str'>
# ['confederation', 'bond', 'alinement']
#
# allied <class 'str'>
# ['confederative', 'Allied']
#
# alligator <class 'str'>
# []
#
# allow <class 'str'>
# ['take_into_account', 'set_aside', 'earmark', 'allow_for', 'give_up', 'grant']
#
# allowance <class 'str'>
# ['valuation_reserve', 'allowance_account', 'valuation_account']
#
# alloy <class 'str'>
# ['debase', 'admixture']
#
# allure <class 'str'>
# ['allurement', 'temptingness']
#
# alluring <class 'str'>
# ['enticing', 'beguiling']
#
# ally <class 'str'>
# []
#
# almanac <class 'str'>
# ["farmer's_calendar"]
#
# almighty <class 'str'>
# ['all-powerful', 'Lord', 'omnipotent', 'Creator', 'God_Almighty', 'Maker', 'Jehovah', 'Godhead', 'Almighty', 'Divine']
#
# almond <class 'str'>
# ['Amygdalus_communis', 'Prunus_amygdalus', 'Prunus_dulcis', 'sweet_almond']
#
# aloha <class 'str'>
# ['ciao']
#
# alone <class 'str'>
# ['only', 'exclusively', 'unequalled', 'solely', 'entirely', 'unequaled', 'unaccompanied']
#
# aloof <class 'str'>
# ['upstage']
#
# alpha <class 'str'>
# []
#
# alphabet <class 'str'>
# ['first_principle', "ABC's", 'first_rudiment', 'ABC', 'rudiment', 'ABCs']
#
# alphabetical <class 'str'>
# ['alphabetic']
#
# alpine <class 'str'>
# ['Alpine']
#
# altar <class 'str'>
# ["Lord's_table", 'communion_table']
#
# altar boy <class 'str'>
# []
#
# alter <class 'str'>
# ['spay', 'interpolate', 'falsify']
#
# alteration <class 'str'>
# []
#
# altercation <class 'str'>
# ['fracas', 'affray']
#
# alternate <class 'str'>
# ['flip-flop', 'interchange', 'take_turns']
#
# alternating <class 'str'>
# ['flip-flop', 'interchange', 'take_turns']
#
# alternative <class 'str'>
# []
#
# altimeter <class 'str'>
# []
#
# altitude <class 'str'>
# ['EL', 'ALT']
#
# aluminum <class 'str'>
# ['atomic_number_13', 'aluminium', 'Al']
#
# alumnus <class 'str'>
# ['alumna', 'alum']
#
# alzheimers <class 'str'>
# ["Alzheimer's_disease", "Alzheimer's", 'Alzheimers']
#
# amaretto <class 'str'>
# []
#
# amateur <class 'str'>
# ['unskilled', 'amateurish', 'inexpert']
#
# amaze <class 'str'>
# ['nonplus', 'perplex', 'stupefy', 'mystify', 'vex', 'bewilder', 'dumbfound', 'flummox', 'baffle']
#
# amazed <class 'str'>
# ['nonplus', 'perplex', 'stupefy', 'mystify', 'vex', 'astounded', 'stunned', 'bewilder', 'dumbfound', 'flummox', 'astonied', 'baffle']
#
# amazement <class 'str'>
# ['astonishment']
#
# amazing <class 'str'>
# ['awe-inspiring', 'nonplus', 'perplex', 'stupefy', 'mystify', 'vex', 'bewilder', 'awing', 'dumbfound', 'flummox', 'baffle']
#
# ambassador <class 'str'>
# ['embassador']
#
# amber <class 'str'>
# ['brownish-yellow', 'yellow-brown']
#
# ambience <class 'str'>
# ['ambiance']
#
# ambient <class 'str'>
# []
#
# ambiguous <class 'str'>
# ['equivocal']
#
# ambition <class 'str'>
# ['ambitiousness']
#
# ambitious <class 'str'>
# ['challenging']
#
# ambrosia <class 'str'>
# ['beebread', 'bitterweed', 'ragweed']
#
# ambulance <class 'str'>
# []
#
# ambush <class 'str'>
# ['ambuscade', 'lying_in_wait', 'bushwhack', 'lie_in_wait', 'waylay', 'scupper', 'still-hunt']
#
# amend <class 'str'>
# ['remediate', 'ameliorate', 'better', 'meliorate']
#
# amendment <class 'str'>
# []
#
# amends <class 'str'>
# ['ameliorate', 'remediate', 'indemnification', 'indemnity', 'meliorate', 'reparation', 'damages', 'better', 'redress']
#
# amiable <class 'str'>
# ['genial', 'good-humored', 'good-humoured', 'affable']
#
# amino <class 'str'>
# ['amino_group', 'aminic']
#
# ammo <class 'str'>
# []
#
# ammonia <class 'str'>
# ['ammonium_hydroxide', 'ammonia_water']
#
# ammonium <class 'str'>
# ['ammonium_ion']
#
# ammunition <class 'str'>
# []
#
# amnesia <class 'str'>
# ['memory_loss']
#
# amnesty <class 'str'>
# ['free_pardon']
#
# amorous <class 'str'>
# ['amative', 'amatory']
#
# amount <class 'str'>
# ['sum_of_money', 'add_up', 'amount_of_money']
#
# amour <class 'str'>
# ['affaire']
#
# amp <class 'str'>
# ['A', 'adenylic_acid', 'adenosine_monophosphate', 'ampere', 'AMP']
#
# amphibian <class 'str'>
# ['amphibious_vehicle', 'amphibious_aircraft']
#
# amphibious <class 'str'>
# []
#
# ample <class 'str'>
# ['plentiful', 'sizeable', 'plenteous', 'copious']
#
# amputate <class 'str'>
# ['cut_off']
#
# amputation <class 'str'>
# []
#
# amuck <class 'str'>
# ['amok', 'demoniacal', 'murderously', 'demoniac', 'possessed']
#
# amulet <class 'str'>
# []
#
# amuse <class 'str'>
# ['disport']
#
# amused <class 'str'>
# ['disport', 'diverted', 'entertained']
#
# amusement <class 'str'>
# []
#
# amusing <class 'str'>
# ['risible', 'amusive', 'diverting', 'disport', 'mirthful']
#
# anaconda <class 'str'>
# ['Eunectes_murinus']
#
# anagram <class 'str'>
# ['anagrammatize', 'anagrammatise']
#
# anal <class 'str'>
# ['anal_retentive']
#
# analogy <class 'str'>
# ['doctrine_of_analogy']
#
# analysis <class 'str'>
# ['analytic_thinking', 'depth_psychology']
#
# analyst <class 'str'>
# []
#
# analytical <class 'str'>
# ['analytic']
#
# analyze <class 'str'>
# ['break_down', 'take_apart', 'psychoanalyze', 'psychoanalyse', 'analyse']
#
# analyzer <class 'str'>
# ['analyser']
#
# anaphylactic <class 'str'>
# []
#
# anarchist <class 'str'>
# ['nihilist', 'syndicalist']
#
# anarchy <class 'str'>
# []
#
# anatomy <class 'str'>
# ['material_body', 'general_anatomy', 'soma', 'physical_body', 'bod', 'human_body']
#
# ancestor <class 'str'>
# ['antecedent', 'ascendent']
#
# ancestral <class 'str'>
# ['transmissible', 'patrimonial']
#
# ancestry <class 'str'>
# ['line_of_descent', 'filiation', 'blood_line', 'stemma', 'parentage', 'derivation']
#
# anchor <class 'str'>
# ['keystone', 'anchorman', 'drop_anchor', 'linchpin', 'mainstay', 'lynchpin', 'anchorperson', 'ground_tackle', 'cast_anchor']
#
# anchorage <class 'str'>
# ['Anchorage', 'anchorage_ground']
#
# ancient <class 'str'>
# ['antediluvian']
#
# android <class 'str'>
# ['mechanical_man']
#
# anecdote <class 'str'>
# []
#
# anemia <class 'str'>
# ['anaemia', 'genus_Anemia', 'Anemia']
#
# anemic <class 'str'>
# ['anaemic']
#
# anesthesia <class 'str'>
# ['anaesthesia']
#
# anesthesiologist <class 'str'>
# ['anesthetist', 'anaesthetist']
#
# anesthetic <class 'str'>
# ['anesthetic_agent', 'anaesthetic', 'anaesthetic_agent']
#
# aneurysm <class 'str'>
# ['aneurism']
#
# angel <class 'str'>
# ['Angel_Falls', 'Angel', 'holy_man', 'holy_person']
#
# angelic <class 'str'>
# ['saintlike', 'beatific', 'angelical', 'cherubic', 'saintly', 'seraphic']
#
# anger <class 'str'>
# ['ira', 'see_red', 'ire', 'choler', 'angriness']
#
# angina <class 'str'>
# ['angina_pectoris']
#
# angiogram <class 'str'>
# []
#
# angle <class 'str'>
# ['Angle']
#
# angora <class 'str'>
# ['Turkish_capital', 'Angora_rabbit', 'capital_of_Turkey', 'Angora_cat', 'Angora_goat', 'Ankara', 'Angora']
#
# angry <class 'str'>
# ['tempestuous']
#
# angst <class 'str'>
# []
#
# anguish <class 'str'>
# []
#
# anguished <class 'str'>
# ['tormented', 'tortured']
#
# animal <class 'str'>
# ['fleshly', 'animate_being']
#
# animated <class 'str'>
# ['reanimate', 'enliven', 'renovate', 'animise', 'vivify', 'animize', 'liven_up', 'animate', 'invigorate', 'revivify', 'quicken', 'exalt']
#
# animation <class 'str'>
# ['brio', 'living', 'spiritedness', 'liveliness', 'aliveness', 'vivification', 'invigoration']
#
# animosity <class 'str'>
# ['animus', 'bad_blood']
#
# ankle <class 'str'>
# ['ankle_joint', 'articulatio_talocruralis', 'mortise_joint']
#
# anklet <class 'str'>
# ['bobbysocks', 'ankle_bracelet', 'anklets', 'bobbysock']
#
# annals <class 'str'>
# ['chronological_record']
#
# annex <class 'str'>
# ['annexe']
#
# annihilate <class 'str'>
# ['decimate', 'wipe_out', 'carry_off']
#
# annihilation <class 'str'>
# ['disintegration', 'obliteration']
#
# anniversary <class 'str'>
# ['day_of_remembrance']
#
# announce <class 'str'>
# ['harbinger', 'annunciate', 'foretell', 'denote']
#
# announcement <class 'str'>
# ['promulgation', 'annunciation']
#
# announcer <class 'str'>
# []
#
# annoy <class 'str'>
# ['get_at', 'vex', 'nettle', 'chafe', 'get_to', 'rile', 'nark']
#
# annoyance <class 'str'>
# ['pain_in_the_ass', 'vexation', 'aggravator', 'botheration', 'chafe', 'infliction', 'pain_in_the_neck']
#
# annoyed <class 'str'>
# ['nettled', 'get_at', 'miffed', 'vex', 'nettle', 'stung', 'pestered', 'riled', 'roiled', 'chafe', 'pissed_off', 'harried', 'steamed', 'rile', 'get_to', 'harassed', 'pissed', 'nark', 'irritated', 'vexed']
#
# annoying <class 'str'>
# ['plaguy', 'teasing', 'vexation', 'pestering', 'get_at', 'galling', 'vex', 'nettle', 'vexatious', 'plaguey', 'nettlesome', 'pestiferous', 'chafe', 'vexing', 'bothersome', 'rile', 'get_to', 'nark']
#
# annual <class 'str'>
# ['one-year']
#
# annul <class 'str'>
# ['quash', 'countermand', 'overturn', 'nullify', 'invalidate', 'repeal']
#
# annulment <class 'str'>
# ['repeal', 'invalidation', 'revocation', 'abrogation']
#
# anointed <class 'str'>
# ['inunct', 'anoint', 'embrocate', 'anele']
#
# anomaly <class 'str'>
# ['anomalousness', 'unusual_person']
#
# anonymity <class 'str'>
# ['namelessness']
#
# anonymous <class 'str'>
# ['anon.']
#
# anorexic <class 'str'>
# ['anorectic']
#
# answer <class 'str'>
# []
#
# ant <class 'str'>
# ['emmet', 'pismire']
#
# antagonistic <class 'str'>
# ['antipathetical', 'antipathetic']
#
# antagonize <class 'str'>
# ['antagonise']
#
# antelope <class 'str'>
# []
#
# antenna <class 'str'>
# ['transmitting_aerial', 'feeler']
#
# anterior <class 'str'>
# ['front_tooth']
#
# anthem <class 'str'>
# []
#
# anthill <class 'str'>
# ['formicary']
#
# anthrax <class 'str'>
# ['splenic_fever']
#
# anthropological <class 'str'>
# []
#
# anthropologist <class 'str'>
# []
#
# anthropology <class 'str'>
# []
#
# anti <class 'str'>
# []
#
# antiaircraft <class 'str'>
# ['antiaircraft_gun', 'ack-ack_gun', 'pom-pom', 'ack-ack', 'flack']
#
# antibiotic <class 'str'>
# ['antibiotic_drug']
#
# antibiotics <class 'str'>
# ['antibiotic_drug']
#
# antichrist <class 'str'>
# ['Antichrist']
#
# anticipate <class 'str'>
# ['look_for', 'look_to', 'foretell', 'previse', 'prognosticate', 'forestall', 'foreknow', 'forebode']
#
# anticipation <class 'str'>
# ['prevision']
#
# antics <class 'str'>
# ['put-on', 'antic', 'clown_around']
#
# antidote <class 'str'>
# ['counterpoison']
#
# antigravity <class 'str'>
# []
#
# antiquated <class 'str'>
# ['antediluvian', 'antiquate']
#
# antique <class 'str'>
# ['outmoded', 'passe', 'gaffer', 'old-timer', 'passee', 'demode', 'old-fashioned', 'old-hat', 'antiquate', 'old_geezer', 'oldtimer', 'age-old']
#
# antiques <class 'str'>
# ['gaffer', 'old-timer', 'antiquate', 'old_geezer', 'oldtimer']
#
# antiseptic <class 'str'>
# []
#
# antisocial <class 'str'>
# ['asocial']
#
# antsy <class 'str'>
# ['fretful', 'fidgety']
#
# anus <class 'str'>
# []
#
# anvil <class 'str'>
# ['incus']
#
# anxiety <class 'str'>
# ['anxiousness']
#
# anxious <class 'str'>
# ['unquiet', 'dying']
#
# anytime <class 'str'>
# []
#
# aorta <class 'str'>
# []
#
# aortic <class 'str'>
# ['aortal']
#
# apache <class 'str'>
# ['Apache']
#
# apartment <class 'str'>
# []
#
# apartments <class 'str'>
# []
#
# apathy <class 'str'>
# ['spiritlessness', 'numbness']
#
# ape <class 'str'>
# ['aper', 'anthropoid', 'imitator', 'caricature', 'emulator']
#
# apex <class 'str'>
# ['acme', 'solar_apex', 'vertex', "apex_of_the_sun's_way"]
#
# aphrodisiac <class 'str'>
# ['aphrodisiacal']
#
# apocalypse <class 'str'>
# ['Revelation', 'Book_of_Revelation', 'Revelation_of_Saint_John_the_Divine', 'Apocalypse']
#
# apologetic <class 'str'>
# ['excusatory']
#
# apologize <class 'str'>
# ['rationalise', 'apologise']
#
# apology <class 'str'>
# ['apologia']
#
# apostle <class 'str'>
# ['Apostelic_Father', 'Apostle']
#
# apothecary <class 'str'>
# ['pill_roller', 'pill_pusher']
#
# appalled <class 'str'>
# ['scandalise', 'horrify', 'dismayed', 'scandalize', 'appal', 'shocked', 'appall', 'aghast']
#
# appalling <class 'str'>
# ['scandalise', 'dismaying', 'horrify', 'scandalize', 'appal', 'appall']
#
# apparatus <class 'str'>
# []
#
# apparel <class 'str'>
# ['garb', 'enclothe', 'raiment', 'habilitate', 'fit_out', 'wearing_apparel', 'tog']
#
# apparent <class 'str'>
# ['seeming', 'ostensible']
#
# apparition <class 'str'>
# ['phantasm', 'phantasma', 'fantasm', 'specter', 'spectre']
#
# appeal <class 'str'>
# ['appealingness', 'entreaty', 'ingathering']
#
# appear <class 'str'>
# ['come_along', 'come_out']
#
# appearance <class 'str'>
# ['coming_into_court', 'visual_aspect', 'appearing']
#
# appease <class 'str'>
# ['placate', 'lenify', 'assuage', 'gruntle', 'propitiate', 'conciliate', 'mollify', 'quell']
#
# appendage <class 'str'>
# ['outgrowth']
#
# appendectomy <class 'str'>
# ['appendicectomy']
#
# appendicitis <class 'str'>
# []
#
# appendix <class 'str'>
# ['vermiform_process', 'vermiform_appendix', 'cecal_appendage']
#
# appetite <class 'str'>
# ['appetency', 'appetence']
#
# appetizer <class 'str'>
# ['appetiser']
#
# appetizing <class 'str'>
# ['appetising']
#
# applaud <class 'str'>
# ['spat']
#
# applause <class 'str'>
# ['clapping', 'hand_clapping']
#
# apple <class 'str'>
# ['orchard_apple_tree', 'Malus_pumila']
#
# apple juice <class 'str'>
# []
#
# applejack <class 'str'>
# []
#
# applesauce <class 'str'>
# ['folderol', 'wish-wash', 'apple_sauce', 'codswallop', 'trumpery']
#
# appliance <class 'str'>
# ['gismo', 'widget', 'contrivance']
#
# applicant <class 'str'>
# ['applier']
#
# application <class 'str'>
# ['practical_application', 'applications_programme', 'application_program', 'covering']
#
# apply <class 'str'>
# ['go_for', 'utilise', 'lend_oneself', 'put_on']
#
# appoint <class 'str'>
# []
#
# appointment <class 'str'>
# ['appointee', 'naming', 'fitting', 'designation']
#
# appraisal <class 'str'>
# []
#
# appreciate <class 'str'>
# ['revalue', 'take_account', 'apprize', 'apprise']
#
# appreciation <class 'str'>
# ['perceptiveness', 'discernment']
#
# appreciative <class 'str'>
# []
#
# apprehend <class 'str'>
# ['grok', 'get_the_picture', 'pick_up', 'quail_at']
#
# apprehension <class 'str'>
# ['apprehensiveness', 'misgiving', 'discernment', 'taking_into_custody']
#
# apprehensive <class 'str'>
# []
#
# apprentice <class 'str'>
# ['prentice']
#
# approach <class 'str'>
# ['come_on', 'come_near', 'draw_near', 'glide_slope', 'go_about', 'draw_close', 'glide_path', 'border_on', 'set_about', 'feeler', 'coming', 'plan_of_attack', 'go_up', 'approach_shot', 'approach_path', 'near', 'approaching']
#
# appropriate <class 'str'>
# ['set_aside', 'earmark']
#
# approval <class 'str'>
# ['approving', 'favorable_reception', 'favourable_reception']
#
# approve <class 'str'>
# ['O.K.', 'okay']
#
# approximate <class 'str'>
# ['near', 'come_close', 'close_together', 'approximative']
#
# apricot <class 'str'>
# ['apricot_tree', 'salmon_pink', 'yellowish_pink']
#
# apron <class 'str'>
# ['forestage', 'proscenium']
#
# apt <class 'str'>
# ['minded', 'tending', 'apposite', 'given', 'disposed']
#
# aptitude <class 'str'>
# []
#
# aqua <class 'str'>
# ['greenish_blue', 'peacock_blue', 'cobalt_blue']
#
# aquamarine <class 'str'>
# ['greenish_blue', 'peacock_blue', 'cobalt_blue']
#
# aquarium <class 'str'>
# ['marine_museum', 'fish_tank']
#
# aquatic <class 'str'>
# []
#
# arbitrary <class 'str'>
# []
#
# arbitration <class 'str'>
# ['arbitrement', 'arbitrament']
#
# arcade <class 'str'>
# ['colonnade']
#
# arcane <class 'str'>
# []
#
# arch <class 'str'>
# ['arc', 'implike', 'impish', 'prankish', 'archway', 'patronising', 'puckish', 'pixilated']
#
# archaeological <class 'str'>
# ['archaeologic', 'archeological', 'archeologic']
#
# archaeologist <class 'str'>
# ['archeologist']
#
# archaeology <class 'str'>
# ['archeology']
#
# archaic <class 'str'>
# ['antediluvian']
#
# archangel <class 'str'>
# ['Angelica_Archangelica', 'garden_angelica']
#
# archbishop <class 'str'>
# []
#
# archdiocese <class 'str'>
# []
#
# archduke <class 'str'>
# []
#
# archery <class 'str'>
# []
#
# architect <class 'str'>
# []
#
# architectural <class 'str'>
# []
#
# architecture <class 'str'>
# ['computer_architecture']
#
# archive <class 'str'>
# ['file_away']
#
# arctic <class 'str'>
# ['Arctic', 'gelid', 'gumshoe', 'north-polar', 'Arctic_Zone', 'galosh', 'North_Frigid_Zone', 'golosh', 'glacial']
#
# ardent <class 'str'>
# ['fervid', 'fervent', 'impassioned', 'perfervid']
#
# area <class 'str'>
# ['expanse', 'surface_area']
#
# arena <class 'str'>
# ['scene_of_action', 'sports_stadium']
#
# argue <class 'str'>
# []
#
# argument <class 'str'>
# ['logical_argument', 'disputation', 'parameter', 'disceptation', 'contestation', 'arguing', 'line_of_reasoning', 'argumentation', 'literary_argument']
#
# argumentative <class 'str'>
# []
#
# arise <class 'str'>
# ['come_up', 'stand_up', 'turn_out', 'uprise', 'rise_up', 'bob_up', 'move_up', 'get_up', 'spring_up', 'go_up', 'originate']
#
# aristocracy <class 'str'>
# []
#
# aristocrat <class 'str'>
# ['blue_blood', 'patrician']
#
# aristocratic <class 'str'>
# ['blue-blooded', 'aristocratical', 'patrician']
#
# arithmetic <class 'str'>
# ['arithmetical']
#
# ark <class 'str'>
# ['Ark_of_the_Covenant', 'Ark']
#
# arm <class 'str'>
# ['fortify', 'weapon_system', 'build_up', 'gird']
#
# armada <class 'str'>
# []
#
# armament <class 'str'>
# ['equipping', 'arming']
#
# armchair <class 'str'>
# []
#
# armed <class 'str'>
# ['fortify', 'build_up', 'gird']
#
# armor <class 'str'>
# ['armour']
#
# armored <class 'str'>
# ['panoplied', 'armour', 'armoured']
#
# armory <class 'str'>
# ['armoury']
#
# armpit <class 'str'>
# ['axilla', 'axillary_cavity', 'axillary_fossa']
#
# army <class 'str'>
# ['U._S._Army', 'regular_army', 'United_States_Army', 'Army', 'USA', 'ground_forces', 'US_Army']
#
# aroma <class 'str'>
# ['odour', 'olfactory_property']
#
# arouse <class 'str'>
# ['conjure_up', 'kindle', 'bring_up', 'perk_up', 'energise', 'enkindle', 'put_forward', 'call_forth', 'waken', 'come_alive', 'evoke', 'wind_up', 'turn_on', 'call_down', 'wake_up']
#
# aroused <class 'str'>
# ['put_forward', 'stimulated', 'turned_on', 'conjure_up', 'ruttish', 'perk_up', 'randy', 'call_down', 'aflame', 'wound_up', 'worked_up', 'bring_up', 'energise', 'enkindle', 'come_alive', 'stirred', 'wake_up', 'stirred_up', 'waken', 'evoke', 'wind_up', 'turn_on', 'call_forth', 'kindle']
#
# arraignment <class 'str'>
# []
#
# arrange <class 'str'>
# ['coiffe', 'fix_up', 'coif', 'set_up', 'coiffure']
#
# arrangement <class 'str'>
# ['arranging', 'musical_arrangement', 'organisation']
#
# array <class 'str'>
# ['regalia', 'set_out', 'lay_out', 'raiment']
#
# arrest <class 'str'>
# ['turn_back', 'stoppage', 'hold_back', 'pick_up', 'taking_into_custody']
#
# arrhythmia <class 'str'>
# ['cardiac_arrhythmia']
#
# arrival <class 'str'>
# ['comer', 'arriver', 'reaching']
#
# arrive <class 'str'>
# ['make_it', 'go_far', 'get_in']
#
# arrogance <class 'str'>
# ['high-handedness', 'hauteur', 'haughtiness', 'lordliness']
#
# arrogant <class 'str'>
# ['self-important', 'chesty']
#
# arrow <class 'str'>
# []
#
# arsenal <class 'str'>
# ['armoury']
#
# arsenic <class 'str'>
# ['As', 'arsenic_trioxide', 'white_arsenic', 'atomic_number_33', 'arsenous_anhydride', 'ratsbane', 'arsenous_oxide']
#
# arson <class 'str'>
# ['incendiarism', 'fire-raising']
#
# arsonist <class 'str'>
# ['firebug', 'incendiary']
#
# art <class 'str'>
# ['fine_art', 'artistic_production', 'artistic_creation', 'nontextual_matter']
#
# arterial <class 'str'>
# []
#
# artery <class 'str'>
# ['arterial_blood_vessel', 'arteria']
#
# arthritis <class 'str'>
# []
#
# artichoke <class 'str'>
# ['globe_artichoke', 'Cynara_scolymus', 'artichoke_plant']
#
# article <class 'str'>
# []
#
# articulate <class 'str'>
# ['give_voice', 'vocalize', 'enunciate', 'enounce', 'vocalise', 'articulated', 'sound_out']
#
# artifact <class 'str'>
# ['artefact']
#
# artificial <class 'str'>
# ['contrived', 'stilted']
#
# artillery <class 'str'>
# ['artillery_unit', 'heavy_weapon']
#
# artist <class 'str'>
# ['creative_person']
#
# artiste <class 'str'>
# []
#
# artistic <class 'str'>
# ['esthetic']
#
# artistry <class 'str'>
# []
#
# artwork <class 'str'>
# ['nontextual_matter']
#
# arty <class 'str'>
# []
#
# asbestos <class 'str'>
# []
#
# ascend <class 'str'>
# ['uprise', 'climb_up', 'move_up', 'go_up', 'come_up']
#
# ascendant <class 'str'>
# ['antecedent', 'ascendent', 'dominating', 'ascensive']
#
# ascending <class 'str'>
# ['uprise', 'ascent', 'climb_up', 'move_up', 'go_up', 'come_up']
#
# ascension <class 'str'>
# ['rising', 'Ascension_of_Christ', 'ascent', 'Ascension', 'Ascension_of_the_Lord', 'Ascension_Day']
#
# ascertain <class 'str'>
# ['find_out', 'see_to_it']
#
# ashamed <class 'str'>
# []
#
# ashtray <class 'str'>
# []
#
# asinine <class 'str'>
# ['fatuous', 'vacuous']
#
# ask <class 'str'>
# ['enquire', 'call_for', 'postulate', 'necessitate']
#
# asleep <class 'str'>
# ['at_peace', 'benumbed', 'departed', 'gone', 'at_rest']
#
# asparagus <class 'str'>
# ['Asparagus_officinales', 'edible_asparagus']
#
# aspect <class 'str'>
# ['panorama', 'facet', 'facial_expression', 'vista']
#
# aspen <class 'str'>
# []
#
# asphalt <class 'str'>
# ['mineral_pitch']
#
# asphyxia <class 'str'>
# []
#
# asphyxiation <class 'str'>
# []
#
# aspiration <class 'str'>
# ['breathing_in']
#
# aspire <class 'str'>
# ['draw_a_bead_on', 'shoot_for']
#
# aspirin <class 'str'>
# ['acetylsalicylic_acid', 'St._Joseph', 'Empirin', 'Bayer']
#
# aspiring <class 'str'>
# ['draw_a_bead_on', 'aspirant', 'shoot_for']
#
# ass <class 'str'>
# ['buns', 'nates', 'nooky', 'derriere', 'arse', 'American_Samoa', 'hind_end', 'keister', 'rear_end', 'piece_of_ass', 'roll_in_the_hay', 'behind', 'nookie', 'shtup', 'screwing', 'tail_end', 'Eastern_Samoa', 'fundament', 'hindquarters', 'prat', 'atomic_number_33', 'tooshie', 'fanny', 'As', 'piece_of_tail', 'tush', 'AS']
#
# assailant <class 'str'>
# ['assaulter']
#
# assassin <class 'str'>
# ['bravo', 'assassinator']
#
# assassinate <class 'str'>
# []
#
# assassination <class 'str'>
# ['character_assassination', 'blackwash']
#
# assault <class 'str'>
# ['lash_out', 'dishonour', 'ravish', 'snipe', 'assail', 'ravishment', 'Assault', 'set_on']
#
# assemble <class 'str'>
# ['put_together', 'foregather', 'get_together', 'tack_together', 'forgather', 'set_up']
#
# assembly <class 'str'>
# ['assemblage', 'gathering', 'meeting_place']
#
# assemblyman <class 'str'>
# []
#
# assert <class 'str'>
# ['aver', 'put_forward', 'affirm', 'swan', 'avow', 'asseverate']
#
# assertive <class 'str'>
# ['self-assertive', 'self-asserting']
#
# assess <class 'str'>
# ['appraise', 'buns', 'nates', 'nooky', 'derriere', 'arse', 'hind_end', 'keister', 'rear_end', 'valuate', 'piece_of_ass', 'roll_in_the_hay', 'behind', 'nookie', 'shtup', 'screwing', 'tail_end', 'fundament', 'hindquarters', 'prat', 'tooshie', 'fanny', 'piece_of_tail', 'tush']
#
# assessment <class 'str'>
# ['judgement']
#
# asset <class 'str'>
# ['plus']
#
# asshole <class 'str'>
# ['mother_fucker', 'arsehole', 'arse', 'SOB', 'son_of_a_bitch', 'whoreson']
#
# assign <class 'str'>
# ['impute', 'allot', 'depute', 'arrogate', 'ascribe', 'set_apart']
#
# assignment <class 'str'>
# ['designation', 'assigning', 'naming', 'duty_assignment', 'grant']
#
# assimilate <class 'str'>
# ['take_in', 'imbibe']
#
# assist <class 'str'>
# ['wait_on', 'attend_to']
#
# assistance <class 'str'>
# []
#
# assistant <class 'str'>
# ['adjunct']
#
# associate <class 'str'>
# ['affiliate', 'assort', 'associate_degree', 'link_up', 'consociate', 'tie_in', 'colligate']
#
# association <class 'str'>
# ['tie-up', 'connexion']
#
# assorted <class 'str'>
# ['sort', 'affiliate', 'sundry', 'assort', 'sort_out', 'mixed']
#
# assortment <class 'str'>
# ['compartmentalisation', 'miscellanea', 'categorization', 'salmagundi', 'categorisation', 'mixed_bag', 'miscellany', 'smorgasbord', 'compartmentalization']
#
# assume <class 'str'>
# ['take_for_granted', 'take_on', 'take_up', 'don', 'arrogate', 'get_into', 'take_over', 'put_on', 'usurp']
#
# assumption <class 'str'>
# ['laying_claim', 'Assumption', 'effrontery', 'presumptuousness', 'supposition', 'supposal', 'Assumption_of_Mary', 'premiss', 'August_15']
#
# assurance <class 'str'>
# ['self-confidence', 'self-assurance', 'sureness']
#
# assure <class 'str'>
# ['see_to_it']
#
# asterisk <class 'str'>
# []
#
# asteroid <class 'str'>
# ['star-shaped']
#
# asthma <class 'str'>
# ['bronchial_asthma', 'asthma_attack']
#
# asthmatic <class 'str'>
# ['wheezy', 'wheezing']
#
# astonish <class 'str'>
# []
#
# astonished <class 'str'>
# ['astounded', 'stunned', 'astonied']
#
# astonishing <class 'str'>
# ['astounding', 'stupefying', 'staggering']
#
# astound <class 'str'>
# []
#
# astral <class 'str'>
# []
#
# astrology <class 'str'>
# ['star_divination']
#
# astronaut <class 'str'>
# ['cosmonaut']
#
# astronomer <class 'str'>
# ['stargazer', 'uranologist']
#
# astronomical <class 'str'>
# ['astronomic']
#
# astronomy <class 'str'>
# ['uranology']
#
# astute <class 'str'>
# []
#
# asylum <class 'str'>
# ['mental_hospital', 'mental_home', 'insane_asylum', 'psychiatric_hospital', 'mental_institution']
#
# atheist <class 'str'>
# ['atheistic', 'atheistical']
#
# athlete <class 'str'>
# ['jock']
#
# athletic <class 'str'>
# ['gymnastic', 'acrobatic']
#
# athletics <class 'str'>
# ['athletic_contest', 'athletic_competition']
#
# atlas <class 'str'>
# ['atlas_vertebra', 'map_collection', 'Atlas', 'telamon', 'book_of_maps']
#
# atmosphere <class 'str'>
# ['atmospheric_state', 'atm', 'standard_atmosphere', 'standard_pressure', 'ambiance']
#
# atmospheric <class 'str'>
# ['atmospherical']
#
# atoll <class 'str'>
# []
#
# atom <class 'str'>
# ['corpuscle', 'mote']
#
# atomic <class 'str'>
# []
#
# atone <class 'str'>
# ['abye', 'expiate', 'aby']
#
# atrium <class 'str'>
# []
#
# atrocious <class 'str'>
# ['flagitious']
#
# atrocity <class 'str'>
# ['barbarousness', 'inhumanity', 'heinousness', 'barbarity', 'atrociousness']
#
# atrophy <class 'str'>
# ['wasting_away', 'wasting']
#
# attach <class 'str'>
# ['bond', 'sequester']
#
# attachment <class 'str'>
# ['fond_regard', 'fastening', 'affixation', 'adhesion', 'bond', 'adherence']
#
# attack <class 'str'>
# ['onslaught', 'aggress', 'lash_out', 'onrush', 'snipe', 'assail', 'plan_of_attack', 'flack', 'tone-beginning', 'set_on']
#
# attacker <class 'str'>
# ['assaulter']
#
# attain <class 'str'>
# ['come_across', 'light_upon', 'happen_upon', 'come_upon', 'chance_on', 'chance_upon', 'arrive_at', 'fall_upon']
#
# attempt <class 'str'>
# ['set_about', 'assay', 'endeavour']
#
# attempted <class 'str'>
# ['set_about', 'assay']
#
# attend <class 'str'>
# ['give_ear', 'advert', 'take_care', 'pay_heed', 'wait_on', 'attend_to', 'go_to']
#
# attendance <class 'str'>
# ['attending']
#
# attendant <class 'str'>
# ['concomitant', 'consequent', 'accompaniment', 'co-occurrence', 'attender', 'attendee', 'meeter', 'sequent', 'resultant', 'ensuant', 'accompanying']
#
# attention <class 'str'>
# ['attending', 'tending']
#
# attentive <class 'str'>
# ['heedful', 'paying_attention']
#
# attest <class 'str'>
# ['bear_witness', 'take_the_stand']
#
# attic <class 'str'>
# ['Ionic', 'bonce', 'Classical_Greek', 'Attic', 'garret', 'Ionic_dialect']
#
# attire <class 'str'>
# ['dress_up', 'fancy_up', 'trick_up', 'deck_up', 'fig_up', 'prink', 'get_up', 'fig_out', 'tog_up', 'overdress', 'deck_out', 'garb', 'trick_out', 'tog_out', 'gussy_up', 'rig_out']
#
# attitude <class 'str'>
# ['mental_attitude']
#
# attorney <class 'str'>
# []
#
# attract <class 'str'>
# ['draw_in', 'pull_in']
#
# attraction <class 'str'>
# ['attractiveness', 'attractor', 'attractive_force', 'attractive_feature', 'drawing_card', 'attracter']
#
# attractive <class 'str'>
# []
#
# attribute <class 'str'>
# ['ascribe', 'impute']
#
# auburn <class 'str'>
# []
#
# auction <class 'str'>
# ['vendue', 'auction_sale', 'auction_bridge', 'auction_off']
# auctioneer <class 'str'>
# ['auction_off']
#
# audacious <class 'str'>
# ['brazen-faced', 'bald-faced', 'dauntless', 'venturous', 'hardy', 'unfearing', 'venturesome', 'bodacious', 'brassy', 'barefaced']
#
# audacity <class 'str'>
# ['audaciousness', 'temerity']
#
# audible <class 'str'>
# ['hearable']
#
# audience <class 'str'>
# ['hearing']
#
# audio <class 'str'>
# ['audio_recording', 'audio_frequency', 'sound_recording']
#
# audit <class 'str'>
# ['audited_account', 'scrutinize', 'scrutinise']
#
# audition <class 'str'>
# ['auditory_modality', 'try_out', 'auditory_sense', 'sense_of_hearing', 'hearing']
#
# auditor <class 'str'>
# ['hearer', 'attender']
#
# auditorium <class 'str'>
# []
#
# auditory <class 'str'>
# ['audile', 'auditive']
#
# aunt <class 'str'>
# ['aunty']
#
# auntie <class 'str'>
# ['aunty']
#
# aura <class 'str'>
# ['gloriole', 'nimbus', 'aureole']
#
# auspicious <class 'str'>
# []
#
# authentic <class 'str'>
# ['unquestionable', 'bona_fide']
#
# authenticate <class 'str'>
# []
#
# authenticity <class 'str'>
# ['genuineness']
#
# author <class 'str'>
# []
#
# authority <class 'str'>
# ['authorisation', 'self-confidence', 'sureness', 'federal_agency', 'self-assurance', 'say-so', 'government_agency']
#
# authorization <class 'str'>
# ['authorisation', 'say-so', 'empowerment']
#
# authorize <class 'str'>
# ['empower', 'authorise']
#
# autism <class 'str'>
# []
#
# autistic <class 'str'>
# []
#
# auto <class 'str'>
# []
#
# autobiographical <class 'str'>
# ['autobiographic']
#
# autobiography <class 'str'>
# []
#
# autograph <class 'str'>
# ['inscribe', 'John_Hancock']
#
# autographed <class 'str'>
# ['inscribe']
#
# automated <class 'str'>
# ...
#
# whirlpool <class 'str'>
# ['maelstrom', 'eddy', 'purl']
#
# whirlwind <class 'str'>
# []
#
# whisk <class 'str'>
# ['whisk_off', 'whisk_broom']
#
# whiskers <class 'str'>
# ["hair's-breadth", 'vibrissa', 'face_fungus', 'whisker', 'hairsbreadth', 'bewhisker', 'sensory_hair']
#
# whiskey <class 'str'>
# ['whisky']
#
# whisper <class 'str'>
# ['whispering', 'voicelessness', 'rustling', 'susurration']
#
# whistle <class 'str'>
# ['pennywhistle', 'whistling', 'tin_whistle']
#
# whit <class 'str'>
# ['tittle', 'smidgeon', 'scintilla', 'smidgin', 'smidge']
#
# white <class 'str'>
# ['ashen', 'Patrick_White', 'Patrick_Victor_Martindale_White', 'White_person', 'Edward_Douglas_White_Jr.', 'blanched', 'white-hot', 'whiteness', 'gabardine', 'Edward_White', 'Andrew_D._White', 'whitened', 'Caucasian', 'lily-white', 'White', 'Edward_D._White', 'albumen', 'whiten', 'White_River', 'Stanford_White', 'ovalbumin', 'Andrew_Dickson_White', 'T._H._White', 'Theodore_Harold_White', 'egg_white', 'E._B._White', 'bloodless', 'Elwyn_Brooks_White']
#
# whitefish <class 'str'>
# []
#
# whitewash <class 'str'>
# ['sleek_over', 'hush_up', 'gloss_over']
#
# whittle <class 'str'>
# ['Whittle', 'Frank_Whittle', 'Sir_Frank_Whittle', 'pare']
#
# whiz <class 'str'>
# ['mavin', 'maven', 'whizz', 'whirr', 'whir', 'birr']
#
# whole <class 'str'>
# ['unhurt', 'totally', 'unscathed', 'entirely', 'wholly', 'hale', 'all', 'completely', 'altogether']
#
# wholesale <class 'str'>
# ['in_large_quantities', 'sweeping']
#
# wholesome <class 'str'>
# []
#
# whopper <class 'str'>
# ['whacker', 'walloper']
#
# whopping <class 'str'>
# ['whop', 'bonk', 'banging', 'whap', 'thumping', 'walloping', 'wham']
#
# whore <class 'str'>
# ['working_girl', 'sporting_lady', 'bawd', 'cocotte', 'lady_of_pleasure', 'fancy_woman', 'woman_of_the_street', 'cyprian']
#
# whorehouse <class 'str'>
# ['house_of_prostitution', 'bawdyhouse', 'sporting_house', 'bordello', 'bagnio', 'house_of_ill_repute']
#
# wicked <class 'str'>
# ['skanky', 'disgustful', 'repelling', 'implike', 'loathly', 'repellant', 'impish', 'prankish', 'puckish', 'pixilated']
#
# wickedness <class 'str'>
# ['sinfulness', 'nefariousness', 'vileness', 'repulsiveness', 'loathsomeness', 'sliminess', 'lousiness']
#
# wicker <class 'str'>
# ['caning', 'wickerwork']
#
# wide <class 'str'>
# ['panoptic', 'all-embracing', 'wide-eyed', 'all-encompassing', 'astray', 'wide_of_the_mark', 'wide-cut', 'all-inclusive', 'encompassing', 'across-the-board', 'widely']
#
# widen <class 'str'>
# ['let_out']
#
# widespread <class 'str'>
# ['far-flung']
#
# widow <class 'str'>
# ['widow_woman']
#
# widowed <class 'str'>
# []
#
# widower <class 'str'>
# ['widowman']
#
# width <class 'str'>
# []
#
# wield <class 'str'>
# []
#
# wiener <class 'str'>
# ['wienerwurst', 'frankfurter', 'Norbert_Wiener', 'frank', 'hot_dog', 'Wiener']
#
# wienie <class 'str'>
# []
#
# wife <class 'str'>
# ['married_woman']
#
# wig <class 'str'>
# ['wigging']
#
# wiggle <class 'str'>
# ['joggle']
#
# wiki <class 'str'>
# []
#
# wild <class 'str'>
# ['state_of_nature', 'tempestuous', 'natural_state', 'raving_mad', 'uncivilised', 'baseless', 'rampantly', 'unwarranted', 'groundless']
#
# wildcat <class 'str'>
# ['unauthorised', 'wildcat_well']
#
# wildebeest <class 'str'>
# ['gnu']
#
# wilderness <class 'str'>
# ['Wilderness']
#
# wildfire <class 'str'>
# []
#
# wildlife <class 'str'>
# []
#
# will <class 'str'>
# ['volition']
#
# willful <class 'str'>
# ['wilful', 'self-willed', 'froward']
#
# willies <class 'str'>
# []
#
# willing <class 'str'>
# ['volition', 'uncoerced', 'unforced']
#
# willingness <class 'str'>
# []
#
# willow <class 'str'>
# ['willow_tree']
#
# willpower <class 'str'>
# ['self-possession', 'will_power', 'self-command', 'self-control', 'self-will']
#
# wilt <class 'str'>
# ['wilt_disease', 'droop', 'wilting']
#
# wily <class 'str'>
# ['guileful', 'knavish', 'tricksy']
#
# wimp <class 'str'>
# ['WIMP', 'weakly_interacting_massive_particle']
#
# wimpy <class 'str'>
# ['wimpish']
#
# win <class 'str'>
# ['deliver_the_goods', 'bring_home_the_bacon', 'pull_ahead', 'profits', 'come_through', 'gain_ground', 'get_ahead', 'make_headway']
#
# winch <class 'str'>
# ['windlass']
#
# wind <class 'str'>
# ['meander', 'current_of_air', 'wind_instrument', 'flatus', 'breaking_wind', 'malarky', 'idle_words', 'wreathe', 'confidential_information', 'farting', 'winding', 'wind_up', 'air_current']
#
# windbag <class 'str'>
# ['gasbag']
#
# windmill <class 'str'>
# ['aerogenerator', 'wind_generator']
#
# window <class 'str'>
# ['windowpane']
#
# windowsill <class 'str'>
# []
#
# windpipe <class 'str'>
# []
#
# windshield <class 'str'>
# ['windscreen']
#
# windy <class 'str'>
# ['wordy', 'blowy', 'long-winded', 'airy', 'verbose', 'Laputan']
#
# wine <class 'str'>
# ['wine-colored', 'vino', 'wine-coloured']
#
# wine cooler <class 'str'>
# []
#
# wing <class 'str'>
# ['backstage', 'offstage', 'annexe']
#
# winged <class 'str'>
# []
#
# winger <class 'str'>
# []
#
# wingman <class 'str'>
# []
#
# wink <class 'str'>
# ['trice', 'eye_blink', 'split_second', 'nictitation', 'blinking', 'New_York_minute', 'twinkling', 'nictation', 'blink_of_an_eye', 'winkle', 'nictate', 'blink_away', 'winking', 'nictitate']
#
# winner <class 'str'>
# ['achiever', 'victor', 'succeeder']
#
# winnings <class 'str'>
# ['profits', 'winning']
#
# wino <class 'str'>
# ['sot', 'inebriate', 'rummy']
#
# winter <class 'str'>
# ['overwinter']
#
# wintertime <class 'str'>
# []
#
# wipe <class 'str'>
# ['pass_over']
#
# wiper <class 'str'>
# ['wiper_blade', 'wiper_arm', 'windscreen_wiper', 'contact_arm', 'windshield_wiper']
#
# wire <class 'str'>
# ['conducting_wire', 'electrify']
#
# wireless <class 'str'>
# ['radio_receiver', 'radiocommunication', 'receiving_set', 'radio_set', 'tuner']
#
# wiretap <class 'str'>
# []
#
# wiring <class 'str'>
# ['electrify']
#
# wisdom <class 'str'>
# ['sapience', 'Wisdom', 'wiseness', 'soundness', 'Wisdom_of_Solomon']
#
# wise <class 'str'>
# ['wise_to', 'Isaac_Mayer_Wise', 'Stephen_Samuel_Wise', 'judicious', 'overbold', 'Wise', 'knowing']
#
# wish <class 'str'>
# ['indirect_request', 'wishing', 'compliments', 'wish_well']
#
# wishbone <class 'str'>
# ['wishing_bone']
#
# wishful <class 'str'>
# ['aspirant', 'desirous']
#
# wisp <class 'str'>
# []
#
# wit <class 'str'>
# ['witticism', 'mental_capacity', 'humour', 'wittiness', 'learning_ability', 'brainpower']
#
# witch <class 'str'>
# ['beldame', 'bewitch', 'Wiccan', 'crone', 'beldam', 'enchant']
#
# witchcraft <class 'str'>
# ['witchery']
#
# withdraw <class 'str'>
# ['draw_back', 'bow_out', 'sequester', 'recede', 'unsay', 'call_back', 'crawfish_out', 'move_back', 'take_back', 'take_away', "pull_in_one's_horns", 'call_in', 'crawfish', 'pull_back', 'take_out', 'pull_away', 'sequestrate', 'back_out', 'draw_off', 'back_away', 'seclude']
#
# withdrawal <class 'str'>
# ['climb-down', 'onanism', 'backdown', 'withdrawal_method', 'coitus_interruptus', 'pulling_out', 'secession', 'drug_withdrawal']
#
# wither <class 'str'>
# ['shrivel_up']
#
# withering <class 'str'>
# ['annihilative', 'shrivel_up', 'annihilating']
#
# withhold <class 'str'>
# ['keep_back', 'recoup']
#
# withholding <class 'str'>
# ['recoup', 'keep_back', 'withholding_tax']
#
# withstand <class 'str'>
# ['hold_out', 'stand_firm', 'hold_up']
#
# witless <class 'str'>
# ['nitwitted', 'soft-witted']
#
# witness <class 'str'>
# ['witnesser', 'attestant', 'attestor', 'attestator']
#
# witty <class 'str'>
# []
#
# wiz <class 'str'>
# ['maven', 'mavin', 'whizz']
#
# wizard <class 'str'>
# ['thaumaturgist', 'wizardly', 'maven', 'whizz', 'mavin', 'witching', 'thaumaturge', 'sorcerous']
#
# wobble <class 'str'>
# ['careen', 'coggle']
#
# wobbly <class 'str'>
# ['Wobbly', 'wonky']
#
# woe <class 'str'>
# ['suffering', 'woefulness']
#
# wok <class 'str'>
# []
#
# wolf <class 'str'>
# ['woman_chaser', 'Friedrich_August_Wolf', 'Wolf', 'skirt_chaser', 'wolf_down', 'masher', 'Hugo_Wolf']
#
# wolverine <class 'str'>
# ['Gulo_gulo', 'Gulo_luscus', 'Wolverine', 'carcajou', 'skunk_bear', 'Michigander']
#
# woman <class 'str'>
# ['cleaning_lady', 'cleaning_woman', 'adult_female', 'fair_sex', 'char', 'charwoman']
#
# womanhood <class 'str'>
# ['muliebrity', 'fair_sex']
#
# womanizer <class 'str'>
# ['womaniser', 'philanderer']
#
# womb <class 'str'>
# []
#
# wonder <class 'str'>
# ['enquire', 'wonderment']
#
# wonderful <class 'str'>
# ['marvellous', 'rattling', 'howling']
#
# wondrous <class 'str'>
# ['superbly', 'marvelously', 'rattling', 'howling', 'marvellous', 'toppingly', 'terrifically', 'wondrously', 'marvellously', 'wonderfully']
#
# wont <class 'str'>
# []
#
# woo <class 'str'>
# []
#
# wood <class 'str'>
# ['Wood', 'Mrs._Henry_Wood', 'woods', 'Ellen_Price_Wood', 'woodwind_instrument', 'Grant_Wood', 'Sir_Henry_Wood', 'Natalie_Wood', 'Sir_Henry_Joseph_Wood', 'woodwind']
#
# wooden <class 'str'>
# []
#
# woodland <class 'str'>
# ['timberland']
#
# woodpecker <class 'str'>
# ['peckerwood']
#
# woodshed <class 'str'>
# []
#
# woodsman <class 'str'>
# ['woodman', 'woodworker']
#
# woodwork <class 'str'>
# ['woodworking']
#
# woof <class 'str'>
# ['weft', 'filling']
#
# wool <class 'str'>
# ['woollen']
#
# woolen <class 'str'>
# ['woollen']
#
# woozy <class 'str'>
# ['vertiginous']
#
# word <class 'str'>
# ['word_of_honor', 'give_voice', 'Bible', 'Word', 'give-and-take', 'Holy_Writ', 'Logos', 'countersign', 'Word_of_God', 'Scripture', 'Good_Book', 'Holy_Scripture', 'Son', 'watchword', 'Christian_Bible', 'Book']
#
# work <class 'str'>
# ['figure_out', 'make_for', 'work_out', 'work_on', 'knead', 'act_upon', 'do_work', 'body_of_work', 'oeuvre', 'put_to_work', 'piece_of_work', 'puzzle_out', 'ferment']
#
# workaholic <class 'str'>
# []
#
# worker <class 'str'>
# ['proletarian', 'prole']
#
# workings <class 'str'>
# ['figure_out', 'make_for', 'works', 'work_out', 'work_on', 'knead', 'act_upon', 'working', 'do_work', 'put_to_work', 'puzzle_out', 'ferment']
#
# workload <class 'str'>
# ['work_load']
#
# workman <class 'str'>
# ['working_person', 'working_man', 'workingman']
#
# workmanship <class 'str'>
# []
#
# workout <class 'str'>
# ['exercising', 'physical_exertion', 'physical_exercise']
#
# workplace <class 'str'>
# []
#
# workshop <class 'str'>
# []
#
# workup <class 'str'>
# []
#
# world <class 'str'>
# ['world-wide', 'worldwide', 'worldly_concern', 'Earth', 'macrocosm', 'human_race', 'earthly_concern', 'humans', 'human_beings', 'populace']
#
# worldly <class 'str'>
# []
#
# worm <class 'str'>
# ['dirt_ball', 'writhe']
#
# wormhole <class 'str'>
# []
#
# wormwood <class 'str'>
# []
#
# worried <class 'str'>
# ['vex', 'disturbed', 'disquieted']
#
# worry <class 'str'>
# ['vex', 'vexation']
#
# worrying <class 'str'>
# ['distressful', 'vex', 'bedevilment', 'troubling', 'badgering', 'perturbing', 'worrisome']
#
# worship <class 'str'>
# ['idolise', 'idolize', 'revere', 'hero-worship']
#
# worthless <class 'str'>
# []
#
# worthwhile <class 'str'>
# []
#
# worthy <class 'str'>
# []
#
# would <class 'str'>
# []
#
# wound <class 'str'>
# ['meander', 'spite', 'wounding', 'wreathe', 'wind_up', 'combat_injury']
#
# wounds <class 'str'>
# ['combat_injury', 'wounding', 'spite']
#
# wrap <class 'str'>
# ['wrapping', 'envelop', 'enclose', 'enwrap', 'enfold', 'wrap_up']
#
# wrapper <class 'str'>
# ['peignoir', 'neglige', 'wrapping', 'housecoat']
#
# wrath <class 'str'>
# ['ira', 'ire']
#
# wreak <class 'str'>
# ['make_for']
#
# wreath <class 'str'>
# ['coronal', 'lei', 'chaplet', 'garland']
#
# wreck <class 'str'>
# ['wrack', 'bust_up']
#
# wreckage <class 'str'>
# []
#
# wrecker <class 'str'>
# ['tow_car', 'diversionist', 'tow_truck']
#
# wrench <class 'str'>
# ['wrick', 'spanner', 'rick']
#
# wrestle <class 'str'>
# ['grapple', 'hand-to-hand_struggle', 'writhe']
#
# wrestler <class 'str'>
# ['matman', 'grappler']
#
# wrestling <class 'str'>
# ['grapple', 'hand-to-hand_struggle', 'rassling', 'writhe']
#
# wretch <class 'str'>
# ['poor_devil']
#
# wretched <class 'str'>
# ['suffering', 'pitiable', 'misfortunate', 'piteous', 'execrable', 'woeful']
#
# wriggle <class 'str'>
# ['writhe']
# wring <class 'str'>
# ['contort', 'deform']
#
# wringer <class 'str'>
# []
#
# wrinkle <class 'str'>
# ['crumple', 'crinkle', 'furrow', 'scrunch', 'rumple', 'ruckle', 'scrunch_up']
#
# wrinkled <class 'str'>
# ['crumple', 'crinkle', 'scrunch', 'scrunch_up', 'wrinkly', 'rumple', 'unironed', 'ruckle', 'furrow']
#
# wrist <class 'str'>
# ['wrist_joint', 'radiocarpal_joint', 'carpus', 'articulatio_radiocarpea']
#
# wristwatch <class 'str'>
# ['wrist_watch']
#
# writ <class 'str'>
# ['judicial_writ']
#
# write <class 'str'>
# ['indite', 'drop_a_line']
#
# writer <class 'str'>
# []
#
# wrong <class 'str'>
# ['amiss', 'incorrectly', 'ill-timed', 'wrongly', 'unseasonable', 'awry', 'wrongfulness', 'legal_injury']
#
# wrongdoing <class 'str'>
# ['wrongful_conduct', 'actus_reus']
#
# wrongful <class 'str'>
# []
#
# yacht <class 'str'>
# ['racing_yacht']
#
# yahoo <class 'str'>
# ['chawbacon', 'bumpkin', 'rube', 'yokel', 'Yahoo', 'hayseed']
#
# yak <class 'str'>
# ['yack', 'yakety-yak', 'cackle', 'Bos_grunniens']
#
# yank <class 'str'>
# ['Yankee-Doodle', 'Yank', 'Northerner', 'Yankee']
#
# yap <class 'str'>
# ['cakehole', 'yip', 'maw', 'gob', 'yelp']
#
# yard <class 'str'>
# ['grounds', 'G', 'K', 'railyard', 'curtilage', '1000', 'railway_yard', 'cubic_yard', 'thou', 'chiliad', 'M', 'one_thousand']
#
# yarn <class 'str'>
# ['narration']
#
# yawn <class 'str'>
# ['oscitancy', 'yawning', 'gape', 'oscitance', 'yaw']
#
# year <class 'str'>
# ['twelvemonth', 'yr']
#
# yearbook <class 'str'>
# []
#
# yearly <class 'str'>
# ['every_year', 'annually', 'each_year']
#
# yearn <class 'str'>
# ['languish', 'hanker', 'long']
#
# yeast <class 'str'>
# ['barm']
#
# yell <class 'str'>
# ['hollo', 'shout_out', 'vociferation', 'outcry']
#
# yeller <class 'str'>
# ['bellower', 'screecher', 'shouter', 'roarer', 'bawler']
#
# yellow <class 'str'>
# ['chickenhearted', 'yellowed', 'jaundiced', 'yellow-bellied', 'xanthous', 'icteric', 'scandalmongering', 'yellowness', 'yellowish', 'white-livered', 'sensationalistic', 'lily-livered']
#
# yen <class 'str'>
# ['languish']
#
# yield <class 'str'>
# ['buckle_under', 'takings', 'ease_up', 'cede', 'relent', 'give_way', 'give_in', 'knuckle_under', 'succumb', 'move_over', 'grant']
#
# yo-yo <class 'str'>
# []
#
# yodel <class 'str'>
# ['descant', 'warble']
#
# yoga <class 'str'>
# []
#
# yogurt <class 'str'>
# ['yoghurt', 'yoghourt']
#
# yoke <class 'str'>
# ['couplet', 'distich', 'duad', 'dyad']
#
# yolk <class 'str'>
# ['vitellus', 'egg_yolk']
#
# young <class 'str'>
# ['Young', 'Whitney_Moore_Young_Jr.', 'Cy_Young', 'untested', 'Brigham_Young', 'Lester_Willis_Young', 'unseasoned', 'Whitney_Young', 'untried', 'Loretta_Young', 'Thomas_Young', 'vernal', 'Edward_Young', 'Pres_Young', 'Danton_True_Young']
#
# youngster <class 'str'>
# ['nestling', 'small_fry', 'tiddler', 'tike']
#
# youth <class 'str'>
# ['youthfulness', 'younker', 'young_person', 'juvenility', 'spring_chicken', 'early_days']
#
# youthful <class 'str'>
# ['vernal']
#
# yucky <class 'str'>
# ['skanky', 'repelling', 'loathly', 'repellant', 'disgustful']
#
# yuletide <class 'str'>
# ['Christmas', 'Yule', 'Christmastide', 'Christmastime', 'Yuletide', 'Noel']
#
# yummy <class 'str'>
# ['pleasant-tasting', 'delectable', 'toothsome']
#
# yuppie <class 'str'>
# []
#
# zap <class 'str'>
# ['atomize', 'vaporize', 'atomise', 'micro-cook']
#
# zeal <class 'str'>
# ['ardour', 'ardor', 'forwardness', 'elan', 'eagerness']
#
# zebra <class 'str'>
# []
#
# zenith <class 'str'>
# []
#
# zephyr <class 'str'>
# ['gentle_wind', 'Zephyr']
#
# zest <class 'str'>
# ['spice_up', 'tanginess', 'zestfulness', 'piquance', 'piquantness', 'piquancy']
#
# zeta <class 'str'>
# []
#
# zigzag <class 'str'>
# ['zig-zag', 'zag', 'zig']
#
# zilch <class 'str'>
# ['goose_egg', 'cypher', 'nothing', 'aught', 'zero', 'zippo', 'null', 'nil', 'naught']
#
# zillion <class 'str'>
# ['jillion']
#
# zinc <class 'str'>
# ['Zn', 'atomic_number_30']
#
# zing <class 'str'>
# ['pizzaz', 'dynamism']
#
# zip <class 'str'>
# ['goose_egg', 'nothing', 'aught', 'cypher', 'zero', 'naught', 'slide_fastener', 'ZIP_code', 'zippo', 'zip_fastener', 'ZIP', 'postal_code', 'null', 'vigour', 'nil', 'travel_rapidly', 'postcode', 'zip_up']
#
# zipper <class 'str'>
# ['zip_fastener', 'slide_fastener', 'zip_up']
#
# zit <class 'str'>
# []
#
# zodiac <class 'str'>
# []
#
# zombie <class 'str'>
# ['automaton', 'zombi', 'zombi_spirit', 'zombie_spirit', 'living_dead', 'snake_god']
#
# zone <class 'str'>
# ['zona', 'geographical_zone']
#
# zoning <class 'str'>
# []
#
# zoo <class 'str'>
# ['zoological_garden', 'menagerie']
#
# zoom <class 'str'>
# ['soar_upwards', 'rapid_climb', 'rapid_growth', 'whizz', 'zoom_along', 'soar_up', 'whizz_along']
#
# zucchini <class 'str'>
# ['courgette']

# %%
dict_syn['']
# Out:
# ['awful',
#  'atrocious',
#  'terrible',
#  'abominable',
#  'painful',
#  'dreadful',
#  'unspeakable']

# %%
VAD_extend = pd.DataFrame(columns=['Word','V','A','D'])

# %%
VAD_extend = pd.DataFrame(columns=['Word','V','A','D'])
for word in dict_syn.keys():
    print(word)
    name = [word]
    value = list(VAD.loc[dict_syn[word]].mean().get_values())
    VAD_extend = VAD_extend.append(pd.Series(name+value,index=VAD_extend.columns),ignore_index=True)
# Out:
# ant_bear
# anteater
# Orycteropus_afer
# ear-shell
# wantonness
# wildness
# give_up
# unconstraint
# defection
# forsaking
# venter
# abdominal_cavity
# ab
# abdominal_muscle
# nobble
# stick_out
# put_up
# imperishable
# low-down
# scummy
# unhopeful
# aflame
# reddened
# aflare
# inflamed
# on_fire
# able-bodied
# abnormalcy
# mental_defectiveness
# freakishness
# dwelling_house
# habitation
# domicile
# get_rid_of
# execrable
# detestable
# odious
# abhorrence
# detestation
# odium
# execration
# abradant
# abrasive_material
# up_on
# au_courant
# au_fait
# disconnected
# precipitous
# absence_seizure
# missing
# abstracted
# scatty
# lacking
# absentminded
# wanting
# old_man
# absinth
# lad's_love
# Artemisia_absinthium
# common_wormwood
# out-and-out
# infrangible
# downright
# inviolable
# right-down
# remission_of_sin
# remittal
# shrive
# suck_up
# soak_up
# engross
# sop_up
# engulf
# take_up
# immerse
# take_over
# take_in
# imbibe
# abstention
# purloin
# filch
# synopsis
# nonobjective
# snarf
# abstractionist
# pilfer
# abstraction
# precis
# nonfigurative
# derisory
# the_absurd
# nonsensical
# absurdness
# ridiculousness
# fatuity
# fatuousness
# teemingness
# copiousness
# blackguard
# maltreatment
# ill-treat
# maltreat
# ill-usage
# revilement
# vilification
# mistreat
# clapperclaw
# contumely
# ill-use
# ill-treatment
# scurrilous
# opprobrious
# unfathomable
# abyssal
# abysm
# abye
# expiate
# aby
# pedantic
# academician
# donnish
# faculty_member
# honorary_society
# speed_up
# quicken
# quickening
# speedup
# atom_smasher
# throttle_valve
# particle_accelerator
# gas_pedal
# accelerator_pedal
# accent_mark
# idiom
# accentuate
# speech_pattern
# punctuate
# emphasise
# go_for
# live_with
# take_on
# espousal
# acceptation
# banker's_acceptance
# toleration
# sufferance
# memory_access
# get_at
# access_code
# accession
# approachable
# accessary
# accoutrement
# adjuvant
# appurtenant
# adjunct
# accouterment
# ancillary
# appurtenance
# add-on
# fortuity
# chance_event
# inadvertent
# eclat
# acclamation
# plaudit
# plaudits
# spat
# conciliate
# fitting
# go_with
# play_along
# come_with
# attach_to
# keep_company
# carry_out
# fulfil
# carry_through
# attainment
# acquirement
# harmonize
# conformity
# concord
# allot
# fit_in
# harmonise
# accordance
# grant
# piano_accordion
# squeeze_box
# business_relationship
# news_report
# answer_for
# write_up
# account_statement
# answerableness
# answerability
# comptroller
# accounting_system
# method_of_accounting
# accountancy
# pile_up
# cumulate
# amass
# roll_up
# comminate
# anathemize
# execrate
# accurst
# anathematize
# maledict
# accurse
# anathematise
# anathemise
# accusal
# criminate
# top-notch
# ACE
# A-one
# tiptop
# first-rate
# sweep_through
# topnotch
# breeze_through
# maven
# I
# sail_through
# whizz
# angiotensin_converting_enzyme
# angiotensin-converting_enzyme
# pass_with_flying_colors
# tops
# mavin
# 1
# Allied_Command_Europe
# alkyne
# ethyne
# languish
# aching
# sulphurous
# Zen
# acidulous
# sulfurous
# acidulent
# acrid
# battery-acid
# virulent
# Lucy_in_the_sky_with_diamonds
# Elvis
# loony_toons
# acerbic
# acerb
# caustic
# back_breaker
# window_pane
# vitriolic
# acidic
# recognise
# acknowledgment
# acoustical
# conversancy
# acquaintanceship
# conversance
# larn
# learning
# exculpate
# comport
# assoil
# Akko
# Akka
# Acre
# Accho
# land_area
# acrylic_paint
# acrylate_resin
# acrylic_resin
# acrylic_fiber
# dissemble
# enactment
# human_action
# playact
# act_as
# human_activity
# roleplay
# natural_action
# litigate
# natural_process
# activeness
# action_mechanism
# action_at_law
# legal_action
# military_action
# touch_off
# spark_off
# trigger_off
# actuate
# aerate
# set_off
# energizing
# activating
# active_agent
# combat-ready
# fighting
# active_voice
# participating
# activistic
# bodily_function
# bodily_process
# body_process
# thespian
# histrion
# role_player
# existent
# stylostixis
# knifelike
# acute_accent
# penetrating
# ague
# piercing
# incisive
# penetrative
# needlelike
# acuate
# A.D.
# AD
# advertizing
# advertizement
# advert
# anno_Domini
# byword
# adamantine
# intransigent
# inexorable
# adaption
# ADD
# ADHD
# MBD
# add_together
# tote_up
# minimal_brain_dysfunction
# sum_up
# add_up
# summate
# tot_up
# attention_deficit_disorder
# minimal_brain_damage
# append
# attention_deficit_hyperactivity_disorder
# hyperkinetic_syndrome
# common_viper
# Vipera_berus
# dependance
# habituation
# habit-forming
# computer_address
# accost
# name_and_address
# turn_to
# savoir-faire
# come_up_to
# practiced
# skilful
# enough
# passable
# fair_to_middling
# cleave
# stand_by
# stick_to
# stick_by
# hold_fast
# bond
# cohere
# adhesive_agent
# adhesive_material
# next
# side_by_side
# conterminous
# contiguous
# adjectival
# abut
# butt_against
# adjoin
# butt_on
# march
# break_up
# line_up
# aline
# claims_adjustor
# claim_agent
# adjustor
# claims_adjuster
# readjustment
# lot
# deal_out
# parcel_out
# administrate
# dish_out
# dole_out
# mete_out
# shell_out
# establishment
# judicature
# giving_medication
# governing_body
# government_activity
# organisation
# presidential_term
# governing
# governance
# decision_maker
# full_admiral
# wonderment
# look_up_to
# protagonist
# adorer
# admission_fee
# price_of_admission
# entrance_money
# admission_price
# admission_charge
# entrance_fee
# intromit
# let_in
# allow_in
# adobe_brick
# stripling
# puerile
# jejune
# teenaged
# dramatize
# dramatise
# sweep_up
# espouse
# borrowing
# adopted
# idolisation
# idolization
# latria
# worshipful
# doting
# Adrenalin
# epinephrine
# epinephrin
# undirected
# aimless
# planless
# rudderless
# directionless
# fully_grown
# grown
# full-grown
# fornicator
# criminal_conversation
# get_along
# go_on
# feeler
# make_headway
# set_ahead
# kick_upstairs
# cash_advance
# supercharge
# shape_up
# in_advance
# get_ahead
# throw_out
# forward_motion
# onward_motion
# pass_on
# further
# gain_ground
# betterment
# come_along
# come_on
# bring_forward
# move_on
# pull_ahead
# march_on
# get_on
# beforehand
# forward-looking
# furtherance
# dangerous_undertaking
# risky_venture
# take_chances
# take_a_chance
# escapade
# run_a_risk
# venturer
# adventuresome
# resister
# antagonist
# opposer
# untoward
# inauspicious
# hard_knocks
# advertize
# publicise
# publicize
# publicizing
# rede
# give_notice
# apprize
# apprise
# send_word
# weighing
# consultative
# consultatory
# consultive
# advocator
# exponent
# pleader
# proponent
# counsellor
# counselor-at-law
# aeriform
# transmitting_aerial
# airy
# ethereal
# forward_pass
# aery
# aerobic_exercise
# flowing
# streamlined
# esthetic
# esthetical
# aesthetical
# social_occasion
# social_function
# affaire
# touch_on
# bear_upon
# bear_on
# warmness
# affectionateness
# philia
# warmheartedness
# lovesome
# tie-up
# phylogenetic_relation
# chemical_attraction
# avouchment
# assertion
# avowal
# affirmatory
# approbatory
# approving
# approbative
# plausive
# low-cost
# low-priced
# diss
# inundated
# awash
# flooded
# overflowing
# aforesaid
# said
# African
# hereafter
# backwash
# good_afternoon
# historic_period
# eld
# geezerhood
# senesce
# years
# old_age
# long_time
# maturate
# federal_agency
# delegacy
# means
# government_agency
# agendum
# order_of_business
# agentive_role
# federal_agent
# exacerbate
# worsen
# exasperate
# exacerbation
# exasperation
# strong-growing
# fast-growing
# pugnacity
# belligerence
# assaulter
# spry
# nimbleness
# lightsomeness
# legerity
# ageing
# ripening
# senescence
# senescent
# vex
# charge_up
# shake_up
# stir_up
# raise_up
# turn_on
# foment
# commove
# fermentation
# upheaval
# tempestuousness
# hullabaloo
# ferment
# lucent
# lambent
# torturesome
# torturing
# agonise
# torturous
# agonize
# agonising
# suffering
# excruciation
# gibe
# jibe
# accordant
# conformable
# concordant
# consonant
# agrarian
# factory_farm
# Agriculture
# Agriculture_Department
# agribusiness
# husbandry
# USDA
# Department_of_Agriculture
# tending
# financial_aid
# economic_aid
# adjutant
# aide-de-camp
# acquired_immune_deficiency_syndrome
# under_the_weather
# ail
# poorly
# peaked
# ill
# draw_a_bead_on
# bearing
# purport
# heading
# take_aim
# shoot_for
# melodic_phrase
# air_travel
# airwave
# air_out
# gentle_wind
# melodic_line
# ventilate
# flying_field
# landing_field
# airline_business
# air_hose
# air_lock
# aeroplane
# airdrome
# drome
# aerodrome
# dirigible
# air_space
# flight_strip
# landing_strip
# air-tight
# gas-tight
# respiratory_tract
# skyway
# air_passage
# air_duct
# flight_path
# air_lane
# onyx_marble
# alabastrine
# Mexican_onyx
# oriental_alabaster
# warning_device
# horrify
# alarm_system
# alarum
# consternation
# appal
# alarm_clock
# warning_signal
# appall
# mollymawk
# record_album
# inebriant
# intoxicant
# alcoholic_beverage
# alcoholic_drink
# dipsomaniac
# soaker
# souse
# alcohol-dependent
# boozer
# alky
# potomania
# alcohol_addiction
# inebriation
# dipsomania
# rattling
# qui_vive
# zippy
# watchful
# alerting
# Medicago_sativa
# lucerne
# algorithmic_program
# algorithmic_rule
# also_known_as
# false_name
# a.k.a.
# assumed_name
# exculpation
# self-justification
# extraterrestrial_being
# noncitizen
# disaffect
# outlander
# estrange
# disaffection
# estrangement
# climb_down
# ordinate
# alinement
# allegement
# so-called
# allege
# aver
# fealty
# supersensitive
# supersensitised
# sensitised
# sensitized
# supersensitized
# hypersensitized
# hypersensitised
# hypersensitive
# allergic_reaction
# assuage
# palliate
# bowling_alley
# skittle_alley
# back_street
# confederation
# confederative
# Allied
# take_into_account
# set_aside
# earmark
# allow_for
# valuation_reserve
# allowance_account
# valuation_account
# debase
# admixture
# allurement
# temptingness
# enticing
# beguiling
# farmer's_calendar
# all-powerful
# Lord
# omnipotent
# Creator
# God_Almighty
# Maker
# Jehovah
# Godhead
# Almighty
# Divine
# Amygdalus_communis
# Prunus_amygdalus
# Prunus_dulcis
# sweet_almond
# ciao
# only
# exclusively
# unequalled
# solely
# entirely
# unequaled
# unaccompanied
# upstage
# first_principle
# ABC's
# first_rudiment
# ABC
# rudiment
# ABCs
# alphabetic
# Alpine
# Lord's_table
# communion_table
# spay
# interpolate
# falsify
# fracas
# affray
# flip-flop
# interchange
# take_turns
# EL
# ALT
# atomic_number_13
# aluminium
# Al
# alumna
# alum
# Alzheimer's_disease
# Alzheimer's
# Alzheimers
# unskilled
# amateurish
# inexpert
# nonplus
# perplex
# stupefy
# mystify
# bewilder
# dumbfound
# flummox
# baffle
# astounded
# stunned
# astonied
# astonishment
# awe-inspiring
# awing
# embassador
# brownish-yellow
# yellow-brown
# ambiance
# equivocal
# ambitiousness
# challenging
# beebread
# bitterweed
# ragweed
# ambuscade
# lying_in_wait
# bushwhack
# lie_in_wait
# waylay
# scupper
# still-hunt
# remediate
# ameliorate
# better
# meliorate
# indemnification
# indemnity
# reparation
# damages
# redress
# genial
# good-humored
# good-humoured
# affable
# amino_group
# aminic
# ammonium_hydroxide
# ammonia_water
# ammonium_ion
# memory_loss
# free_pardon
# amative
# amatory
# sum_of_money
# amount_of_money
# A
# adenylic_acid
# adenosine_monophosphate
# ampere
# AMP
# amphibious_vehicle
# amphibious_aircraft
# plentiful
# sizeable
# plenteous
# copious
# cut_off
# amok
# demoniacal
# murderously
# demoniac
# possessed
# disport
# diverted
# entertained
# risible
# amusive
# diverting
# mirthful
# Eunectes_murinus
# anagrammatize
# anagrammatise
# anal_retentive
# doctrine_of_analogy
# analytic_thinking
# depth_psychology
# analytic
# break_down
# take_apart
# psychoanalyze
# psychoanalyse
# analyse
# analyser
# nihilist
# syndicalist
# material_body
# general_anatomy
# soma
# physical_body
# bod
# human_body
# antecedent
# ascendent
# transmissible
# patrimonial
# line_of_descent
# filiation
# blood_line
# stemma
# parentage
# derivation
# keystone
# anchorman
# drop_anchor
# linchpin
# mainstay
# lynchpin
# anchorperson
# ground_tackle
# cast_anchor
# Anchorage
# anchorage_ground
# antediluvian
# mechanical_man
# anaemia
# genus_Anemia
# Anemia
# anaemic
# anaesthesia
# anesthetist
# anaesthetist
# anesthetic_agent
# anaesthetic
# anaesthetic_agent
# aneurism
# Angel_Falls
# Angel
# holy_man
# holy_person
# saintlike
# beatific
# angelical
# cherubic
# saintly
# seraphic
# ira
# see_red
# ire
# choler
# angriness
# angina_pectoris
# Angle
# Turkish_capital
# Angora_rabbit
# capital_of_Turkey
# Angora_cat
# Angora_goat
# Ankara
# Angora
# tempestuous
# tormented
# tortured
# fleshly
# animate_being
# reanimate
# enliven
# renovate
# animise
# vivify
# animize
# liven_up
# animate
# invigorate
# revivify
# exalt
# brio
# living
# spiritedness
# liveliness
# aliveness
# vivification
# invigoration
# animus
# bad_blood
# ankle_joint
# articulatio_talocruralis
# mortise_joint
# bobbysocks
# ankle_bracelet
# anklets
# bobbysock
# chronological_record
# annexe
# decimate
# wipe_out
# carry_off
# disintegration
# obliteration
# day_of_remembrance
# harbinger
# annunciate
# foretell
# denote
# promulgation
# annunciation
# nettle
# chafe
# get_to
# rile
# nark
# pain_in_the_ass
# vexation
# aggravator
# botheration
# infliction
# pain_in_the_neck
# nettled
# miffed
# stung
# pestered
# riled
# roiled
# pissed_off
# harried
# steamed
# harassed
# pissed
# irritated
# vexed
# plaguy
# teasing
# pestering
# galling
# vexatious
# plaguey
# nettlesome
# pestiferous
# vexing
# bothersome
# one-year
# quash
# countermand
# overturn
# nullify
# invalidate
# repeal
# invalidation
# revocation
# abrogation
# inunct
# anoint
# embrocate
# anele
# anomalousness
# unusual_person
# namelessness
# anon.
# anorectic
# emmet
# pismire
# antipathetical
# antipathetic
# antagonise
# front_tooth
# formicary
# splenic_fever
# antiaircraft_gun
# ack-ack_gun
# pom-pom
# ack-ack
# flack
# antibiotic_drug
# Antichrist
# look_for
# look_to
# previse
# prognosticate
# forestall
# foreknow
# forebode
# prevision
# put-on
# antic
# clown_around
# counterpoison
# antiquate
# outmoded
# passe
# gaffer
# old-timer
# passee
# demode
# old-fashioned
# old-hat
# old_geezer
# oldtimer
# age-old
# asocial
# fretful
# fidgety
# incus
# anxiousness
# unquiet
# dying
# aortal
# Apache
# spiritlessness
# numbness
# aper
# anthropoid
# imitator
# caricature
# emulator
# acme
# solar_apex
# vertex
# apex_of_the_sun's_way
# aphrodisiacal
# Revelation
# Book_of_Revelation
# Revelation_of_Saint_John_the_Divine
# Apocalypse
# excusatory
# rationalise
# apologise
# apologia
# Apostelic_Father
# Apostle
# pill_roller
# pill_pusher
# scandalise
# dismayed
# scandalize
# shocked
# aghast
# dismaying
# garb
# enclothe
# raiment
# habilitate
# fit_out
# wearing_apparel
# tog
# seeming
# ostensible
# phantasm
# phantasma
# fantasm
# specter
# spectre
# appealingness
# entreaty
# ingathering
# come_out
# coming_into_court
# visual_aspect
# appearing
# placate
# lenify
# gruntle
# propitiate
# mollify
# quell
# outgrowth
# appendicectomy
# vermiform_process
# vermiform_appendix
# cecal_appendage
# appetency
# appetence
# appetiser
# appetising
# clapping
# hand_clapping
# orchard_apple_tree
# Malus_pumila
# folderol
# wish-wash
# apple_sauce
# codswallop
# trumpery
# gismo
# widget
# contrivance
# applier
# practical_application
# applications_programme
# application_program
# covering
# utilise
# lend_oneself
# put_on
# appointee
# naming
# designation
# revalue
# take_account
# perceptiveness
# discernment
# grok
# get_the_picture
# pick_up
# quail_at
# apprehensiveness
# misgiving
# taking_into_custody
# prentice
# come_near
# draw_near
# glide_slope
# go_about
# draw_close
# glide_path
# border_on
# set_about
# coming
# plan_of_attack
# go_up
# approach_shot
# approach_path
# near
# approaching
# favorable_reception
# favourable_reception
# O.K.
# okay
# come_close
# close_together
# approximative
# apricot_tree
# salmon_pink
# yellowish_pink
# forestage
# proscenium
# minded
# apposite
# given
# disposed
# greenish_blue
# peacock_blue
# cobalt_blue
# marine_museum
# fish_tank
# arbitrement
# arbitrament
# colonnade
# arc
# implike
# impish
# prankish
# archway
# patronising
# puckish
# pixilated
# archaeologic
# archeological
# archeologic
# archeologist
# archeology
# Angelica_Archangelica
# garden_angelica
# computer_architecture
# file_away
# Arctic
# gelid
# gumshoe
# north-polar
# Arctic_Zone
# galosh
# North_Frigid_Zone
# golosh
# glacial
# fervid
# fervent
# impassioned
# perfervid
# expanse
# surface_area
# scene_of_action
# sports_stadium
# logical_argument
# disputation
# parameter
# disceptation
# contestation
# arguing
# line_of_reasoning
# argumentation
# literary_argument
# come_up
# stand_up
# turn_out
# uprise
# rise_up
# bob_up
# move_up
# get_up
# spring_up
# originate
# blue_blood
# patrician
# blue-blooded
# aristocratical
# arithmetical
# Ark_of_the_Covenant
# Ark
# fortify
# weapon_system
# build_up
# gird
# equipping
# arming
# armour
# panoplied
# armoured
# armoury
# axilla
# axillary_cavity
# axillary_fossa
# U._S._Army
# regular_army
# United_States_Army
# Army
# USA
# ground_forces
# US_Army
# odour
# olfactory_property
# conjure_up
# kindle
# bring_up
# perk_up
# energise
# enkindle
# put_forward
# call_forth
# waken
# come_alive
# evoke
# wind_up
# call_down
# wake_up
# stimulated
# turned_on
# ruttish
# randy
# wound_up
# worked_up
# stirred
# stirred_up
# coiffe
# fix_up
# coif
# set_up
# coiffure
# arranging
# musical_arrangement
# regalia
# set_out
# lay_out
# turn_back
# stoppage
# hold_back
# cardiac_arrhythmia
# comer
# arriver
# reaching
# make_it
# go_far
# get_in
# high-handedness
# hauteur
# haughtiness
# lordliness
# self-important
# chesty
# As
# arsenic_trioxide
# white_arsenic
# atomic_number_33
# arsenous_anhydride
# ratsbane
# arsenous_oxide
# incendiarism
# fire-raising
# firebug
# incendiary
# fine_art
# artistic_production
# artistic_creation
# nontextual_matter
# arterial_blood_vessel
# arteria
# globe_artichoke
# Cynara_scolymus
# artichoke_plant
# give_voice
# vocalize
# enunciate
# enounce
# vocalise
# articulated
# sound_out
# artefact
# contrived
# stilted
# artillery_unit
# heavy_weapon
# creative_person
# climb_up
# dominating
# ascensive
# ascent
# rising
# Ascension_of_Christ
# Ascension
# Ascension_of_the_Lord
# Ascension_Day
# find_out
# see_to_it
# fatuous
# vacuous
# enquire
# call_for
# postulate
# necessitate
# at_peace
# benumbed
# departed
# gone
# at_rest
# Asparagus_officinales
# edible_asparagus
# panorama
# facet
# facial_expression
# vista
# mineral_pitch
# breathing_in
# acetylsalicylic_acid
# St._Joseph
# Empirin
# Bayer
# aspirant
# buns
# nates
# nooky
# derriere
# arse
# American_Samoa
# hind_end
# keister
# rear_end
# piece_of_ass
# roll_in_the_hay
# behind
# nookie
# shtup
# screwing
# tail_end
# Eastern_Samoa
# fundament
# hindquarters
# prat
# tooshie
# fanny
# piece_of_tail
# tush
# AS
# bravo
# assassinator
# character_assassination
# blackwash
# lash_out
# dishonour
# ravish
# snipe
# assail
# ravishment
# Assault
# set_on
# put_together
# foregather
# get_together
# tack_together
# forgather
# assemblage
# gathering
# meeting_place
# affirm
# swan
# avow
# asseverate
# self-assertive
# self-asserting
# appraise
# valuate
# judgement
# plus
# mother_fucker
# arsehole
# SOB
# son_of_a_bitch
# whoreson
# impute
# depute
# arrogate
# ascribe
# set_apart
# assigning
# duty_assignment
# wait_on
# attend_to
# affiliate
# assort
# associate_degree
# link_up
# consociate
# tie_in
# colligate
# connexion
# sort
# sundry
# sort_out
# mixed
# compartmentalisation
# miscellanea
# categorization
# salmagundi
# categorisation
# mixed_bag
# miscellany
# smorgasbord
# compartmentalization
# take_for_granted
# don
# get_into
# usurp
# laying_claim
# Assumption
# effrontery
# presumptuousness
# supposition
# supposal
# Assumption_of_Mary
# premiss
# August_15
# self-confidence
# self-assurance
# sureness
# star-shaped
# bronchial_asthma
# asthma_attack
# wheezy
# wheezing
# astounding
# stupefying
# staggering
# star_divination
# cosmonaut
# stargazer
# uranologist
# astronomic
# uranology
# mental_hospital
# mental_home
# insane_asylum
# psychiatric_hospital
# mental_institution
# atheistic
# atheistical
# jock
# gymnastic
# acrobatic
# athletic_contest
# athletic_competition
# atlas_vertebra
# map_collection
# Atlas
# telamon
# book_of_maps
# atmospheric_state
# atm
# standard_atmosphere
# standard_pressure
# atmospherical
# corpuscle
# mote
# flagitious
# barbarousness
# inhumanity
# heinousness
# barbarity
# atrociousness
# wasting_away
# wasting
# sequester
# fond_regard
# fastening
# affixation
# adhesion
# adherence
# onslaught
# aggress
# onrush
# tone-beginning
# come_across
# light_upon
# happen_upon
# come_upon
# chance_on
# chance_upon
# arrive_at
# fall_upon
# assay
# endeavour
# give_ear
# take_care
# pay_heed
# go_to
# attending
# concomitant
# consequent
# accompaniment
# co-occurrence
# attender
# attendee
# meeter
# sequent
# resultant
# ensuant
# accompanying
# heedful
# paying_attention
# bear_witness
# take_the_stand
# Ionic
# bonce
# Classical_Greek
# Attic
# garret
# Ionic_dialect
# dress_up
# fancy_up
# trick_up
# deck_up
# fig_up
# prink
# fig_out
# tog_up
# overdress
# deck_out
# trick_out
# tog_out
# gussy_up
# rig_out
# mental_attitude
# draw_in
# pull_in
# attractiveness
# attractor
# attractive_force
# attractive_feature
# drawing_card
# attracter
# vendue
# auction_sale
# auction_bridge
# auction_off
# brazen-faced
# bald-faced
# dauntless
# venturous
# hardy
# unfearing
# venturesome
# bodacious
# brassy
# barefaced
# audaciousness
# temerity
# hearable
# hearing
# audio_recording
# audio_frequency
# sound_recording
# audited_account
# scrutinize
# scrutinise
# auditory_modality
# try_out
# auditory_sense
# sense_of_hearing
# hearer
# audile
# auditive
# aunty
# gloriole
# nimbus
# aureole
# unquestionable
# bona_fide
# genuineness
# authorisation
# say-so
# empowerment
# empower
# authorise
# autobiographic
# inscribe
# John_Hancock
# automatize
# machine-driven
# automate
# machine-controlled
# automatise
# automatonlike
# automatic_pistol
# reflexive
# automatic_rifle
# machinelike
# robotlike
# machine_rifle
# self-propelling
# self-propelled
# self-sufficiency
# self-direction
# self-reliance
# automatic_pilot
# robot_pilot
# post-mortem
# post-mortem_examination
# postmortem_examination
# PM
# necropsy
# supplementary
# handiness
# accessibility
# availableness
# uncommitted
# useable
# roll_down
# boulevard
# modal
# middling
# average_out
# averting
# antipathy
# distaste
# forfend
# turn_away
# fend_off
# head_off
# forefend
# obviate
# ward_off
# stave_off
# debar
# airmanship
# air_power
# aeronaut
# airman
# devouring
# zealous
# esurient
# avocado_pear
# aguacate
# avocado_tree
# Persea_Americana
# alligator_pear
# keep_off
# shunning
# dodging
# turning_away
# wakening
# waking_up
# laurels
# honour
# awarding
# accolade
# cognisant
# cognizant
# sentience
# cognisance
# knowingness
# cognizance
# veneration
# awestricken
# awestruck
# direful
# awfully
# frightfully
# terribly
# cumbersome
# ill-chosen
# ungainly
# unenviable
# ill_at_ease
# inapt
# bunglesome
# ineptness
# clumsiness
# stiffness
# slowness
# nuisance_value
# gracelessness
# ineptitude
# cumbersomeness
# unwieldiness
# maladroitness
# sunblind
# sunshade
# ax
# Axis
# axis_of_rotation
# bloc
# axis_vertebra
# babble_out
# babbling
# spill_the_beans
# burble
# let_the_cat_out_of_the_bag
# lallation
# blather
# guggle
# tattle
# blab_out
# blither
# smatter
# blether
# gurgle
# cocker
# featherbed
# coddle
# mollycoddle
# cosset
# baby-sitter
# bach
# bachelor-at-arms
# unmarried_man
# knight_bachelor
# bachelor_girl
# rearwards
# dorsum
# backwards
# rearward
# backward
# plunk_for
# vertebral_column
# indorse
# bet_on
# backrest
# rachis
# plump_for
# book_binding
# back_up
# gage
# spinal_column
# basketball_backboard
# guts
# back_door
# back_entrance
# backcloth
# blowback
# backlash
# downplay
# background_signal
# screen_background
# play_down
# background_knowledge
# setting
# desktop
# backhanded
# backhand_stroke
# backhand_shot
# left-slanting
# rucksack
# back_pack
# haversack
# packsack
# back_end
# double_back
# fill-in
# backing
# reliever
# patronage
# musical_accompaniment
# backup_man
# stand-in
# computer_backup
# boondocks
# hinterland
# back_country
# Bacon
# Baron_Verulam
# Francis_Bacon
# Roger_Bacon
# Viscount_St._Albans
# Sir_Francis_Bacon
# 1st_Baron_Verulam
# bacterium
# spoilt
# speculative
# uncollectible
# badly
# spoiled
# high-risk
# forged
# Wisconsinite
# Badger
# beleaguer
# mischievousness
# severeness
# naughtiness
# traveling_bag
# bagful
# old_bag
# travelling_bag
# udder
# cup_of_tea
# beigel
# loose-fitting
# travelling_salesman
# roadman
# commercial_traveler
# traveling_salesman
# commercial_traveller
# bail_bond
# tantalize
# razz
# tantalise
# come-on
# sweetener
# broil
# bakeshop
# bakehouse
# equilibrise
# Libra
# Balance
# symmetricalness
# equaliser
# Libra_the_Balance
# equilibrate
# equipoise
# residuum
# proportionality
# counterweight
# counterpoise
# counterbalance
# balance_wheel
# equilibrize
# Libra_the_Scales
# denudate
# bald-headed
# bald-pated
# denuded
# baldpate
# baldhead
# Bale
# Basel
# Basle
# musket_ball
# Ball
# ballock
# testis
# orchis
# Lucille_Ball
# glob
# bollock
# barretter
# ballast_resistor
# light_ballast
# danseuse
# concert_dance
# ball_game
# new_ballgame
# ballistic_trajectory
# billow
# balloting
# voting
# approximate_range
# baseball_player
# Biro
# ballpen
# ballpoint_pen
# dance_hall
# dance_palace
# unguent
# unction
# around_the_bend
# round_the_bend
# cracked
# kookie
# crackers
# bats
# whacky
# nuts
# barmy
# Bam
# ostracize
# banning
# Bachelor_of_Arts_in_Nursing
# BAN
# proscription
# ostracise
# forbiddance
# cast_out
# blackball
# banana_tree
# banding
# dance_orchestra
# isthmus
# striation
# dance_band
# stria
# bandana
# brigand
# outdoor_stage
# have_it_away
# make_love
# be_intimate
# have_sex
# sleep_with
# have_intercourse
# bonk
# have_a_go_at_it
# do_it
# sleep_together
# smasher
# slapdash
# spang
# make_out
# get_laid
# get_it_on
# lie_with
# eff
# have_it_off
# relegate
# balustrade
# handrail
# bannister
# balusters
# banking_company
# savings_bank
# bank_building
# money_box
# camber
# depository_financial_institution
# banking_concern
# coin_bank
# cant
# insolvent
# belly-up
# streamer
# banshie
# chaff
# josh
# backchat
# raillery
# give-and-take
# baptise
# block_up
# legal_profession
# Browning_automatic_rifle
# block_off
# legal_community
# BAR
# taproom
# ginmill
# churl
# tike
# uncivilised
# Goth
# boor
# barbeque
# cook_out
# bristled
# biting
# bristly
# setaceous
# burry
# briery
# burred
# nipping
# spiny
# setose
# briary
# mordacious
# barbellate
# barb
# Barber
# Samuel_Barber
# caparison
# barde
# unsheathed
# unembellished
# stark
# denude
# unornamented
# au_naturel
# stripped
# scanty
# barefooted
# shoeless
# throw_up
# vomit_up
# retch
# disgorge
# be_sick
# regurgitate
# spue
# vomitus
# regorge
# upchuck
# dicker
# flatboat
# lighter
# thrust_ahead
# hoy
# push_forward
# barytone
# baritone_voice
# baritone_horn
# atomic_number_56
# Ba
# barque
# mixologist
# barkeeper
# barleycorn
# b
# cirriped
# cirripede
# Branta_leucopsis
# barnacle_goose
# business_leader
# top_executive
# magnate
# big_businessman
# barrage_fire
# bombard
# shelling
# outpouring
# cask
# bbl
# gun_barrel
# barrelful
# barricado
# swop
# al-Qa'ida
# meanspirited
# substructure
# free-base
# al-Qaida
# radix
# Base
# alkali
# baseborn
# understructure
# base_of_operations
# root_word
# nucleotide
# basal
# Qaeda
# found
# al-Qaeda
# baseball_game
# service_line
# whap
# whop
# blate
# introductory
# canonical
# BASIC
# canonic
# bedrock
# fundamental_principle
# basic_principle
# rudiments
# fundamentals
# sweet_basil
# Basil_of_Caesarea
# Basil
# St._Basil
# St._Basil_the_Great
# Basil_the_Great
# catchment_basin
# drainage_basin
# washbowl
# catchment_area
# drainage_area
# river_basin
# basinful
# washstand
# watershed
# washbasin
# savour
# field_goal
# basketful
# handbasket
# basketball_hoop
# basketball_game
# hoops
# bass_part
# basso
# freshwater_bass
# bass_voice
# sea_bass
# love_child
# illegitimate_child
# phoney
# by-blow
# chiropteran
# at-bat
# cricket_bat
# squash_racquet
# squash_racket
# drub
# plenty
# spate
# hatful
# mickle
# peck
# tidy_sum
# good_deal
# passel
# slew
# quite_a_little
# muckle
# great_deal
# bathing_tub
# Bath
# bathing_machine
# bagnio
# washup
# john
# lav
# truncheon
# billystick
# billy_club
# billy
# large_number
# plurality
# knock_about
# baste
# dinge
# batsman
# beat-up
# beaten-up
# banging
# electric_battery
# assault_and_battery
# stamp_battery
# field_of_honor
# field_of_battle
# crenelation
# battlement
# crenellation
# battlewagon
# gaud
# fallal
# bangle
# gewgaw
# yawp
# true_laurel
# bay_tree
# embayment
# Laurus_nobilis
# bay_laurel
# bazar
# make_up
# personify
# atomic_number_4
# glucinium
# Be
# embody
# comprise
# pharos
# beacon_light
# beacon_fire
# radio_beacon
# beading
# beadwork
# astragal
# spangled
# jewelled
# beadlike
# buttony
# gemmed
# sequined
# spangly
# jeweled
# buttonlike
# neb
# nib
# schnoz
# nozzle
# snoot
# schnozzle
# honker
# irradiation
# radio_beam
# electron_beam
# ray_of_light
# light_beam
# shaft_of_light
# beam_of_light
# ray
# balance_beam
# bean_plant
# edible_bean
# beany
# give_birth
# gestate
# have_a_bun_in_the_oven
# supportable
# endurable
# sufferable
# face_fungus
# byssus
# barbate
# whiskery
# whiskered
# bewhiskered
# toter
# pallbearer
# comportment
# armorial_bearing
# mien
# heraldic_bearing
# busby
# shako
# god-awful
# bestial
# cadence
# pulsate
# beat_out
# bushed
# metre
# trounce
# wash_up
# musical_rhythm
# tucker
# overreach
# all_in
# beat_up
# outfox
# work_over
# ticktock
# tucker_out
# pulsation
# thrum
# ticktack
# ravisher
# mantrap
# lulu
# beaut
# silk_hat
# Beaver
# opera_hat
# top_hat
# topper
# Oregonian
# dress_hat
# castor
# high_hat
# beaver_fur
# stovepipe
# beaver_away
# kip_down
# hit_the_hay
# hit_the_sack
# sack_out
# go_to_sleep
# go_to_bed
# crawl_in
# turn_in
# bedding_material
# bed_clothing
# bedclothes
# sleeping_accommodation
# bedchamber
# sleeping_room
# bedcover
# bed_covering
# counterpane
# bed_cover
# bellyache
# beef_cattle
# boeuf
# claxon
# beetling
# overhang
# bechance
# betide
# mendicant
# pauperize
# pauperise
# get_down
# Begin
# start_out
# lead_off
# Menachem_Begin
# tiro
# tyro
# founding_father
# rootage
# starting_time
# showtime
# outset
# get-go
# commencement
# demeanour
# deportment
# behaviour
# doings
# behavioural
# lay_eyes_on
# ecru
# belching
# eructation
# eruct
# burping
# extravasate
# worshipper
# truster
# worshiper
# pick_at
# derogate
# denigrate
# Alexander_Bell
# Melville_Bell
# gong
# Bell
# ship's_bell
# Vanessa_Stephen
# Vanessa_Bell
# bell_shape
# campana
# Alexander_Melville_Bell
# Alexander_Graham_Bell
# scrapper
# war-ridden
# combatant
# battler
# warring
# hollering
# holla
# hollo
# holloa
# Solomon_Bellow
# yowl
# Saul_Bellow
# bellowing
# Bellow
# roaring
# belly_out
# paunch
# umbilicus
# omphalus
# belly_button
# omphalos
# belong_to
# belonging
# holding
# dear
# dearest
# belt_ammunition
# belted_ammunition
# swath
# whang
# belt_out
# white_whale
# white_sturgeon
# Delphinapterus_leucas
# Acipenser_huso
# hausen
# Bench
# judiciary
# work_bench
# workbench
# bending
# bend_dexter
# plication
# flexure
# Bend
# deform
# benefactive_role
# donee
# do_good
# benefaction
# large-hearted
# good-hearted
# freehearted
# philanthropic
# eleemosynary
# kindly
# openhearted
# beneficent
# benignant
# benzol
# benzine
# bereave
# grief-stricken
# bereaved_person
# bereft
# sorrowing
# berserker
# built_in_bed
# mooring
# billet
# moorage
# tie_up
# entreat
# adjure
# best_seller
# stakes
# genus_Beta
# Beta
# give_away
# tell_on
# lead_astray
# bewray
# cheat_on
# perfidy
# potable
# drinkable
# mazed
# baffled
# befuddled
# mixed-up
# bemused
# discombobulate
# at_sea
# bemuse
# predetermine
# preconception
# one-sided
# slanted
# coloured
# tipple
# Bible
# Word
# Holy_Writ
# Word_of_God
# Holy_Scripture
# Good_Book
# Scripture
# Christian_Bible
# Book
# scriptural
# hydrogen_carbonate
# bicentenary
# brabble
# bickering
# pettifog
# niggle
# pettifoggery
# tiff
# with_child
# bragging
# liberal
# vauntingly
# enceinte
# boastfully
# bounteous
# self-aggrandizing
# freehanded
# braggart
# magnanimous
# expectant
# crowing
# bighearted
# cock-a-hoop
# braggy
# boastful
# swelled
# giving
# openhanded
# self-aggrandising
# gravid
# vainglorious
# Bighorn_River
# Rocky_Mountain_sheep
# Ovis_canadensis
# bighorn_sheep
# Bighorn
# Rocky_Mountain_bighorn
# cimarron
# dogmatism
# Bikini
# two-piece
# isobilateral
# two-sided
# bilaterally_symmetrical
# bilaterally_symmetric
# bilge_water
# take_in_water
# banker's_bill
# greenback
# handbill
# bank_bill
# broadsheet
# government_note
# Federal_Reserve_note
# banknote
# throwaway
# billhook
# bank_note
# vizor
# placard
# eyeshade
# posting
# hoarding
# 1000000000000
# one_thousand_million
# 1000000000
# jillion
# one_million_million
# binful
# BIN
# ABA_transit_number
# bank_identification_number
# binary_program
# binary_star
# double_star
# tie_down
# truss
# constipate
# obligate
# reaper_binder
# ring-binder
# ski_binding
# bandaging
# dressing
# overeat
# gourmandize
# overindulge
# scarf_out
# gormandise
# ingurgitate
# engorge
# satiate
# overgorge
# gormandize
# pig_out
# englut
# splurge
# glut
# keno
# beano
# field_glasses
# opera_glasses
# life_story
# life_history
# biologic
# life_scientist
# biota
# biological_science
# birch_rod
# birchen
# birken
# birch_tree
# birdwatch
# shuttlecock
# razzing
# boo
# Bronx_cheer
# nascence
# giving_birth
# parturition
# nativity
# nascency
# natal_day
# nevus
# place_of_origin
# place_of_birth
# provenience
# provenance
# patrimony
# cooky
# epicene
# bisexual_person
# fleck
# mo
# seize_with_teeth
# backbite
# catty
# cattish
# insect_bite
# chomp
# collation
# raciness
# pungency
# sharpness
# bitingly
# acrimonious
# bitterly
# piercingly
# rancor
# tartness
# acerbity
# rancour
# acrimony
# jaundice
# thorniness
# staff_vine
# woody_nightshade
# waxwork
# Solanum_dulcamara
# false_bittersweet
# shrubby_bittersweet
# deadly_nightshade
# poisonous_nightshade
# semisweet
# bittersweet_nightshade
# climbing_nightshade
# American_bittersweet
# climbing_bittersweet
# Celastrus_scandens
# bittie
# weeny
# teensy-weensy
# teentsy
# itty-bitty
# weensy
# itsy-bitsy
# teeny-weeny
# flakey
# gonzo
# off-the-wall
# outre
# outlandish
# prate
# twaddle
# maunder
# tittle-tattle
# clack
# prattle
# palaver
# blabber
# gibber
# gabble
# piffle
# telltale
# taleteller
# talebearer
# pitch-dark
# Shirley_Temple_Black
# Shirley_Temple
# calamitous
# black-market
# melanize
# Black_person
# ignominious
# inkiness
# Negroid
# lightlessness
# pitch-black
# pitch_blackness
# melanise
# inglorious
# blackened
# mordant
# smutty
# blackamoor
# Black
# Negro
# Joseph_Black
# total_darkness
# nigrify
# smuggled
# blackberry_bush
# merle
# ouzel
# Turdus_merula
# ousel
# merl
# European_blackbird
# New_World_blackbird
# chalkboard
# sear
# char
# pirate_flag
# jack_oak
# Jolly_Roger
# blackjack_oak
# Quercus_marilandica
# vingt-et-un
# black_flag
# cosh
# twenty-one
# black_book
# shitlist
# extortionist
# extortioner
# dimout
# brownout
# vesica
# leaf_blade
# vane
# incrimination
# blasted
# find_fault
# deuced
# damned
# darned
# blamed
# inculpation
# goddam
# inculpable
# irreproachable
# unimpeachable
# politic
# flavorless
# flavourless
# savourless
# savorless
# vapid
# lacuna
# blank_shell
# across-the-board
# panoptic
# all-embracing
# all-inclusive
# encompassing
# all-encompassing
# din
# clamor
# blaring
# cacophony
# profanation
# knock_down
# good_time
# pillory
# chargeman
# clamant
# strident
# blazing
# clamorous
# vociferous
# blaze_out
# blaze_away
# sports_jacket
# sport_coat
# sports_coat
# sport_jacket
# decolorise
# bleaching_agent
# decolorize
# decolourise
# discolourise
# bleach_out
# discolorize
# discolorise
# decolor
# whitener
# decolour
# decolourize
# blanching_agent
# cutting
# shed_blood
# phlebotomize
# phlebotomise
# hemophile
# haemophile
# haemophiliac
# hemophiliac
# disfigure
# deface
# meld
# immix
# blending
# coalesce
# portmanteau_word
# conflate
# portmanteau
# blend_in
# commingle
# intermix
# intermingle
# immingle
# liquidizer
# liquidiser
# consecrate
# sanctify
# hallow
# blest
# beatified
# Blessed
# grace
# benediction
# blue_cheese
# Colonel_Blimp
# sausage_balloon
# Blimp
# unsighted
# subterfuge
# unreasoning
# blindfolded
# glary
# fulgent
# glaring
# cecity
# sightlessness
# eye_blink
# nictitation
# blinking
# nictation
# winkle
# nictate
# blink_away
# winking
# nictitate
# radar_target
# pip
# walking_on_air
# cloud_nine
# blissfulness
# seventh_heaven
# scald
# vesicate
# bleb
# bulla
# vesication
# red-hot
# vesiculation
# blistery
# safety_blitz
# linebacker_blitzing
# blitzkrieg
# kibosh
# stymie
# choke_up
# blocking
# parry
# pulley-block
# stymy
# obturate
# occlusion
# cylinder_block
# occlude
# auction_block
# city_block
# draw_a_blank
# immobilise
# pulley_block
# immobilize
# mental_block
# engine_block
# close_up
# blank_out
# seal_off
# encirclement
# smash_hit
# megahit
# loggerhead
# dumbass
# dunderhead
# lunkhead
# numskull
# muttonhead
# fuckhead
# web_log
# blighter
# fella
# light-haired
# profligate
# rakehell
# roue
# battue
# bloodletting
# sleuthhound
# gore
# blood_stream
# sanguinary
# bloody-minded
# bally
# crashing
# all-fired
# salad_days
# heyday
# bloom_of_youth
# rosiness
# efflorescence
# bloomer
# flub
# drawers
# foul-up
# botch
# pratfall
# fuckup
# bungle
# boo-boo
# blooper
# blossom_forth
# blossom_out
# smirch
# daub
# charge_sheet
# day_book
# rap_sheet
# blotting_paper
# police_blotter
# ball_up
# shove_off
# botch_up
# foul_up
# bollix_up
# go_down_on
# bodge
# blow_out
# black_eye
# bollix
# bobble
# bumble
# louse_up
# be_adrift
# screw_up
# nose_candy
# bollocks_up
# burn_out
# C
# shoot_a_line
# swash
# fuck_up
# shove_along
# bluster
# vaunt
# mishandle
# mess_up
# gasconade
# muck_up
# fellate
# pufferfish
# sea_squab
# puffer
# globefish
# cock_sucking
# walkaway
# gala_affair
# shoo-in
# laugher
# blowlamp
# avoirdupois
# blub
# blubber_out
# fatness
# snuffle
# sniffle
# snivel
# blueish
# blue_devil
# disconsolate
# blue_air
# Amytal
# blue_sky
# gamey
# drear
# puritanic
# bluing
# puritanical
# blueing
# downcast
# wild_blue_yonder
# bluish
# gamy
# dispirited
# blueness
# down
# downhearted
# blue_angel
# low-spirited
# amobarbital_sodium
# risque
# down_in_the_mouth
# blueberry_bush
# fairy_bluebird
# Bluegrass_Country
# blue_grass
# Bluegrass_Region
# Bluegrass
# blue_devils
# vapours
# megrims
# vapors
# bluff_out
# four_flush
# blunder_out
# drop_the_ball
# blurt_out
# point-blank
# benumb
# deaden
# straight-from-the-shoulder
# frank
# plainspoken
# free-spoken
# smutch
# obnubilate
# glaze_over
# film_over
# blear
# blurred
# muzzy
# bleary
# redden
# feather_boa
# wild_boar
# Sus_scrofa
# circuit_board
# circuit_card
# control_panel
# gameboard
# control_board
# add-in
# dining_table
# display_panel
# plug-in
# instrument_panel
# display_board
# roomer
# lodger
# embarkation
# embarkment
# council_chamber
# jactitation
# self-praise
# boasting
# gravy_boat
# gravy_holder
# sauceboat
# yachting
# shipload
# carload
# waterman
# boater
# Lynx_rufus
# bay_lynx
# bobsleigh
# bob
# presage
# augur
# auspicate
# betoken
# foreshadow
# prefigure
# portend
# somatic
# soundbox
# eubstance
# physical_structure
# organic_structure
# consistence
# dead_body
# bog_down
# peat_bog
# bogy
# bogie
# bugbear
# bugaboo
# Romany
# Gipsy
# Romani
# Bohemian
# Rommany
# Roma
# Gypsy
# moil
# seethe
# furuncle
# roil
# boiling_point
# steam_boiler
# bold_face
# boldface
# bullock_block
# bolt_of_lightning
# stiffly
# deadbolt
# absquatulate
# decamp
# go_off
# bolt_out
# abscond
# make_off
# run_out
# beetle_off
# rigidly
# run_off
# flush_it
# bomb_calorimeter
# hoagy
# submarine_sandwich
# hoagie
# Italian_sandwich
# hero_sandwich
# Cuban_sandwich
# zep
# poor_boy
# manna_from_heaven
# windfall
# bunce
# gold_rush
# thrall
# thralldom
# thraldom
# draw_together
# bring_together
# soldering
# bondman
# bondswoman
# swot
# grind_away
# swot_up
# osseous_tissue
# bone_up
# os
# mug_up
# debone
# off-white
# balefire
# poke_bonnet
# cowling
# cowl
# sightly
# comely
# bonnie
# fillip
# osteal
# pinched
# boney
# wasted
# haggard
# osseous
# gaunt
# cadaverous
# emaciated
# titty
# knocker
# boogie-woogie
# rule_book
# leger
# playscript
# book_of_account
# account_book
# al-Qur'an
# record_book
# Quran
# Koran
# clerking
# leaflet
# bookmarker
# bookstall
# pedant
# microphone_boom
# boom_out
# baby_boomer
# throwing_stick
# throw_stick
# hike_up
# cost_increase
# booster_shot
# booster_rocket
# takeoff_rocket
# takeoff_booster
# plugger
# relay_transmitter
# booster_amplifier
# booster_unit
# relay_link
# relay_station
# booster_dose
# recall_dose
# booster_station
# lifter
# iron_boot
# iron_heel
# the_boot
# kicking
# John_Wilkes_Booth
# Booth
# corn_liquor
# moonshiner
# dirty_money
# strong_drink
# John_Barleycorn
# hard_drink
# fuddle
# hard_liquor
# spirits
# BoP
# Federal_Bureau_of_Prisons
# moulding
# delimitation
# molding
# boundary_line
# mete
# frame_in
# environ
# bore
# world-weary
# tedium
# drilling
# ho-hum
# irksome
# oil_production
# wearisome
# deadening
# Born
# Max_Born
# B
# atomic_number_5
# genus_Bos
# emboss
# political_boss
# Bos
# party_boss
# hirer
# autocratic
# magisterial
# high-and-mighty
# peremptory
# botanic
# phytology
# flora
# disoblige
# put_out
# trouble_oneself
# discommode
# incommode
# inconvenience_oneself
# bottleful
# nursing_bottle
# feeding_bottle
# chokepoint
# constriction
# undersurface
# merchant_ship
# bottom_of_the_inning
# underside
# merchantman
# bottomland
# resile
# bounciness
# leaping
# jounce
# reverberate
# take_a_hop
# saltation
# bouncing
# chucker-out
# springy
# bounds
# indentured
# trammel
# destined
# bandaged
# articled
# apprenticed
# bountifulness
# amplitude
# Bounty
# H.M.S._Bounty
# bounteousness
# posy
# nosegay
# redolence
# fragrancy
# Bourbon
# Bourbon_dynasty
# dress_shop
# bovid
# bow_down
# obeisance
# accede
# bowknot
# bowing
# prow
# give_in
# curtain_call
# bowlful
# bowling_ball
# pipe_bowl
# derby_hat
# bowler_hat
# plug_hat
# derby
# box_seat
# boxwood
# loge
# boxful
# Boxer
# pugilist
# bagger
# boxershorts
# underdrawers
# fisticuffs
# packing
# pugilism
# male_child
# swain
# beau
# young_man
# schoolboyish
# boylike
# boysenberry_bush
# zany
# bandeau
# orthodontic_braces
# gallus
# couplet
# distich
# bracing
# suspender
# duad
# dyad
# stabilise
# bitstock
# braces
# watchband
# watchstrap
# wristband
# watch_bracelet
# wall_bracket
# angle_bracket
# square_bracket
# bracket_out
# line-shooting
# vaporing
# braiding
# gold_braid
# plait
# pleach
# tress
# encephalon
# mental_capacity
# brainiac
# learning_ability
# Einstein
# brainpower
# nous
# brainwave
# smart_as_a_whip
# pasture_brake
# Pteridium_aquilinum
# bracken
# furcate
# ramify
# ramification
# offshoot
# mark
# firebrand
# stigmatise
# marque
# trade_name
# brand_name
# brandmark
# stigmatize
# nervy
# boldness
# memorial_tablet
# brass_instrument
# brass_section
# holy_terror
# little_terror
# brave_out
# braw
# braveness
# courageousness
# fearlessness
# wrangle
# free-for-all
# brawniness
# muscularity
# sinew
# heftiness
# transgress
# falling_out
# infract
# go_against
# gelt
# lolly
# shekels
# dinero
# simoleons
# clams
# wampum
# breadstuff
# moolah
# staff_of_life
# pelf
# lucre
# boodle
# comprehensiveness
# largeness
# come_apart
# faulting
# good_luck
# split_up
# fall_in
# cave_in
# wear_out
# break_dance
# break_of_serve
# dampen
# give_way
# break_off
# breakage
# intermit
# snap_off
# get_around
# give_out
# recrudesce
# gaolbreak
# fall_apart
# time_out
# bring_out
# break_away
# go_bad
# breaking
# break_in
# let_out
# get_out
# prisonbreak
# open_frame
# break_out
# demote
# happy_chance
# kick_downstairs
# geological_fault
# prison-breaking
# conk_out
# break-dance
# breakout
# let_on
# separatist
# fissiparous
# breaking_away
# equipment_failure
# partitioning
# crack-up
# dislocation
# breakers
# ledgeman
# circuit_breaker
# dissolution
# front
# white_meat
# breathing_space
# breathing_place
# intimation
# breathing_spell
# breathing_time
# catch_one's_breath
# take_a_breath
# take_a_breather
# suspire
# pass_off
# respire
# snorkel_breather
# schnorkel
# schnorchel
# dyspneal
# dyspnoeic
# dyspnoeal
# pulseless
# dyspneic
# rear_of_tube
# rear_of_barrel
# engender
# stock_breeder
# facts_of_life
# gentility
# bringing_up
# fostering
# fosterage
# rearing
# genteelness
# raising
# duck_soup
# piece_of_cake
# child's_play
# walkover
# blowy
# crony
# blood_brother
# Brother
# brewage
# eglantine
# sweetbriar
# brier
# catbrier
# tree_heath
# Rosa_eglanteria
# briar_pipe
# bullbrier
# sweetbrier
# greenbrier
# horse_brier
# Smilax_rotundifolia
# horse-brier
# Erica_arborea
# grease_one's_palms
# nuptial
# Saint_Brigid
# Bride
# St._Bride
# Brigid
# Saint_Bridget
# Saint_Bride
# Bridget
# St._Brigid
# St._Bridget
# maid_of_honor
# bridgework
# bridge_deck
# bridge_over
# nosepiece
# bridge_circuit
# legal_brief
# abbreviated
# brilliantly
# lustrous
# undimmed
# brightly
# burnished
# clear_up
# lighten_up
# light_up
# luminosity
# smartness
# brightness_level
# luminousness
# luminance
# splendour
# grandness
# native_sulfur
# native_sulphur
# bring_in
# make_for
# refreshful
# brisken
# brisk_up
# brickle
# toffy
# brickly
# unannealed
# breastpin
# unsubtle
# large-minded
# unspecific
# propagate
# programme
# circularise
# disseminate
# circularize
# pass_around
# broadcast_medium
# branch_out
# diversify
# tirade
# philippic
# Brassica_oleracea_italica
# humiliated
# disordered
# wiped_out
# unkept
# humbled
# busted
# broken_in
# heartsick
# stony-broke
# skint
# broke
# stone-broke
# brokerage_firm
# brokerage_house
# securities_firm
# cliche
# platitude
# banality
# bronc
# broncho
# bronzy
# grizzle
# incubate
# bulk_large
# meditative
# musing
# ruminative
# pondering
# contemplative
# pensiveness
# broody
# pensive
# Scots_heather
# ling
# Calluna_vulgaris
# heather
# broom_handle
# house_of_prostitution
# bawdyhouse
# sporting_house
# bordello
# house_of_ill_repute
# sodality
# trade_union
# labor_union
# trades_union
# fraternal
# brotherlike
# supercilium
# chocolate-brown
# Robert_Brown
# Brown
# brownness
# Brown_University
# dark-brown
# embrown
# browned
# John_Brown
# brownish
# browsing
# contuse
# spite
# brunet
# brushing
# brushwood
# coppice
# copse
# light_touch
# roughshod
# barbarous
# fell
# ferociousness
# viciousness
# savagery
# barbarism
# house_of_cards
# spumy
# foamy
# frothy
# effervescing
# bubbling
# foaming
# dollar_bill
# one_dollar_bill
# shoot_down
# Pearl_Buck
# vaulting_horse
# Pearl_Sydenstricker_Buck
# sawhorse
# Buck
# sawbuck
# long_horse
# vaquero
# buckeroo
# bucketful
# crumple
# bird_shot
# duck_shot
# Polygonum_fagopyrum
# Fagopyrum_esculentum
# bud
# John_Donald_Budge
# Budge
# Don_Budge
# burnish
# devotee
# yellowish_brown
# furbish
# raw_sienna
# caramel_brown
# buffer_zone
# polisher
# buffer_storage
# buffer_store
# cowcatcher
# snack_counter
# sideboard
# snack_bar
# merry_andrew
# hemipteran
# microbe
# hemipteron
# hemipterous_insect
# sodomise
# sodomize
# sodomite
# sodomist
# roadster
# bugleweed
# ramp_up
# work_up
# habitus
# body-build
# constructor
# detergent_builder
# medulla_oblongata
# electric-light_bulb
# light_bulb
# incandescent_lamp
# electric_light
# medulla
# swelling
# jut
# extrusion
# protrusion
# protrude
# bulge_out
# bug_out
# excrescence
# prominence
# protuberance
# pop_out
# gibbousness
# gibbosity
# bull's_eye
# Samson
# Taurus
# Taurus_the_Bull
# bull_through
# strapper
# talk_through_one's_hat
# dogshit
# papal_bull
# Bull
# bruiser
# Irish_bull
# English_bulldog
# dozer
# bullet_train
# unshakable
# watertight
# unassailable
# toreador
# Rana_catesbeiana
# bullet-headed
# loud-hailer
# loud_hailer
# detention_cell
# detention_centre
# yobbo
# strong-arm
# slap-up
# yobo
# ballyrag
# cracking
# not_bad
# yob
# boss_around
# push_around
# hector
# swagger
# bang-up
# bullyrag
# browbeat
# smashing
# corking
# scum_bag
# chintzy
# lounge_about
# waste_one's_time
# so-and-so
# rotter
# git
# arse_about
# fuck_off
# frig_around
# lounge_around
# stinkpot
# loll
# loll_around
# tinny
# do-nothing
# dirty_dog
# layabout
# bum_about
# arse_around
# idler
# bum_around
# cadge
# humblebee
# dislodge
# jolting
# jolty
# rocky
# bunch_up
# clustering
# bunch_together
# practice_bundling
# sheaf
# big_bucks
# bundle_up
# big_money
# megabucks
# bungee_cord
# turn_tail
# bunkum
# lam
# nonsensicality
# run_away
# guff
# head_for_the_hills
# bunk_bed
# fly_the_coop
# buncombe
# scarper
# feed_bunk
# hokum
# take_to_the_woods
# meaninglessness
# hightail_it
# sand_trap
# bunny_rabbit
# bunny_girl
# buoy_up
# onus
# encumbrance
# weight_down
# burthen
# loading
# incumbrance
# loaded_down
# heavy-laden
# chest_of_drawers
# bureaucratism
# administrative_official
# Burger
# beefburger
# Warren_E._Burger
# Warren_Earl_Burger
# Warren_Burger
# interment
# sepulture
# entombment
# inhumation
# burying
# sendup
# spoof
# lampoon
# pasquinade
# burn_down
# cauterise
# burn_mark
# burn_off
# cauterize
# burn_up
# combust
# incinerate
# burning
# Aaron_Burr
# bur
# Burr
# break_open
# fusillade
# salvo
# bristle
# flare-up
# abound
# entomb
# swallow_up
# eat_up
# lay_to_rest
# inter
# inhume
# bus_topology
# charabanc
# autobus
# passenger_vehicle
# omnibus
# double-decker
# jitney
# busbar
# motorcoach
# motorbus
# waiter's_assistant
# George_H.W._Bush
# President_George_W._Bush
# Bush
# George_Herbert_Walker_Bush
# Dubyuh
# crotch_hair
# George_Walker_Bush
# George_Bush
# bush-league
# Dubya
# President_Bush
# George_W._Bush
# pubic_hair
# chaparral
# Vannevar_Bush
# shrub
# furbish_up
# shaggy-haired
# shaggy-coated
# shaggy
# byplay
# business_organisation
# business_sector
# stage_business
# line_of_work
# commercial_enterprise
# business_enterprise
# business_organization
# business_concern
# man_of_affairs
# fizzle
# female_chest
# baby_buster
# bronco_buster
# broncobuster
# bustle_about
# meddlesome
# meddling
# busybodied
# in_use
# interfering
# officious
# nosy-parker
# quidnunc
# nosey-parker
# meatman
# sad_sack
# botcher
# bumbler
# stumbler
# blunderer
# butch
# fumbler
# bungler
# slaughterer
# Butler
# pantryman
# Samuel_Butler
# butt_end
# coffin_nail
# cigaret
# bunt
# butt_joint
# crowfoot
# kingcup
# goldcup
# butter-flower
# butterflower
# dally
# butterfly_stroke
# chat_up
# coquette
# philander
# coquet
# buttock
# clit
# push_button
# vendee
# purchaser
# emptor
# Cathartes_aura
# turkey_vulture
# Buteo_buteo
# turkey_buzzard
# ringway
# ring_road
# beltway
# short-circuit
# electrical_shunt
# go_around
# tangled
# knotty
# convoluted
# Byzantine
# involved
# tortuous
# cabriolet
# floorshow
# night_club
# floor_show
# nightspot
# Brassica_oleracea
# chou
# cultivated_cabbage
# Cabernet
# Cabernet_Sauvignon
# storage_locker
# cablegram
# cable_system
# cable_length
# transmission_line
# cable_television
# cable's_length
# cable_television_service
# overseas_telegram
# ship's_galley
# cookhouse
# cabin_car
# hive_up
# memory_cache
# squirrel_away
# lay_away
# remains
# golf_caddie
# caddy
# plebe
# caffein
# Cage
# cage_in
# John_Milton_Cage_Jr.
# coop
# John_Cage
# batting_cage
# canny
# cagy
# chary
# cahoot
# patty
# calamary
# cataclysm
# atomic_number_20
# Ca
# count_on
# work_out
# cypher
# figuring
# computation
# estimator
# figurer
# calculating_machine
# reckoner
# infinitesimal_calculus
# tophus
# concretion
# sura
# calfskin
# calibre
# callisthenics
# birdsong
# send_for
# Call
# call_up
# outcry
# birdcall
# call_off
# shout_out
# phone_call
# margin_call
# telephone_call
# vociferation
# call_in
# call_option
# caller-up
# phoner
# telephoner
# caller-out
# chirography
# calloused
# indurate
# pachydermatous
# thickened
# calmness
# equanimity
# chill_out
# calm_air
# tranquillize
# calm_down
# quieten
# still
# cool_it
# composure
# becalm
# tranquillise
# simmer_down
# unagitated
# tranquilize
# cool_off
# settle_down
# comradery
# chumminess
# comradeship
# comradeliness
# television_camera
# photographic_camera
# tv_camera
# cinematographer
# camera_operator
# camo
# encamp
# bivouac
# camp_down
# cantonment
# camp_out
# campy
# coterie
# ingroup
# encampment
# inner_circle
# summer_camp
# refugee_camp
# political_campaign
# military_campaign
# take_the_field
# hunting_expedition
# camping_bus
# motor_home
# tenting
# bivouacking
# camping_ground
# camping_site
# campground
# camping_area
# crapper
# give_the_sack
# commode
# tin_can
# force_out
# canful
# give_the_axe
# send_away
# can_buoy
# epithelial_duct
# canalize
# canalise
# stoolpigeon
# stoolie
# canary-yellow
# stool_pigeon
# snitcher
# canary_yellow
# fink
# canary_bird
# strike_down
# Crab
# Cancer
# Cancer_the_Crab
# malignant_neoplastic_disease
# genus_Cancer
# heart-to-heart
# electioneering
# candidature
# campaigning
# campaigner
# standard_candle
# candela
# taper
# wax_light
# cd
# candle_flame
# candle_holder
# fair-mindedness
# frankness
# candidness
# forthrightness
# candour
# directness
# confect
# sugarcoat
# lambast
# lambaste
# flog
# canid
# cuspid
# laniary
# eye_tooth
# canine_tooth
# eyetooth
# dogtooth
# case_shot
# canister_shot
# cannister
# canker_sore
# marihuana
# ganja
# hemp
# transcribed
# tinned
# anthropophagus
# anthropophagite
# man-eater
# carom
# cannon_ball
# round_shot
# cantaloup_vine
# cantaloupe_vine
# cantaloup
# Cucumis_melo_cantalupensis
# mobile_canteen
# canvas_tent
# public_opinion_poll
# opinion_poll
# detonating_device
# pileus
# chapiter
# jacket_crown
# crownwork
# potentiality
# capableness
# adequate_to
# equal_to
# up_to
# electrical_capacity
# mental_ability
# capacitance
# capriole
# gambol
# working_capital
# upper-case_letter
# majuscule
# Capital
# Das_Kapital
# capital_letter
# Washington
# uppercase
# capitalist_economy
# capitalistic
# take_advantage
# capitalise
# cappuccino_coffee
# coffee_cappuccino
# ejector_seat
# space_capsule
# abridgement
# abridgment
# capsulate
# ejection_seat
# capsulise
# condensation
# encapsulate
# capsulize
# headwaiter
# police_chief
# maitre_d'hotel
# skipper
# police_captain
# maitre_d'
# chieftain
# sea_captain
# senior_pilot
# jailed
# engrossed
# imprisoned
# enwrapped
# confined
# absorbed
# wrapped
# immurement
# enslavement
# enamor
# bewitch
# enamour
# captivate
# becharm
# gaining_control
# beguile
# enchant
# elevator_car
# cable_car
# railroad_car
# railway_car
# railcar
# caramelized_sugar
# wagon_train
# carbon_copy
# atomic_number_6
# carbon_paper
# carburettor
# carcase
# bill_of_fare
# scorecard
# carte_du_jour
# calling_card
# identity_card
# batting_order
# visiting_card
# unlifelike
# composition_board
# Cardigan
# Cardigan_Welsh_corgi
# cardinal_grosbeak
# Cardinalis_cardinalis
# cardinal_number
# redbird
# carmine
# Richmondena_Cardinalis
# heart_specialist
# heart_surgeon
# give_care
# forethought
# tutelage
# calling
# slaphappy
# unworried
# freewheeling
# happy-go-lucky
# devil-may-care
# harum-scarum
# measured
# thrifty
# regardless
# sloppiness
# nonperformance
# lading
# mass_murder
# butchery
# clove_pink
# gillyflower
# Dianthus_caryophyllus
# funfair
# carrousel
# merry-go-round
# luggage_carousel
# whirligig
# luggage_carrousel
# chicane
# cavil
# carpal_bone
# wrist_bone
# woodworking
# passenger_car
# baby_buggy
# perambulator
# baby_carriage
# equipage
# pram
# go-cart
# pushchair
# mail_carrier
# newsboy
# letter_carrier
# carrier_wave
# aircraft_carrier
# immune_carrier
# attack_aircraft_carrier
# common_carrier
# flattop
# cultivated_carrot
# Daucus_carota_sativa
# air_sick
# airsick
# pushcart
# handcart
# hale
# corporate_trust
# gristle
# cartonful
# toon
# animated_cartoon
# cut_up
# chip_at
# cascade_down
# typesetter's_case
# fount
# typeface
# encase
# causa
# display_case
# compositor's_case
# vitrine
# instance
# guinea_pig
# pillow_slip
# grammatical_case
# caseful
# incase
# hard_currency
# John_Cash
# cash_in
# Cash
# Johnny_Cash
# immediate_payment
# hard_cash
# bank_clerk
# Jammu_and_Kashmir
# Kashmir
# Cashmere
# gambling_casino
# cassino
# jewel_casket
# contrive
# shake_off
# cast_of_characters
# cast_off
# dramatis_personae
# hurtle
# throw_off
# casting
# plaster_cast
# ...
# baccy
# yearling
# bambino
# bean_curd
# toilette
# permissiveness
# patient_of
# Lycopersicon_esculentum
# love_apple
# tomato_plant
# tom
# long_ton
# gross_ton
# short_ton
# net_ton
# tonus
# inflect
# pure_tone
# tonicity
# tone_of_voice
# pair_of_tongs
# natural_language
# tonic_water
# tonal
# accented
# quinine_water
# tool_case
# tool_chest
# tool_cabinet
# carousal
# booze-up
# odontalgia
# soup-strainer
# big_top
# upside
# top_off
# spinning_top
# circus_tent
# top_of_the_inning
# top_side
# round_top
# upper_side
# teetotum
# common_topaz
# false_topaz
# braless
# bare-breasted
# great_mullein
# woolly_mullein
# common_mullein
# Verbascum_thapsus
# flannel_mullein
# Aaron's_rod
# bedevilment
# badgering
# numbfish
# crampfish
# electric_ray
# torsion
# violent_stream
# holdall
# carryall
# tote_bag
# allude
# touch_modality
# cutaneous_senses
# sense_of_touch
# tinct
# skin_senses
# ruffianly
# street_fighter
# toupe
# touristry
# tourer
# holidaymaker
# tourney
# compression_bandage
# ticket_tout
# touter
# towage
# towboat
# townsfolk
# Town
# Ithiel_Town
# perniciousness
# toy_dog
# tracing
# trackable
# tracer_bullet
# cartroad
# caterpillar_track
# data_track
# cart_track
# caterpillar_tread
# trade_wind
# trade_in
# dealings
# tragical
# house_trailer
# railroad_train
# flight_simulator
# double-dealer
# treasonist
# two-timer
# double-crosser
# aerial_tramway
# tramway
# cable_tramway
# ropeway
# tramp_steamer
# hiker
# tramper
# tramp_down
# tread_down
# trampling
# quietude
# quietness
# antianxiety_agent
# tranquilliser
# tranquillizer
# ataractic_agent
# ataractic_drug
# dealing
# written_text
# transfer_of_training
# transferral
# transferee
# conveyance
# carry-over
# transubstantiate
# transmute
# metamorphose
# blood_transfusion
# evildoing
# fugacious
# ephemeral
# transitory
# short-lived
# transeunt
# electronic_transistor
# junction_transistor
# theodolite
# pass_across
# transportation_system
# move_through
# modulation
# interlingual_rendition
# translating_program
# transcriber
# transmitting
# transmittance
# transmittal
# transmission_system
# guileless
# transplantation
# organ_transplant
# transplanting
# tape_drive
# tape_transport
# conveyer_belt
# conveyor
# car_transporter
# conveyor_belt
# conveyer
# transexual
# transvestic
# cross-dresser
# rubbishy
# psychic_trauma
# locomotion
# move_around
# traveling
# change_of_location
# travelling
# traveller
# crosspiece
# transom
# trave
# traversal
# crossbeam
# punic
# perfidious
# perfidiousness
# tread-wheel
# treadwheel
# salt_mine
# high_treason
# subversiveness
# traitorousness
# lese_majesty
# hoarded_wealth
# financial_officer
# Department_of_the_Treasury
# Treasury_obligations
# United_States_Treasury
# Treasury
# exchequer
# Treasury_Department
# First_Lord_of_the_Treasury
# regale
# Sir_Herbert_Beerbohm_Tree
# shoetree
# tree_diagram
# Tree
# earth_tremor
# microseism
# entrench
# impinge
# encroach
# common_chord
# tribulation
# Triangle
# Triangulum
# trigon
# trilateral
# federation_of_tribes
# fast_one
# whoremaster
# whoremonger
# chicanery
# skulduggery
# hocus-pocus
# skullduggery
# jiggery-pokery
# wile
# hanky_panky
# hoaxer
# tricker
# prankster
# cut-up
# practical_joker
# velocipede
# trike
# small_beer
# wanton_away
# frivol
# piddle_away
# dawdling
# trigonometry
# gun_trigger
# one_million_million_million
# passementerie
# trimness
# tailored
# head_trip
# trip_out
# tripper
# three-bagger
# triplex
# three-base_hit
# rejoicing
# exulting
# exultant
# triumphal
# trivium
# trolling
# scout_troop
# scout_group
# cavalryman
# state_trooper
# Torrid_Zone
# tropical_zone
# Trotskyite
# Trot
# Trotskyist
# trouble_maker
# mischief-maker
# bad_hat
# troubler
# till
# public_treasury
# armistice
# cease-fire
# motortruck
# hand_truck
# truck_driver
# teamster
# on-key
# true_up
# admittedly
# dead_on_target
# avowedly
# confessedly
# earth-ball
# chocolate_truffle
# trump_card
# trump_out
# proboscis
# automobile_trunk
# tree_trunk
# luggage_compartment
# bole
# trustfulness
# trustingness
# reliance
# regent
# legal_guardian
# the_true
# verity
# true_statement
# Sojourner_Truth
# Truth
# try_on
# tubful
# bass_horn
# sousaphone
# tube-shaped_structure
# vacuum_tube
# thermionic_valve
# thermionic_tube
# electron_tube
# thermionic_vacuum_tube
# T.B.
# TB
# rapier
# tuition_fee
# tutorship
# get_it
# catch_on
# latch_on
# whirl_around
# get_wise
# cotton_on
# get_onto
# Russian_cactus
# Cycloloma_atriplicifolium
# Amaranthus_albus
# Russian_tumbleweed
# Amaranthus_graecizans
# Russian_thistle
# Salsola_kali_tenuifolia
# winged_pigweed
# tumour
# neoplasm
# tunny
# Anguilla_sucklandii
# Opuntia_tuna
# tuna_fish
# tune_up
# tunica
# adventitia
# Sturm_und_Drang
# turbulency
# roiling
# roily
# churning
# Turkey
# Republic_of_Turkey
# Meleagris_gallopavo
# turning
# turn_of_events
# change_state
# good_turn
# call_on
# turnaround_time
# turnround
# white_turnip
# Brassica_rapa
# negative_stimulation
# railroad_siding
# siding
# widening
# turnover_rate
# employee_turnover
# dollar_volume
# toll_road
# oil_of_turpentine
# turps
# spirit_of_turpentine
# gum_terpentine
# gun_turret
# gun_enclosure
# polo-neck
# turn_turtle
# capsize
# Desmond_Tutu
# ballet_skirt
# Tutu
# dinner_jacket
# black_tie
# twirp
# pair_of_pincers
# pair_of_tweezers
# tweezer
# 20
# twenty_dollar_bill
# XX
# xx
# branchlet
# sprig
# Gemini
# Twin
# Twin_Falls
# cruller
# vellication
# twitching
# ii
# Tyke
# typecast
# typewrite
# enteric_fever
# typhoid_fever
# autocrat
# despot
# omnipresent
# nefariousness
# vileness
# uke
# ulceration
# sonography
# ultrasonography
# echography
# UV
# ultraviolet_illumination
# ultraviolet_light
# ultraviolet_radiation
# umbilical_cord
# arbitrator
# ump
# arbiter
# umteen
# unaccepted
# unmoved
# consentient
# consentaneous
# unpredicted
# unheralded
# unreciprocated
# unvalued
# free-swimming
# unachievable
# unrealizable
# undoable
# neglected
# untempting
# unauthorised
# inescapable
# ineluctable
# incognizant
# imbalanced
# derange
# ungoverned
# unchecked
# uncurbed
# unbridle
# eldritch
# preternatural
# unsettled
# incertain
# unsealed
# precariousness
# uncertainness
# unaltered
# chartless
# unmapped
# undecipherable
# indecipherable
# ill-defined
# unreadable
# unconscious_mind
# irrepressible
# ungovernable
# uncorrectable
# indocile
# disobliging
# unmown
# full-length
# untrimmed
# underbody
# undervalue
# underestimation
# underreckoning
# lowball
# underrating
# underrate
# undergrad
# belowground
# underarm
# rug_pad
# underlayment
# carpet_pad
# underlie
# short-handed
# short-staffed
# undermanned
# perceivable
# apprehensible
# graspable
# intelligible
# take_in_charge
# sea-poose
# sea-puss
# sea_puss
# sea_purse
# sea-purse
# underclothes
# underclothing
# indiscernible
# indeterminate
# unquestioned
# unchallenged
# unmake
# ungarbed
# unclad
# unappareled
# ungarmented
# unattired
# unjustified
# deathless
# unemployed_people
# mismatched
# unaccountable
# stonyhearted
# unlooked-for
# out_of_the_blue
# unanticipated
# unfortunate_person
# inimical
# infelicitous
# unhurt
# unscathed
# insalubrious
# unhealthful
# unhallowed
# jointure
# interconnected
# undifferentiated
# opaque
# unplanned
# unwilled
# building_block
# social_unit
# unit_of_measurement
# linguistic_universal
# universal_proposition
# universal_joint
# universe_of_discourse
# inequitable
# unknown_quantity
# terra_incognita
# unknown_region
# straight-out
# outright
# inexhaustible
# offload
# unlade
# ill-omened
# ill-fated
# luckless
# ill-starred
# unman
# remote-controlled
# overlooked
# unnoted
# affected
# unneeded
# motiveless
# unentitled
# unknot
# ravel_out
# unpick
# untangle
# unscramble
# unapproachable
# out_of_reach
# unreached
# insubstantial
# unsubstantial
# undependable
# dissonant
# robustious
# rumbustious
# rambunctious
# disobedient
# insanitary
# unsatiated
# unsated
# unobserved
# spiritual_world
# spiritual_domain
# unasked
# mentally_ill
# unnameable
# unverbalised
# unverbalized
# unsaid
# unstated
# unexpressed
# unuttered
# abortive
# stillborn
# inapplicable
# unsuspicious
# unlikeable
# unlikable
# unappealing
# unkindly
# unlace
# unbrace
# unseasonable
# prematurely
# ill-timed
# Harijan
# untasted
# unswayed
# uninfluenced
# out_of_true
# untrusty
# unwedded
# unwished-for
# unwished
# wind_off
# unroll
# inexpedient
# undeserving
# well-being
# eudaimonia
# eudaemonia
# wellbeing
# upper_berth
# upright_piano
# unsloped
# garboil
# tumultuousness
# hubbub
# brouhaha
# upturned
# swage
# tip_over
# bowl_over
# tump_over
# overturned
# knock_over
# parvenu
# arriviste
# nouveau-riche
# parvenue
# upwards
# upwardly
# up
# U
# atomic_number_92
# importunity
# micturition
# habituate
# utilitarian
# utile
# drug_user
# exploiter
# substance_abuser
# James_Usher
# Ussher
# James_Ussher
# Usher
# public-service_corporation
# service_program
# public_utility_company
# public_utility
# utility-grade
# utility_program
# farthermost
# farthest
# furthest
# furthermost
# inoculation
# vaccinum
# vacuum-clean
# vacuum_cleaner
# hoover
# vacuity
# floating
# rootless
# drifting
# undefined
# pelmet
# valance_board
# cornice
# valedictory_speaker
# Valentine
# valorous
# formalise
# formalize
# robustness
# lustiness
# validness
# Valium
# diazepam
# worthful
# economic_value
# note_value
# time_value
# vamp_up
# revamp
# lamia
# new_wave
# Vandal
# hooliganism
# malicious_mischief
# vanilla_extract
# vaporisation
# vaporization
# vapour
# variable_star
# variable_quantity
# magnetic_declination
# pas_seul
# fluctuation
# magnetic_variation
# variety_show
# varment
# first_team
# value-added_tax
# VAT
# ad_valorem_tax
# bank_vault
# burial_vault
# veau
# veg
# vegetational
# vegetal
# vegetive
# fomite
# velum
# embryonic_membrane
# head_covering
# humeral_veil
# caul
# nervure
# venous_blood_vessel
# vena
# mineral_vein
# velours
# velvet-textured
# velvety
# blood_feud
# peddling
# vendition
# hawking
# facing
# veneering
# Venetian
# revengeful
# vent-hole
# blowhole
# venthole
# give_vent
# ventilation_system
# ventilating_system
# airing
# public_discussion
# breathing_apparatus
# breathing_device
# breathing_machine
# heart_ventricle
# locale
# locus
# finding_of_fact
# verse_line
# poetise
# versify
# poetize
# perpendicular
# vas
# watercraft
# undershirt
# singlet
# waistcoat
# veterinary_surgeon
# ex-serviceman
# stager
# old_hand
# warhorse
# old_stager
# veteran_soldier
# ampoule
# phial
# ampul
# ampule
# vibraharp
# vibraphone
# vivacious
# resonate
# frailty
# vicereine
# Limenitis_archippus
# winning
# video_recording
# eyeshot
# vantage_point
# wakefulness
# watchfulness
# weather_eye
# alertness
# open-eyed
# argus-eyed
# vigilance_man
# heartiness
# Pancho_Villa
# Villa
# Francisco_Villa
# Doroteo_Arango
# Greenwich_Village
# hamlet
# Village
# baddie
# exoneration
# acetum
# vinery
# time_of_origin
# vinyl_radical
# vinyl_group
# Viola
# genus_Viola
# irreverence
# reddish_blue
# Virgo
# Virgo_the_Virgin
# Virgin
# pair_of_virginals
# manfulness
# manliness
# moral_excellence
# virtuousness
# computer_virus
# visibleness
# seeable
# visual_sensation
# sojourn
# travel_to
# visitant
# life-sustaining
# verve
# life_force
# elan_vital
# vital_force
# vital_organ
# hellcat
# harpy
# mental_lexicon
# vocal_music
# occupational_group
# vox
# vocalism
# vocalisation
# phonation
# vocalization
# voice_mail
# volleyball_game
# electromotive_force
# emf
# military_volunteer
# Volunteer
# Tennessean
# unpaid_worker
# bosomy
# stacked
# full-bosomed
# curvy
# well-endowed
# busty
# curvaceous
# sonsy
# buxom
# sonsie
# vomitive
# emesis
# nauseant
# puking
# emetic
# regurgitation
# disgorgement
# vomiting
# hoodooism
# voodooism
# vodoun
# maelstrom
# suffrage
# right_to_vote
# voter_turnout
# elector
# verifier
# vowel_sound
# ocean_trip
# whacko
# nutter
# beach_waggon
# black_Maria
# police_van
# beach_wagon
# station_waggon
# coaster_wagon
# patrol_wagon
# estate_car
# waggon
# police_wagon
# station_wagon
# paddy_wagon
# pule
# mewl
# waiting
# hold_off
# Wake_Island
# Wake
# take_the_air
# manner_of_walking
# walkway
# walk_of_life
# paseo
# walking
# paries
# brush_kangaroo
# Erysimum_cheiri
# Cheiranthus_cheiri
# wham
# walnut_tree
# sea_horse
# seahorse
# waltz_around
# walk-in
# valse
# rover
# bird_of_passage
# roamer
# wishing
# trifle_away
# state_of_war
# Baroness_Jackson_of_Lodsworth
# Aaron_Montgomery_Ward
# Mary_Augusta_Arnold_Ward
# Mrs._Humphrey_Ward
# Barbara_Ward
# Ward
# hospital_ward
# Montgomery_Ward
# storage_warehouse
# warm_up
# warmly
# monition
# admonition
# word_of_advice
# warping
# stock_warrant
# stock-purchase_warrant
# war_vessel
# combat_ship
# verruca
# wash_out
# wash_drawing
# wash_away
# dry_wash
# lavation
# wash_off
# washing_machine
# automatic_washer
# white_Anglo-Saxon_Protestant
# WASP
# macerate
# waste_material
# waste_product
# thriftlessness
# permissive_waste
# waste_matter
# wastefulness
# dissipation
# emaciate
# pine_away
# circular_file
# waste_basket
# waste-paper_basket
# wastepaper_basket
# uneconomical
# look_out
# watch_out
# guard_dog
# security_guard
# water_system
# H2O
# water_supply
# body_of_water
# falls
# Citrullus_vulgaris
# watermelon_vine
# waterproofed
# rainproof
# water_company
# washy
# reeking
# Wave
# undulation
# waving
# moving_ridge
# beckon
# wafture
# fluctuate
# quaver
# crinkly
# crinkled
# rippled
# wavelike
# right_smart
# de-escalate
# helplessness
# impuissance
# wealthiness
# arms
# implements_of_war
# weapons_system
# have_on
# wear_thin
# wear_off
# aweary
# upwind
# weather_condition
# atmospheric_condition
# conditions
# weather_forecaster
# interweave
# World_Wide_Web
# entanglement
# WWW
# Wed
# Wednesday
# Midweek
# wedding_party
# hacek
# wedge_shape
# cuneus
# wedge_heel
# chock
# mourning_band
# widow's_weeds
# hebdomad
# calendar_week
# workweek
# hebdomadally
# hebdomadal
# every_week
# each_week
# hebdomadary
# librate
# system_of_weights
# weighting
# exercising_weight
# weight_unit
# free_weight
# weightiness
# Weird
# Wyrd
# bizarreness
# outlandishness
# Weld
# Theodore_Dwight_Weld
# Reseda_luteola
# dyer's_mignonette
# dyer's_rocket
# social_welfare
# public_assistance
# Welsh
# Welsh_Black
# Cambrian
# Cymric
# Welshman
# welch
# Cymry
# lycanthrope
# loup-garou
# wolfman
# W
# Occident
# Cicily_Isabel_Fairfield
# Benjamin_West
# Dame_Rebecca_West
# Rebecca_West
# Mae_West
# westward
# western_United_States
# due_west
# West
# westerly
# Western
# horse_opera
# western_sandwich
# lactating
# knickknackery
# bric-a-brac
# nicknack
# wheat_berry
# roulette_wheel
# steering_wheel
# wheel_around
# lawn_cart
# garden_cart
# barrow
# whimsicality
# flightiness
# arbitrariness
# capriciousness
# whiney
# querulous
# party_whip
# whiplash_injury
# whisk_off
# whisk_broom
# vibrissa
# bewhisker
# sensory_hair
# whisky
# voicelessness
# susurration
# pennywhistle
# whistling
# tin_whistle
# Patrick_White
# Patrick_Victor_Martindale_White
# White_person
# Edward_Douglas_White_Jr.
# white-hot
# Edward_White
# Andrew_D._White
# whitened
# Caucasian
# lily-white
# White
# Edward_D._White
# albumen
# whiten
# White_River
# Stanford_White
# ovalbumin
# Andrew_Dickson_White
# T._H._White
# Theodore_Harold_White
# egg_white
# E._B._White
# Elwyn_Brooks_White
# sleek_over
# gloss_over
# Whittle
# Frank_Whittle
# Sir_Frank_Whittle
# totally
# wholly
# all
# completely
# in_large_quantities
# sweeping
# whacker
# walloper
# repulsiveness
# loathsomeness
# sliminess
# lousiness
# caning
# wickerwork
# astray
# wide_of_the_mark
# widely
# far-flung
# widow_woman
# widowman
# Norbert_Wiener
# Wiener
# married_woman
# wigging
# state_of_nature
# natural_state
# raving_mad
# rampantly
# wildcat_well
# gnu
# Wilderness
# volition
# uncoerced
# unforced
# willow_tree
# wilt_disease
# wilting
# WIMP
# weakly_interacting_massive_particle
# wimpish
# windlass
# current_of_air
# wind_instrument
# wreathe
# air_current
# aerogenerator
# wind_generator
# windowpane
# windscreen
# wine-colored
# vino
# wine-coloured
# backstage
# offstage
# overwinter
# wiper_blade
# wiper_arm
# windscreen_wiper
# contact_arm
# windshield_wiper
# conducting_wire
# electrify
# sapience
# Wisdom
# wiseness
# soundness
# Wisdom_of_Solomon
# wise_to
# Isaac_Mayer_Wise
# Stephen_Samuel_Wise
# Wise
# indirect_request
# wish_well
# wishing_bone
# desirous
# Wiccan
# witchery
# bow_out
# climb-down
# backdown
# withdrawal_method
# coitus_interruptus
# pulling_out
# secession
# drug_withdrawal
# withholding_tax
# attestant
# attestor
# attestator
# Wobbly
# woefulness
# woman_chaser
# Friedrich_August_Wolf
# Wolf
# skirt_chaser
# wolf_down
# masher
# Hugo_Wolf
# Gulo_luscus
# Wolverine
# carcajou
# skunk_bear
# Michigander
# cleaning_lady
# cleaning_woman
# adult_female
# fair_sex
# charwoman
# womaniser
# philanderer
# superbly
# marvelously
# toppingly
# terrifically
# wondrously
# marvellously
# wonderfully
# Wood
# Mrs._Henry_Wood
# Ellen_Price_Wood
# woodwind_instrument
# Grant_Wood
# Sir_Henry_Wood
# Natalie_Wood
# Sir_Henry_Joseph_Wood
# woodwind
# woodman
# woodworker
# woollen
# do_work
# body_of_work
# oeuvre
# put_to_work
# piece_of_work
# proletarian
# prole
# work_load
# working_person
# working_man
# workingman
# idolise
# idolize
# hero-worship
# wounding
# wrapping
# envelop
# enwrap
# enfold
# coronal
# lei
# chaplet
# garland
# bust_up
# tow_car
# tow_truck
# spanner
# matman
# grappler
# poor_devil
# wrinkly
# unironed
# wrist_joint
# radiocarpal_joint
# carpus
# articulatio_radiocarpea
# wrist_watch
# judicial_writ
# drop_a_line
# incorrectly
# wrongly
# wrongfulness
# racing_yacht
# Yahoo
# Bos_grunniens
# Yankee-Doodle
# Yank
# Northerner
# Yankee
# yip
# yelp
# railyard
# curtilage
# railway_yard
# cubic_yard
# oscitancy
# oscitance
# twelvemonth
# yr
# every_year
# annually
# each_year
# barm
# yellowed
# jaundiced
# xanthous
# icteric
# scandalmongering
# yellowness
# yellowish
# sensationalistic
# buckle_under
# knuckle_under
# succumb
# descant
# warble
# yoghurt
# yoghourt
# vitellus
# egg_yolk
# Young
# Whitney_Moore_Young_Jr.
# Cy_Young
# untested
# Brigham_Young
# Lester_Willis_Young
# unseasoned
# Whitney_Young
# untried
# Loretta_Young
# Thomas_Young
# vernal
# Edward_Young
# Pres_Young
# Danton_True_Young
# youthfulness
# younker
# young_person
# juvenility
# spring_chicken
# early_days
# Zephyr
# zig-zag
# zag
# zig
# Zn
# atomic_number_30
# slide_fastener
# ZIP_code
# zip_fastener
# ZIP
# postal_code
# postcode
# zip_up
# zombi
# zombi_spirit
# zombie_spirit
# living_dead
# snake_god
# zona
# geographical_zone
# zoological_garden
# menagerie
# rapid_climb
# rapid_growth
# zoom_along
# whizz_along
# courgette

# %%
VAD_extend.set_index('Word',inplace=True)
VAD_extend_all = VAD.append(VAD_extend)

# %%
VAD_extend_all.to_csv('VAD_extend.csv')

# %%
VAD_extend_all.reset_index(inplace=True)

# %%
VAD_dict = VAD_extend_all.to_dict('index')

# %%
len(VAD_extend_all)
# Out:
# 36267

# %% [markdown]
# ---

# %%
VAD_extend_clean = VAD_extend_all.loc[VAD_extend_all.Word.str.contains('^[A-Za-z0-9]+$')].copy().reset_index(drop=True)
VAD_extend_clean
# Out:
#                    Word         V         A         D
# 0              aardvark  6.260000  2.410000  4.270000
# 1               abalone  5.300000  2.650000  4.950000
# 2               abandon  2.840000  3.730000  3.320000
# 3           abandonment  2.630000  4.950000  2.640000
# 4                 abbey  5.850000  2.200000  5.000000
# 5               abdomen  5.430000  3.680000  5.150000
# 6             abdominal  4.480000  3.500000  5.320000
# 7                abduct  2.420000  5.900000  2.750000
# 8             abduction  2.050000  5.330000  3.020000
# 9                 abide  5.520000  3.260000  5.330000
# 10              abiding  5.570000  3.590000  6.600000
# 11              ability  7.000000  4.850000  6.550000
# 12               abject  4.000000  3.940000  4.350000
# 13               ablaze  5.150000  6.750000  4.580000
# 14                 able  6.640000  3.380000  6.170000
# 15             abnormal  3.530000  4.480000  4.700000
# 16          abnormality  3.050000  5.000000  3.960000
# 17                abode  5.280000  2.900000  5.050000
# 18              abolish  3.840000  4.180000  4.650000
# 19           abominable  4.050000  5.450000  4.620000
# 20          abomination  2.500000  5.900000  3.800000
# 21                abort  3.100000  5.800000  3.380000
# 22             abortion  2.580000  5.430000  4.730000
# 23          abracadabra  5.110000  5.270000  4.960000
# 24             abrasive  4.260000  6.100000  4.940000
# 25              abreast  4.620000  4.610000  5.190000
# 26               abrupt  3.280000  5.230000  3.750000
# 27              abscess  2.790000  4.000000  3.950000
# 28              absence  3.860000  4.300000  4.240000
# 29               absent  4.100000  3.720000  4.210000
# ...                 ...       ...       ...       ...
# 26931          xanthous  6.130000  3.515000  5.785000
# 26932           icteric  6.130000  3.515000  5.785000
# 26933  scandalmongering  6.130000  3.515000  5.785000
# 26934        yellowness  6.130000  3.515000  5.785000
# 26935         yellowish  6.130000  3.515000  5.785000
# 26936  sensationalistic  6.130000  3.515000  5.785000
# 26937           succumb  5.765294  4.124118  5.567647
# 26938           descant  6.100000  3.330000  5.900000
# 26939            warble  6.100000  3.330000  5.900000
# 26940           yoghurt  7.000000  4.520000  6.000000
# 26941          yoghourt  7.000000  4.520000  6.000000
# 26942          vitellus  5.320000  3.050000  5.670000
# 26943             Young  6.078333  4.651667  5.393333
# 26944          untested  6.078333  4.651667  5.393333
# 26945        unseasoned  6.078333  4.651667  5.393333
# 26946           untried  6.078333  4.651667  5.393333
# 26947            vernal  6.078333  4.651667  5.393333
# 26948      youthfulness  6.420000  4.115000  5.300000
# 26949           younker  6.420000  4.115000  5.300000
# 26950        juvenility  6.420000  4.115000  5.300000
# 26951            Zephyr  6.606667  3.286667  5.163333
# 26952               zag  4.515000  5.045000  5.085000
# 26953               zig  4.515000  5.045000  5.085000
# 26954                Zn  4.790000  3.170000  5.000000
# 26955               ZIP  5.222000  4.918000  5.154000
# 26956          postcode  5.222000  4.918000  5.154000
# 26957             zombi  3.570000  6.530000  3.570000
# 26958              zona  4.550000  3.293333  5.080000
# 26959         menagerie  7.000000  5.630000  6.330000
# 26960         courgette  6.300000  4.180000  6.190000
#
# [26961 rows x 4 columns]
