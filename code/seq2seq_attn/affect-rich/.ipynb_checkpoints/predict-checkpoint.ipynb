# %%
import os
import pickle
import argparse
import numpy as np
from model import Options, Seq2SeqAttn
import tensorflow as tf

# %%
from beautifultable import BeautifulTable
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
# Parse the command line arguments.
parser = argparse.ArgumentParser()
parser.add_argument('--data_path', type = str, default = '../pre-data/',
                    help = 'the directory to the data')

parser = argparse.ArgumentParser()
parser.add_argument('--data_path', type = str, default = '../pre-data/',
                    help = 'the directory to the data')

parser.add_argument('--word_embeddings_path', type = str, default = '../pre-data/word_embeddings.npy',
                    help = 'the directory to the pre-trained word embeddings')
parser.add_argument('--VAD_path', type = str, default = '../pre-data/VAD.npy',
                    help = 'the directory to VAD')
parser.add_argument('--tf_path', type = str, default = '../pre-data/tf.npy',
                    help = 'the directory to term frequency')
parser.add_argument('--VAD_loss_path', type = str, default = '../pre-data/VAD_loss.npy',
                    help = 'the directory to VAD loss for each word')
parser.add_argument('--ti_path', type = str, default = '../pre-data/mu_li.npy',
                    help = 'the directory to term importance')

parser.add_argument('--num_epochs', type = int, default = 5,
                    help = 'the number of epochs to train the data')
parser.add_argument('--batch_size', type = int, default = 64,
                    help = 'the batch size')
parser.add_argument('--learning_rate', type = float, default = 0.0001,
                    help = 'the learning rate')
parser.add_argument('--beam_width', type = int, default = 32,
                    help = 'the beam width when decoding')
parser.add_argument('--word_embed_size', type = int, default = 256,
                    help = 'the size of word embeddings')
parser.add_argument('--n_hidden_units_enc', type = int, default = 256,
                    help = 'the number of hidden units of encoder')
parser.add_argument('--n_hidden_units_dec', type = int, default = 256,
                    help = 'the number of hidden units of decoder')
# ? attn_depth
parser.add_argument('--attn_depth', type = int, default = 128,
                    help = 'attention depth')

parser.add_argument('--restore_path_TS', type = str, default = '../model_dailydialog_rf_noVAD/model_TS',
                    help = 'the path to restore the trained model')
parser.add_argument('--save_path_TS', type = str, default = '../model_dailydialog_rf_noVAD/model_TS',
                    help = 'the path to save the trained model to')

parser.add_argument('--restore_path_ST', type = str, default = '../model_dailydialog_rf_noVAD/model_ST',
                    help = 'the path to restore the trained model')
parser.add_argument('--save_path_ST', type = str, default = '../model_dailydialog_rf_noVAD/model_ST',
                    help = 'the path to save the trained model to')

parser.add_argument('--restore_epoch', type = int, default = 5,
                    help = 'the epoch to restore')
# args = parser.parse_args()
args, unknown = parser.parse_known_args()

# %%
def read_data(data_path):
    def load_np_files(path):
        my_set = {}
        my_set['enc_input'] = np.load(os.path.join(path, 'enc_input.npy'))
        my_set['dec_input'] = np.load(os.path.join(path, 'dec_input.npy'))
        my_set['target'] = np.load(os.path.join(path, 'target.npy'))
        my_set['enc_input_len'] = np.load(os.path.join(path, 'enc_input_len.npy'))
        my_set['dec_input_len'] = np.load(os.path.join(path, 'dec_input_len.npy'))
        
        # to check if or not to complete the last batch
        idx = np.arange(my_set['dec_input'].shape[0])
        left_samples = idx[-1]%args.batch_size
        if left_samples:
            last_batch_idx = np.random.randint(0,idx[-1]-left_samples,size = args.batch_size - left_samples - 1)
            idx = np.concatenate([idx,last_batch_idx])
            
            my_set['enc_input'] = my_set['enc_input'][idx]
            my_set['dec_input'] = my_set['dec_input'][idx]
            my_set['target'] = my_set['target'][idx]
            my_set['enc_input_len'] = my_set['enc_input_len'][idx]
            my_set['dec_input_len'] = my_set['dec_input_len'][idx]
        return my_set
    test_set = load_np_files(os.path.join(data_path, 'test'))
    # dictionary index of words
    with open(os.path.join(data_path, 'token2id.pickle'), 'rb') as file:
        token2id = pickle.load(file)
    with open(os.path.join(data_path, 'id2token.pickle'), 'rb') as file:
        id2token = pickle.load(file)
    return test_set, token2id, id2token

# %%
def ids_to_sentence(ids, uttr_len, id2token): # ?
    tokens = []
    if uttr_len is not None:
        for i in range(uttr_len):
            if id2token[ids[i]] != '<eos>' and id2token[ids[i]] != '<go>':
                tokens.append(id2token[ids[i]])
    else:
        i = 0
        while i < len(ids) and id2token[ids[i]] != '<eos>':
            tokens.append(id2token[ids[i]])
            i += 1
    return ' '.join(tokens)

# %%
def revert(myset):
    enc_input = myset['dec_input'][:,1:]
    dec_input = np.insert(myset['enc_input'], 0, token2id['<go>'], axis=1) # add <go> in the beginning of encoder

    target = np.insert(myset['enc_input'], -1, 0, axis=1) 
    tmp_idx = [np.where(s==0)[0][0] for s in target] 
    target[np.arange(target.shape[0]),tmp_idx] = token2id['<eos>'] # add <eos> at the end of encoder
    
    newset = {}
    
    newset['enc_input'] = enc_input
    newset['dec_input'] = dec_input
    newset['target'] = target
    newset['enc_input_len'] = myset['dec_input_len']
    newset['dec_input_len'] = myset['enc_input_len']
    return newset

# %% [markdown]
# given enc_input predict prediction P(T|S)

# %%
test_set, token2id, id2token = read_data(args.data_path)

# %%
if __name__ == '__main__':
#     test_set, token2id, id2token = read_data(args.data_path)
    max_uttr_len_enc = test_set['enc_input'].shape[1]
    max_uttr_len_dec = test_set['dec_input'].shape[1]
    
    test_set['enc_input'] = test_set['enc_input'][:5*args.batch_size]

    word_embeddings = np.load(args.word_embeddings_path)
    VAD = np.load(args.VAD_path)
    termfreq = np.load(args.ti_path) # term importance
    termfreq = termfreq.reshape(-1,1)
    VAD_loss = np.load(args.VAD_loss_path)
    VAD_loss = VAD_loss.reshape(-1,1)

    options = Options(mode = 'PREDICT',
                      VAD_mode = 'FALSE',
                      num_epochs = args.num_epochs,
                      batch_size = args.batch_size,
                      learning_rate = args.learning_rate,
                      beam_width = args.beam_width,
                      corpus_size = len(token2id),
                      max_uttr_len_enc = max_uttr_len_enc,
                      max_uttr_len_dec = max_uttr_len_dec,
                      go_index = token2id['<go>'],
                      eos_index = token2id['<eos>'],
                      word_embed_size = args.word_embed_size,
                      n_hidden_units_enc = args.n_hidden_units_enc,
                      n_hidden_units_dec = args.n_hidden_units_dec,
                      attn_depth = args.attn_depth,
                      word_embeddings = word_embeddings)
    model_TS = Seq2SeqAttn(options)

    for var in model_TS.tvars:
        print(var.name)

    model_TS.restore(os.path.join(args.restore_path_TS, 'model_epoch_{:03d}.ckpt'.format(args.restore_epoch)))
    prediction_TS,probability_TS = model_TS.predict(test_set['enc_input'], test_set['enc_input_len'],VAD,termfreq)
# Out:
# Building the TensorFlow graph...
# embedding/embedding:0
# encoding/rnn/gru_cell/gates/kernel:0
# encoding/rnn/gru_cell/gates/bias:0
# encoding/rnn/gru_cell/candidate/kernel:0
# encoding/rnn/gru_cell/candidate/bias:0
# decoding/memory_layer/kernel:0
# decoding/attention_v:0
# decoding/my_bahdanau_attention/query_layer/kernel:0
# decoding/my_bahdanau_attention/attention_Wb/kernel:0
# decoding/attention_wrapper/gru_cell/gates/kernel:0
# decoding/attention_wrapper/gru_cell/gates/bias:0
# decoding/attention_wrapper/gru_cell/candidate/kernel:0
# decoding/attention_wrapper/gru_cell/candidate/bias:0
# decoding/dense/kernel:0
# decoding/dense/bias:0
# Restoring a pre-trained model from ../model_dailydialog_rf_noVAD/model_TS/model_epoch_005.ckpt...
# INFO:tensorflow:Restoring parameters from ../model_dailydialog_rf_noVAD/model_TS/model_epoch_005.ckpt

# %%
prediction_TS.shape
# Out:
# (320, 20, 32)

# %%
probability_TS.shape
# Out:
# (320, 32)

# %%
with open('../pre-data/test/prediction_TS_noVAD.pickle', 'wb') as f:
    pickle.dump(prediction_TS, f)
    
with open('../pre-data/test/probability_TS_noVAD.pickle', 'wb') as f:
    pickle.dump(probability_TS, f)

# %% [markdown]
# ---
# given prediction predict enc_input P(T|S)

# %%
with open('../pre-data/test/prediction_TS_noVAD.pickle', 'rb') as file:
    prediction_TS = pickle.load(file)
    
with open('../pre-data/test/probability_TS_noVAD.pickle', 'rb') as file:
    probability_TS = pickle.load(file)

# %%
# for every i in range(prediction_TS.shape[0])
# enc_input[i:i+args.beam_width] is the prediction of top args.beam_width of one given source from model_TS
enc_input = prediction_TS[0,:,:].T
for i in range(prediction_TS.shape[0]-1):
    enc_input = np.concatenate((enc_input,prediction_TS[i+1,:,:].T))

# %%
print(prediction_TS.shape,enc_input.shape)
# Out:
# (320, 20, 32) (10240, 20)

# %%
new_test_set = {}
new_test_set['enc_input'] = enc_input

multi_idx = np.tile(np.arange(test_set['enc_input'].shape[0]).T,(args.beam_width,1)).T.ravel()

new_test_set['dec_input'] = np.insert(test_set['enc_input'][multi_idx], 0, token2id['<go>'], axis=1)

# %%
target = np.insert(test_set['enc_input'], -1, 0, axis=1) 
tmp_idx = [np.where(s==0)[0][0] for s in target] 
target[np.arange(target.shape[0]),tmp_idx] = token2id['<eos>'] # add <eos> at the end of encoder

new_test_set['target'] = target[multi_idx]

# %%
new_test_set['enc_input_len'] = (enc_input.shape[1]*np.ones(enc_input.shape[0])).astype(int)
_,idx = np.unique(np.argwhere(enc_input==token2id['<eos>'])[:,0],return_index=True)
# multi <eos> in one sentence, so find the first <eos> in each row
# for those predictions without <eos> the length is max_len
new_test_set['enc_input_len'][np.argwhere(enc_input==token2id['<eos>'])[idx,0]] = np.argwhere(enc_input==token2id['<eos>'])[idx,1]

new_test_set['dec_input_len'] = np.tile(test_set['enc_input_len'],(args.beam_width,1)).T.ravel()

# %%
if __name__ == '__main__':
#     test_set, token2id, id2token = read_data(args.data_path)
    word_embeddings = np.load(args.word_embeddings_path)
    VAD = np.load(args.VAD_path)
    termfreq = np.load(args.ti_path) # term importance
    termfreq = termfreq.reshape(-1,1)

    max_uttr_len_enc = new_test_set['enc_input'].shape[1]
    max_uttr_len_dec = new_test_set['dec_input'].shape[1]
    
    options = Options(mode = 'POST_PREDICT',
                      VAD_mode = 'FALSE',
                      num_epochs = 1,
                      batch_size = 1,
                      learning_rate = args.learning_rate,
                      beam_width = args.beam_width,
                      corpus_size = len(token2id),
                      max_uttr_len_enc = max_uttr_len_enc,
                      max_uttr_len_dec = max_uttr_len_dec,
                      go_index = token2id['<go>'],
                      eos_index = token2id['<eos>'],
                      word_embed_size = args.word_embed_size,
                      n_hidden_units_enc = args.n_hidden_units_enc,
                      n_hidden_units_dec = args.n_hidden_units_dec,
                      attn_depth = args.attn_depth,
                      word_embeddings = word_embeddings)
    model_ST = Seq2SeqAttn(options)

    for var in model_ST.tvars:
        print(var.name)

    model_ST.restore(os.path.join(args.restore_path_ST, 'model_epoch_{:03d}.ckpt'.format(args.restore_epoch)))
    probability_ST = model_ST.post_predict(new_test_set, VAD,termfreq)
    probability_ST = probability_ST.reshape(-1,args.beam_width)
# Out:
# Building the TensorFlow graph...
# embedding/embedding:0
# encoding/rnn/gru_cell/gates/kernel:0
# encoding/rnn/gru_cell/gates/bias:0
# encoding/rnn/gru_cell/candidate/kernel:0
# encoding/rnn/gru_cell/candidate/bias:0
# decoding/memory_layer/kernel:0
# decoding/attention_v:0
# decoding/my_bahdanau_attention/query_layer/kernel:0
# decoding/my_bahdanau_attention/attention_Wb/kernel:0
# decoding/attention_wrapper/gru_cell/gates/kernel:0
# decoding/attention_wrapper/gru_cell/gates/bias:0
# decoding/attention_wrapper/gru_cell/candidate/kernel:0
# decoding/attention_wrapper/gru_cell/candidate/bias:0
# decoding/dense/kernel:0
# decoding/dense/bias:0
# Restoring a pre-trained model from ../model_dailydialog_rf_noVAD/model_ST/model_epoch_005.ckpt...
# INFO:tensorflow:Restoring parameters from ../model_dailydialog_rf_noVAD/model_ST/model_epoch_005.ckpt
# Start to train the model...

# %%
with open('../pre-data/test/probability_ST_noVAD.pickle', 'wb') as f:
    pickle.dump(probability_ST, f)

# %% [markdown]
# ---
# MMI

# %%
def sentence_VAD(sentence,VAD,s_len):
    vad = 0
    for i in range(s_len):
        vad += sum(abs(VAD[sentence[i]]))
    return vad/len(sentence)

# %%
def MMI_bidi(pred_TS,prob_TS,prob_ST,VAD,id2token):
    """
    pred_TS: [num_sentence, max_uttr_len_dec, beam_width]
    prob_TS, prob_ST: [num_sentence, beam_width]
    """
    df = pd.DataFrame(columns=['label_num','label','target',"prediction", "prob_TS", "prob_ST",'ABS_VAD'])
    
    for sentence_num in range(pred_TS.shape[0]):
        bias = sentence_num*args.beam_width
        target = ids_to_sentence(test_set['dec_input'][sentence_num], test_set['dec_input_len'][sentence_num], id2token)
        for i in range(args.beam_width):
            label = ids_to_sentence(new_test_set['dec_input'][bias+i], new_test_set['dec_input_len'][bias+i], id2token)
            pred_s = ids_to_sentence(pred_TS[sentence_num,:,i], new_test_set['enc_input_len'][bias+i], id2token)
            vad = sentence_VAD(pred_TS[sentence_num,:,i], VAD, new_test_set['enc_input_len'][bias+i])
            df.loc[bias+i] = list([sentence_num,label,target,pred_s,prob_TS[sentence_num,i],
                              prob_ST[sentence_num,i],vad])    
#     print(table)
    return df

# %%
df_noVAD = MMI_bidi(prediction_TS,probability_TS,probability_ST,VAD,id2token)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# df_noVAD.to_csv('MMI_noVAD.csv',index=False)
df = pd.read_csv('MMI.csv')
df_noVAD = pd.read_csv('MMI_noVAD.csv')

# %%
lambda_ = 0.8

# %%
df_pred_count = df.prediction.value_counts()

# %%
df_stat = df.groupby(df.prediction).agg({'prob_TS':['mean','count'],
                               'prob_ST':'mean',
                               'ABS_VAD':'mean'}).reset_index().sort_values(by=('prob_TS','count'),ascending=False)

# %%
plt.figure(figsize=(20,12))

plt.subplot(2,2,1)
plt.scatter(x=np.arange(50),y=df_stat.prob_TS['mean'].get_values()[:50])

plt.subplot(2,2,2)
plt.scatter(x=np.arange(50),y=df_stat.prob_ST['mean'].get_values()[:50])

plt.subplot(2,2,3)
plt.scatter(x=np.arange(50),y=df_stat.ABS_VAD['mean'].get_values()[:50])

plt.subplot(2,2,4)
plt.scatter(x=np.arange(50),y=(df_stat.prob_TS['mean']-df_stat.prob_ST['mean']).get_values()[:50])

# %%
df.label.unique()
# Out:
# array(['how come you aingt tell me he coming around more',
#        'where you been , dad', 'tomorrow to settle up , okay', 'what',
#        'so you would kill me as a show of your power',
#        "she 's breathing , okay", 'tino , what are you thinking',
#        "you know what i 'm thinking", 'want to buy one',
#        'who the fuck is this', 'who', "where 's lucy",
#        'what , you ... you okay', "why do n't you tell us about that",
#        'how would he know', "are you feeling what i 'm feeling",
#        'who are you', 'where are you going', 'camarillo',
#        'have you seen your father',
#        'does any man here object to the nuptials',
#        "wait . what 's going on", "you 'd give it all up",
#        'have you got the dog', "alright , brent 's two o 'clock",
#        "what 'd you say , bitch", 'on the <num>th floor',
#        'is it those jerks from the mall', 'fired',
#        'how you gonna do that , then', 'look what i got . huh',
#        'what do you see', 'are you sure you have enough',
#        'ready ? okay , here we go',
#        "why do you think it can n't work as a country song",
#        'could it mean ethan was here , too', "how 's your guy",
#        "so he 's a working musician",
#        'hey , hey , hey . where are you going',
#        '... tomorrow to settle up , okay',
#        'you were unarmed . you just walked in there and asked them for it',
#        'you expect us to pay you to save you',
#        "i 've spent years searching for .. this", "what 's going on",
#        'i get the dresses , right',
#        "you 're in this for the long haul , are n't you",
#        "why do n't you mind your own business",
#        'what you got for me , then', 'would you stop this',
#        "and why did n't they emit life signs", 'y-you did',
#        'tell me . is it true',
#        "yeah , do n't call me again until it 's done . all right",
#        'dog : why fight it', 'dad', 'you ever see the karate kid',
#        'which george',
#        "chaps , would n't it be easier just to go through the side",
#        'so that cryptic message on the phone , what are we talking about',
#        'what the fuck are you doing ?',
#        'how do you fancy doing a little favour for me', 'how do you do',
#        'write what', 'alright , how is lenny',
#        'who hurt you ? by the way that little slim of knowledge',
#        'convince ourselves not to take the final leap',
#        "are you falling for me like i 'm falling for you", 'why',
#        "ma , you 're healthy , right",
#        "are you spending your wife 's money",
#        "what are you doing ? they 're not targets at a",
#        'mike the spike ? kosher mike ? which mike',
#        'is that all right with you', 'where was ethan',
#        "did n't your mother teach you not to touch another man 's brownie",
#        "you do n't hear me", 'can we just start reading',
#        'you want to go get some ice cream', 'how do you',
#        'are you fucking mad , mick', 'can we go',
#        'blue : where you been , dad',
#        'hey , could you hand me that chicken',
#        "what 's he got them all penned up out here for",
#        'with your hands and all , aingt ya',
#        'was that not good enough for you',
#        'could i get this with the aioli on the side as i requested',
#        "oh , where 's ... where 's douglas haig , then", 'well , does he',
#        'can you move', 'who the fuck does she think she is',
#        'so where is she ? pepper', 'what ? mmm-mmm',
#        "it is something you 've seen before , is n't it",
#        'go on . she calls my name in the sleep', 'dog food . what',
#        'did you get the script', 'what do you like to drink',
#        'please , dad', 'ready , boy ? okay . come here . come here',
#        'the right place for what',
#        'so , you think you can take down vortigern', 'what is it', 'yeah',
#        'any excuse , huh , not to work', 'you gonna work today',
#        'this a bounty', 'can i walk with you', 'are you a good liar',
#        'do you know this pirate', 'agent : who was on the phone', 'where',
#        'what you done to your hands', 'have you not been tested',
#        'giving her agg',
#        "are you sure you did n't see someone else before you saw george",
#        'oh , yeah . keep rubbing . and might there be more bacon',
#        "who 's gonna take care of him", 'do you want to go',
#        'what are you doing , lack', 'what money', 'you love him',
#        'thomas', 'on the tip of your finger',
#        'hello , boy . what are you doing out at this time',
#        'what do you want , kid',
#        'quick question : can you tell me where a guy could find some pussy in this town',
#        'have you still got my picture on your wall',
#        "and i 've known you since we were , what , nine years old ? ten",
#        'wanna come with papa', 'bill', 'hey , boy . good',
#        'is that you , blue', "i 'd hang",
#        'what the hell took you so long', 'hey , thirsty',
#        "all you can ? he 's in a coma", 'am i prying too much',
#        'he assaulted you', 'ok ? alright', 'did you find your father',
#        'how have you been , reed', "took off ? he 'd never miss a game",
#        'so , what is this i hear about you terrorising sue and her little girl trixie , hmm',
#        'what do you mean she was already in there ? huh',
#        'you dream about them', 'did you look away',
#        'have we arrived in time to save you from each other',
#        'how many bitches does it hold',
#        "see ? that 's the problem with an education",
#        'huh ? take a look at that',
#        "why do n't you tell us what happened", 'somebody responsible',
#        'money', 'oh , like men',
#        'how do you feel about a rooftop king assassination',
#        'accurately ? <num>', 'what just happened', "what 's wrong",
#        'whose side are you on', 'have you finished', 'then',
#        'what kind of writer are you', 'is it you or is it her',
#        'is that correct', 'have we got the purse', 'bv : huh',
#        "so we 're back to that story , are we now , jack",
#        'in the fight back there , what did you say to that guy',
#        'tepid or warm',
#        "you 're both smart enough not to try anything , right", 'when',
#        'what ? you know that guy ? hey , hey , hey',
#        'a carousel ? giant wheel of cheese', "okay ? i 'm dead serious",
#        'you did', 'why are they holding you without bail',
#        'maybe they were a little bit tougher for me',
#        "what ? it 's like a girlfriend replacement or something",
#        'what the fuck is this', 'you keep that for me , okay , bailey',
#        'how are you feeling today , boy', 'where you going',
#        "so i 'm not going anywhere , am i", 'huh',
#        'shall i pick him up , sarge', 'the sale or the hug',
#        'wait . are you serious', 'goosefat , everything all right', 'or',
#        "so what 's the point", 'how many bathrooms',
#        "because i can n't trust anybody ! where are them",
#        'are you not listening', 'why did you volunteer',
#        "who 's gonna clean him",
#        "did you get my messages ? i 've been clogging up your voicemail",
#        'right ? i followed downs here and i see him talking to casino manager stan rubino',
#        'that gospel', 'what more do you need', 'why is he here',
#        'what are you talking about ? of course there are investments',
#        'hello',
#        'hey , when are you going to get a proper job , boy , hey',
#        'are you any good',
#        'who said anything about love , what are you talking about',
#        'why is that too much to ask', 'hey ... what the fuck is her name',
#        "you 'll make sure he finds a nice home , right",
#        'does that sound good to you',
#        "dena : all right , thomas , there 's another towel in the back , okay",
#        "but are you sure that he 's stable", 'are you okay',
#        'is there something i should know here',
#        "think you 'll be able to drive", "where 's my dad",
#        "gets the crowd involved , does n't it", 'what are you implying',
#        'but if there was no ethan , what was the point of my being here',
#        'oh , technically illegal ? you are an armed robber', 'a boy',
#        "why do n't you tell me", 'come on , len , ready ? come on , boy',
#        'how are you today', 'what are you doing',
#        'what am i supposed to do', "father , what 's happening",
#        "oh , you like it , do n't you",
#        'did he not study with mordred himself',
#        "you 're going to convict me", 'what made you come',
#        'well , you tell them i will take it inside , alright',
#        "you sure that 's a good idea",
#        'hold on . hold on . why are you reading it that way',
#        "the boys would n't sign the bond",
#        "do you read ' barron 's , ' huh",
#        "bill , what 'd you do ? the botox",
#        'so this was your plan ? to be tortured and killed by pirates',
#        'touches', 'come on , boy ! oh ! what',
#        'have you ever been married ? kids',
#        "i mean , everythings moving doing well here , is n't it",
#        'why the fuck is everyone up my butt today', 'eh',
#        'had i been here before', 'what do you give him',
#        "stay ? we 're playing fetch",
#        'do you have any idea who that man is',
#        'was not the prince friendly with the mages at one time',
#        'are you gonna finish it', 'okay , okay',
#        'what , do you think the whole fucking world owes you something',
#        'really',
#        'his coach called , said he missed the game . where is he',
#        "' why can n't everything smell like goat ?",
#        'i mean , why would they make me look fat',
#        "what you talking about ? that 's why you never home",
#        'what do you do ? what',
#        "so what , you do n't have to be a jock or anything to do it",
#        'you get him ? no', "what 's this", "what 'd that guy want",
#        'ready , bailey', 'andy : dad , how could you do this',
#        'what , no good mornings , no hellos', 'do what ? lanzarote',
#        'what the fuck is positiv', 'so where are we', 'he does',
#        'does it sound good to you', "you did n't hear it",
#        'come here . what', 'blue . blue . where you been , mate',
#        'immediate', 'how you gonna make money', "you mean asperger 's",
#        "where are you ? you 're not fucking fooling with me", 'okay',
#        'yes , gentlemen', "so what 's the rest",
#        "who 's shooting ? he shot the cop"], dtype=object)

# %%
df.loc[df.label_num==6]
# Out:
#      label_num                         label  \
# 192  6          tino , what are you thinking
# 193  6          tino , what are you thinking
# 194  6          tino , what are you thinking
# 195  6          tino , what are you thinking
# 196  6          tino , what are you thinking
# 197  6          tino , what are you thinking
# 198  6          tino , what are you thinking
# 199  6          tino , what are you thinking
# 200  6          tino , what are you thinking
# 201  6          tino , what are you thinking
# 202  6          tino , what are you thinking
# 203  6          tino , what are you thinking
# 204  6          tino , what are you thinking
# 205  6          tino , what are you thinking
# 206  6          tino , what are you thinking
# 207  6          tino , what are you thinking
# 208  6          tino , what are you thinking
# 209  6          tino , what are you thinking
# 210  6          tino , what are you thinking
# 211  6          tino , what are you thinking
# 212  6          tino , what are you thinking
# 213  6          tino , what are you thinking
# 214  6          tino , what are you thinking
# 215  6          tino , what are you thinking
# 216  6          tino , what are you thinking
# 217  6          tino , what are you thinking
# 218  6          tino , what are you thinking
# 219  6          tino , what are you thinking
# 220  6          tino , what are you thinking
# 221  6          tino , what are you thinking
# 222  6          tino , what are you thinking
# 223  6          tino , what are you thinking
#
#                                           prediction    prob_TS    prob_ST  \
# 192  yeah .                                          -4.460423  -41.745316
# 193  no .                                            -4.911420  -44.191116
# 194  yes .                                           -5.071821  -7.142359
# 195  okay .                                          -5.832999  -15.748528
# 196  come on .                                       -6.439532  -26.286020
# 197  i 'm sorry .                                    -6.984901  -29.226336
# 198  i do n't know .                                 -7.000763  -27.994682
# 199  i do n't .                                      -8.148950  -51.105934
# 200  what are you ?                                  -8.185874  -43.899414
# 201  i can n't .                                     -8.799090  -11.694035
# 202  i 'm gonna .                                    -8.951763  -17.607479
# 203  i can n't know .                                -9.272992  -20.015516
# 204  oh , i 'm sorry .                               -10.159695 -54.479595
# 205  well , i 'm sorry .                             -10.342186 -30.298447
# 206  i do n't know it .                              -10.376824 -19.360355
# 207  oh , i do n't know .                            -10.776784 -49.845840
# 208  i do n't know you .                             -10.892583 -8.573581
# 209  well , i do n't know .                          -10.894150 -50.802010
# 210  yeah , i do n't know .                          -11.218270 -13.344513
# 211  oh , i do n't .                                 -11.543109 -19.427956
# 212  i do n't know . i 'm sorry .                    -14.446386 -22.827152
# 213  i do n't know . i do n't know .                 -15.300578 -7.421060
# 214  i do n't know . i can n't .                     -15.602619 -17.026299
# 215  i do n't know . i do n't .                      -15.744075 -13.874228
# 216  i do n't know . i 'm gonna .                    -16.313725 -62.576290
# 217  i do n't know . i 'm not .                      -16.485497 -14.995386
# 218  i do n't know . i can n't know .                -16.742859 -33.681511
# 219  i do n't know . i can n't you .                 -17.819925 -14.544787
# 220  i do n't know . i do n't know you .             -19.469606 -43.601978
# 221  i do n't know . i do n't know . i 'm sorry .    -23.250412 -13.145159
# 222  i do n't know . i do n't know . i 'm not .      -25.233061 -38.682610
# 223  i do n't know . i do n't know . i 'm a little . -26.786192 -32.176323
#
#       ABS_VAD
# 192  0.000000
# 193  0.000000
# 194  0.000000
# 195  0.010317
# 196  0.010750
# 197  0.027475
# 198  0.041525
# 199  0.027325
# 200  0.010550
# 201  0.030125
# 202  0.015175
# 203  0.044325
# 204  0.027475
# 205  0.046546
# 206  0.041525
# 207  0.041525
# 208  0.041525
# 209  0.060596
# 210  0.041525
# 211  0.027325
# 212  0.069000
# 213  0.083050
# 214  0.071650
# 215  0.068850
# 216  0.056700
# 217  0.056700
# 218  0.085850
# 219  0.071650
# 220  0.083050
# 221  0.110525
# 222  0.098225
# 223  0.109675

# %%
df_noVAD.loc[df_noVAD.label_num==6]
# Out:
#      label_num                         label                      target  \
# 192  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 193  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 194  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 195  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 196  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 197  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 198  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 199  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 200  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 201  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 202  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 203  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 204  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 205  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 206  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 207  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 208  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 209  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 210  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 211  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 212  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 213  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 214  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 215  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 216  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 217  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 218  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 219  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 220  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 221  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 222  6          tino , what are you thinking  i 'm thinking i 'm ready .
# 223  6          tino , what are you thinking  i 'm thinking i 'm ready .
#
#                                                      prediction    prob_TS  \
# 192  yeah .                                                     -4.457238
# 193  no .                                                       -4.928251
# 194  what ?                                                     -5.348094
# 195  yes .                                                      -5.384078
# 196  okay .                                                     -5.856130
# 197  i 'm sorry .                                               -6.700066
# 198  come on .                                                  -7.018669
# 199  you know ?                                                 -7.229794
# 200  i do n't know .                                            -7.777487
# 201  oh , no .                                                  -8.137600
# 202  i do n't .                                                 -8.621898
# 203  i 'm not .                                                 -8.712008
# 204  i do n't know ?                                            -8.718421
# 205  i can n't know .                                           -9.324408
# 206  yeah , i 'm sorry .                                        -9.976541
# 207  i do n't know it .                                         -11.000463
# 208  oh , i do n't know .                                       -11.375763
# 209  yeah , i do n't know .                                     -11.425036
# 210  no , i do n't know .                                       -11.483724
# 211  well , i do n't know .                                     -11.679910
# 212  oh , i do n't know ?                                       -12.537263
# 213  i do n't know , i 'm sorry .                               -13.781605
# 214  i do n't know , i do n't know .                            -15.125947
# 215  i do n't know , i do n't .                                 -15.566449
# 216  i do n't know , i 'm not .                                 -15.572758
# 217  i do n't know , i do n't know ?                            -16.361900
# 218  i do n't know , i do n't know it .                         -18.508461
# 219  i do n't know , i do n't know , it .                       -20.279196
# 220  i do n't know , i do n't know , i 'm sorry .               -21.791622
# 221  i do n't know , i do n't know , i do n't know .            -23.115467
# 222  i do n't know , i do n't know , i do n't .                 -23.413250
# 223  i do n't know , i do n't know , i do n't know , i 'm not . -31.652330
#
#        prob_ST   ABS_VAD
# 192 -51.266876  0.000000
# 193 -16.561506  0.000000
# 194 -46.724899  0.000000
# 195 -24.624607  0.000000
# 196 -21.699766  0.010317
# 197 -37.053162  0.027475
# 198 -26.412724  0.010750
# 199 -50.359192  0.014200
# 200 -20.906837  0.041525
# 201 -9.570495   0.000000
# 202 -31.250057  0.027325
# 203 -22.770153  0.015175
# 204 -20.935955  0.041525
# 205 -29.192041  0.044325
# 206 -52.017853  0.027475
# 207 -46.935799  0.041525
# 208 -6.228040   0.041525
# 209 -3.921773   0.041525
# 210 -39.568634  0.041525
# 211 -55.770340  0.060596
# 212 -27.176853  0.041525
# 213 -21.576431  0.069000
# 214 -32.469524  0.083050
# 215 -15.333174  0.068850
# 216 -13.005096  0.056700
# 217 -35.931198  0.083050
# 218 -90.262787  0.083050
# 219 -21.046009  0.083050
# 220 -9.495355   0.110525
# 221 -45.008057  0.124575
# 222 -40.779842  0.110375
# 223 -31.408009  0.139750

# %%
pred_S2S = []
f = open('../pre-data/test/pred_S2S.txt', 'w', encoding = 'utf-8')
N = (test_set['enc_input'].shape[0] // args.batch_size) * args.batch_size
for i in range(N):
    f.write('HISTORY:\n')
    uttr = ids_to_sentence(test_set['enc_input'][i,:], test_set['enc_input_len'][i], id2token)
    f.write('- {}\n'.format(uttr))
    f.write('LABEL:\n')
    label = ids_to_sentence(test_set['target'][i,:], test_set['dec_input_len'][i], id2token)
    f.write('- {}\n'.format(label))
    f.write('PREDICTION:\n')
    pred = ids_to_sentence(prediction[i//args.batch_size][i%args.batch_size,:,0], None, id2token)
    f.write('- {}\n\n'.format(pred))
    pred_S2S.append(pred)
f.close()
with open('../pre-data/test/pred_S2S.pickle', 'wb') as f:
    pickle.dump(pred_S2S, f)

# %%
with open('../pre-data/test/prediction.pickle', 'wb') as f:
    pickle.dump(prediction, f)
